# %%
# !pip install C:\Users\archi\Downloads\TA_Lib-0.4.28-cp310-cp310-win_amd64.whl

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import logging
import talib
import time
from typing import Dict, List, Tuple, Optional, Any
from dataclasses import dataclass, field
from pathlib import Path
from datetime import datetime
import os
import sys
# 直接指定完整的專案路徑
project_path = r'C:\Users\archi\Python\Project\tw_stock_analysis'
sys.path.append(project_path)

import shutil
from tqdm import tqdm
import gc
import warnings
import traceback
from concurrent.futures import ThreadPoolExecutor, as_completed
from utils.config_utils import ConfigLoader, config_to_yaml

# %%
@dataclass
class FeatureConfig:
    """台股特徵生成配置類"""

    def __init__(self):
        # 應該添加默認的技術指標參數
        self.TECHNICAL_PARAMS = {
            'SMA': {'timeperiod': 30},
            'RSI': {'timeperiod': 14},
            'MACD': {'fastperiod': 12, 'slowperiod': 26, 'signalperiod': 9},
            'STOCH': {'fastk_period': 5, 'slowk_period': 3, 'slowd_period': 3},
            'BBANDS': {'timeperiod': 30, 'nbdevup': 2, 'nbdevdn': 2},
            'SAR': {'acceleration': 0.02, 'maximum': 0.2}
        }
    
    # 基礎路徑設定
    BASE_DIR: str = "D:/Min/Python/Project/FA_Data"
    META_DATA_DIR: str = "meta_data"
    BACKUP_DIR: str = "backup"
    LOG_DIR: str = "logs"
    FEATURES_DIR: str = "features"
    
    # 資料處理參數
    DATA_PROCESSING: Dict = field(default_factory=lambda: {
        'min_data_points': 30,
        'backup_days': 7,
        'missing_threshold': 0.1,
        'correlation_threshold': 0.95,
        'min_date_range': 30,
        'batch_size': 1000
    })
    
    # 技術指標配置
    TECHNICAL_FEATURES: Dict = field(default_factory=lambda: {
        'trend': ['SMA30', 'DEMA30', 'EMA30', 'TSF'],
        'momentum': ['RSI', 'MACD', 'MACD_signal', 'MACD_hist'],
        'volatility': ['slowk', 'slowd', 'upperband', 'lowerband', 'middleband', 'SAR'],
        'volume': ['量比', '量增率', '量能趨勢', '放量程度', '量價背離'],
        'price': ['振幅', '漲跌幅', '相對強弱', '趨勢強度']
    })
    
    # 技術指標參數
    TECH_PARAMS: Dict = field(default_factory=lambda: {
        'SMA': {'timeperiod': 30},
        'RSI': {'timeperiod': 14},
        'MACD': {'fastperiod': 12, 'slowperiod': 26, 'signalperiod': 9},
        'STOCH': {'fastk_period': 5, 'slowk_period': 3, 'slowd_period': 3},
        'BBANDS': {'timeperiod': 30, 'nbdevup': 2, 'nbdevdn': 2},
        'SAR': {'acceleration': 0.02, 'maximum': 0.2}
    })
    
    # 數據品質參數
    DATA_QUALITY: Dict = field(default_factory=lambda: {
        'min_price': 1.0,
        'min_volume': 1000,
        'max_missing_ratio': 0.1,
        'outlier_std_threshold': 3.0,
        'correlation_threshold': 0.95,
        'min_data_points': 30
    })
    
    # 特徵優先級設定
    FEATURE_PRIORITY: Dict[str, int] = field(default_factory=lambda: {
        '收盤價': 1,
        'RSI': 2,
        'MACD': 3,
        'KD_差值': 4,
        'SMA30': 5,
        'DEMA30': 6,
        'EMA30': 7,
        '波動率': 8,
        '趨勢強度': 9,
        '量能趨勢': 10
    })
    
    # 保護特徵列表
    PROTECTED_FEATURES: List[str] = field(default_factory=lambda: [
        'RSI', 'MACD', 'KD_差值', '收盤價', '開盤價', '最高價', '最低價'
    ])
    
    # 日誌設定
    LOGGING: Dict = field(default_factory=lambda: {
        'file_level': 'DEBUG',
        'console_level': 'INFO',
        'format': '%(asctime)s - %(name)s - %(levelname)s - %(message)s',
        'file_encoding': 'utf-8'
    })
    
    # 批次處理設定
    BATCH_PROCESSING: Dict = field(default_factory=lambda: {
        'max_workers': 4,
        'retry_times': 3,
        'retry_delay': 5,
        'timeout': 300
    })
    
    # 特徵生成設定
    FEATURE_GENERATION: Dict = field(default_factory=lambda: {
        'enable_advanced_features': True,
        'enable_volume_features': True,
        'enable_volatility_features': True,
        'min_periods': {
            'ma': 30,
            'volatility': 20,
            'volume': 20
        }
    })
    
    def __post_init__(self):
        """初始化後設定路徑"""
        self.base_path = Path(self.BASE_DIR)
        self.meta_data_path = self.base_path / self.META_DATA_DIR
        self.backup_path = self.meta_data_path / self.BACKUP_DIR
        self.log_path = self.base_path / self.LOG_DIR
        self.features_path = self.base_path / self.FEATURES_DIR
        
        # 確保所需目錄存在
        self._ensure_directories()
        
    def _ensure_directories(self):
        """確保必要的目錄結構存在"""
        directories = [
            self.base_path,
            self.meta_data_path,
            self.backup_path,
            self.log_path,
            self.features_path
        ]
        for directory in directories:
            directory.mkdir(parents=True, exist_ok=True)
            
    def validate(self) -> Tuple[bool, List[str]]:
        """驗證配置的有效性"""
        errors = []
        
        # 檢查路徑存在性
        for path_name, path in [
            ("基礎目錄", self.base_path),
            ("元數據目錄", self.meta_data_path),
            ("備份目錄", self.backup_path),
            ("日誌目錄", self.log_path),
            ("特徵目錄", self.features_path)
        ]:
            if not path.exists():
                errors.append(f"{path_name}不存在: {path}")
                
        # 檢查必要參數
        if self.DATA_PROCESSING['min_data_points'] < 20:
            errors.append("最小數據點數不應小於20")
            
        if self.DATA_PROCESSING['correlation_threshold'] <= 0:
            errors.append("相關性閾值必須大於0")
            
        # 檢查技術指標參數
        for indicator, params in self.TECH_PARAMS.items():
            if not params:
                errors.append(f"技術指標 {indicator} 缺少必要參數")
                
        return len(errors) == 0, errors
    
    def get_feature_priority(self, feature_name: str) -> int:
        """取得特徵優先級"""
        return self.FEATURE_PRIORITY.get(feature_name, 100)
    
    def is_protected_feature(self, feature_name: str) -> bool:
        """檢查是否為受保護特徵"""
        return feature_name in self.PROTECTED_FEATURES
        
    @classmethod
    def from_yaml(cls, config_path: Path) -> 'FeatureConfig':
        """從 YAML 文件創建配置實例"""
        # 載入配置
        config_data = ConfigLoader.load_config(config_path)
        if not config_data:
            # 如果配置文件不存在，創建預設配置
            ConfigLoader.create_default_config(config_path)
            config_data = ConfigLoader.load_config(config_path)
        
        # 創建實例
        instance = cls()
        
        # 更新配置值
        for key, value in config_data.items():
            if hasattr(instance, key):
                setattr(instance, key, value)
                
        # 初始化路徑
        instance.__post_init__()
        
        return instance
        
    def save_to_yaml(self, config_path: Path) -> bool:
        """保存當前配置到 YAML 文件"""
        config_dict = config_to_yaml(self)
        return ConfigLoader.save_config(config_dict, config_path)
        
    def update_from_dict(self, updates: Dict[str, Any]):
        """從字典更新配置"""
        for key, value in updates.items():
            if hasattr(self, key):
                setattr(self, key, value)

# %%
class FeatureLogger:
    """特徵生成日誌處理類"""
    
    def __init__(self, config: FeatureConfig):
        """初始化日誌處理器
        
        Args:
            config: FeatureConfig實例
        """
        self.config = config
        self.logger = self._setup_logger()
        
    def _setup_logger(self) -> logging.Logger:
        """設置日誌系統"""
        logger = logging.getLogger('FeatureGenerator')
        logger.setLevel(logging.INFO)
        
        # 清除現有的處理器
        logger.handlers.clear()
        
        # 設定日誌格式
        formatter = logging.Formatter(
            '%(asctime)s - %(name)s - %(levelname)s - %(message)s'
        )
        
        # 檔案處理器
        log_file = self.config.log_path / f"feature_generator_{datetime.now().strftime('%Y%m%d')}.log"
        file_handler = logging.FileHandler(log_file, encoding='utf-8')
        file_handler.setFormatter(formatter)
        file_handler.setLevel(logging.DEBUG)
        
        # 控制台處理器
        console_handler = logging.StreamHandler()
        console_handler.setFormatter(formatter)
        console_handler.setLevel(logging.INFO)
        
        logger.addHandler(file_handler)
        logger.addHandler(console_handler)
        
        return logger
    
    def info(self, msg: str):
        """記錄信息級別日誌"""
        self.logger.info(msg)
        
    def warning(self, msg: str):
        """記錄警告級別日誌"""
        self.logger.warning(msg)
        
    def error(self, msg: str):
        """記錄錯誤級別日誌"""
        self.logger.error(msg)
        
    def debug(self, msg: str):
        """記錄調試級別日誌"""
        self.logger.debug(msg)
        
    def critical(self, msg: str):
        """記錄嚴重錯誤級別日誌"""
        self.logger.critical(msg)

# %%
class DataValidator:
    """數據驗證類"""
    
    def __init__(self, config: FeatureConfig, logger: FeatureLogger):
        self.config = config
        self.logger = logger
        
    def validate_data(self, df: pd.DataFrame) -> Tuple[bool, List[str]]:
        errors = []
        
        # 檢查必要欄位
        required_columns = ['證券代號', '日期', '收盤價', '開盤價', '最高價', '最低價', '成交股數']
        missing_columns = [col for col in required_columns if col not in df.columns]
        if missing_columns:
            errors.append(f"缺少必要欄位: {', '.join(missing_columns)}")
            
        # 檢查數據量
        if len(df) < self.config.DATA_PROCESSING['min_data_points']:
            errors.append(f"數據點數不足: {len(df)} < {self.config.DATA_PROCESSING['min_data_points']}")
            
        # 檢查數值有效性
        numeric_columns = ['收盤價', '開盤價', '最高價', '最低價', '成交股數']
        for col in numeric_columns:
            if col in df.columns:
                values = pd.to_numeric(df[col], errors='coerce')
                null_mask = values.isnull()
                if null_mask.all():
                    errors.append(f"欄位 {col} 所有值皆為空")
                # 只檢查非空值
                valid_values = values[~null_mask]
                if len(valid_values) > 0 and (valid_values <= 0).any():
                    errors.append(f"欄位 {col} 存在小於或等於0的值")
                    
        return len(errors) == 0, errors

# %%
class DataPreprocessor:
    """數據預處理類"""
    
    def __init__(self, config: FeatureConfig, logger: FeatureLogger):
        self.config = config
        self.logger = logger
        
    def preprocess_data(self, df: pd.DataFrame) -> pd.DataFrame:
        """預處理數據
        
        Args:
            df: 原始DataFrame
            
        Returns:
            pd.DataFrame: 處理後的DataFrame
        """
        try:
            # 複製數據避免修改原始數據
            df = df.copy()
            
            # 處理日期列
            df['日期'] = pd.to_datetime(df['日期'])
            
            # 確保證券代號為字符串
            df['證券代號'] = df['證券代號'].astype(str)
            
            # 處理數值型欄位
            numeric_columns = ['開盤價', '最高價', '最低價', '收盤價', '成交股數', '成交金額']
            for col in numeric_columns:
                if col in df.columns:
                    # 移除千分位逗號
                    if df[col].dtype == object:
                        df[col] = df[col].str.replace(',', '')
                    # 轉換為數值類型
                    df[col] = pd.to_numeric(df[col], errors='coerce')
                    
            # 處理缺失值
            df = self._handle_missing_values(df)
            
            # 處理異常值
            df = self._handle_outliers(df)
            
            return df
            
        except Exception as e:
            self.logger.error(f"數據預處理失敗: {str(e)}")
            raise
            
    def _handle_missing_values(self, df: pd.DataFrame) -> pd.DataFrame:
        """處理缺失值"""
        # 價格相關欄位使用前值填充
        price_columns = ['開盤價', '最高價', '最低價', '收盤價']
        df[price_columns] = df[price_columns].fillna(method='ffill')
        
        # 成交量相關欄位使用0填充
        volume_columns = ['成交股數', '成交金額']
        df[volume_columns] = df[volume_columns].fillna(0)
        
        # 其他欄位使用中位數填充
        numeric_cols = df.select_dtypes(include=[np.number]).columns
        remaining_cols = [col for col in numeric_cols if col not in price_columns + volume_columns]
        df[remaining_cols] = df[remaining_cols].fillna(df[remaining_cols].median())
        
        return df
        
    def _handle_outliers(self, df: pd.DataFrame) -> pd.DataFrame:
        """處理異常值"""
        numeric_cols = df.select_dtypes(include=[np.number]).columns
        
        for col in numeric_cols:
            # 計算Z-score
            z_scores = np.abs((df[col] - df[col].mean()) / df[col].std())
            
            # 識別異常值
            outliers = z_scores > self.config.DATA_QUALITY['outlier_std_threshold']
            
            if outliers.any():
                # 使用winsorization處理異常值
                lower = df[col].quantile(0.01)
                upper = df[col].quantile(0.99)
                df.loc[outliers, col] = df.loc[outliers, col].clip(lower=lower, upper=upper)
                
                self.logger.warning(f"欄位 {col} 發現並處理了 {outliers.sum()} 個異常值")
                
        return df

# %%
class FeatureGenerator:
    """改進版特徵生成器"""
    
    def __init__(self, config: FeatureConfig):
        self.config = config
        self.logger = FeatureLogger(config)
        self.validator = DataValidator(config, self.logger)
        self.preprocessor = DataPreprocessor(config, self.logger)
        self.scaler = StandardScaler()
        
        # 新增：記憶體監控閾值
        self.memory_threshold = 0.85  # 當記憶體使用超過85%時發出警告
        
        # 新增：特徵計算快取
        self._feature_cache = {}

    def _generate_features_in_batches(self, df: pd.DataFrame) -> pd.DataFrame:
        """批次生成特徵"""
        try:
            # 分批處理的大小
            batch_size = min(len(df), 1000)
            
            # 儲存所有批次的結果
            results = []
            
            # 分批處理數據
            for start in range(0, len(df), batch_size):
                end = start + batch_size
                batch = df[start:end].copy()
                
                # 按順序添加各類特徵
                batch = self._add_technical_indicators(batch)
                batch = self._add_price_features(batch)
                batch = self._add_volume_features(batch)
                batch = self._add_volatility_features(batch)
                batch = self._add_advanced_features(batch)
                
                # 清理快取以節省記憶體
                if start % (batch_size * 5) == 0:
                    self._clear_feature_cache()
                    gc.collect()
                
                results.append(batch)
            
            # 合併所有批次結果
            final_df = pd.concat(results, ignore_index=True)
            
            # 移除高相關性特徵
            final_df = self._remove_correlated_features(final_df)
            
            return final_df
            
        except Exception as e:
            self.logger.error(f"批次生成特徵時發生錯誤: {str(e)}")
            raise
        
    def generate_features(self, df: pd.DataFrame, stock_id: str) -> pd.DataFrame:
        """改進的特徵生成主函數"""
        try:
            # 監控記憶體使用
            if self._check_memory_usage():
                self.logger.warning(f"記憶體使用率較高，請注意")
            
            self.logger.info(f"開始處理股票 {stock_id} 的特徵生成")
            
            # 優化：先進行基本檢查，避免不必要的運算
            if df.empty:
                self.logger.error(f"股票 {stock_id} 數據為空")
                return None
                
            # 資料驗證（增加快速驗證）
            if not self._quick_validate_data(df):
                self.logger.error(f"股票 {stock_id} 數據快速驗證失敗")
                return None
            
            # 詳細驗證
            is_valid, errors = self.validator.validate_data(df)
            if not is_valid:
                self.logger.error(f"股票 {stock_id} 數據驗證失敗: {errors}")
                return None
            
            # 優化：使用批次處理來預處理數據
            df = self._batch_preprocess_data(df)
            
            # 生成特徵
            features_df = self._generate_features_in_batches(df)
            
            # 清理快取
            self._clear_feature_cache()
            
            return features_df
            
        except Exception as e:
            self.logger.error(f"處理股票 {stock_id} 時發生錯誤: {str(e)}\n{traceback.format_exc()}")
            return None
            
        finally:
            # 強制記憶體回收
            gc.collect()
            
    def _check_memory_usage(self) -> bool:
        """檢查記憶體使用情況"""
        import psutil
        memory_use = psutil.Process().memory_percent()
        return memory_use > self.memory_threshold * 100
        
    def _quick_validate_data(self, df: pd.DataFrame) -> bool:
        """快速資料驗證"""
        required_columns = {'證券代號', '日期', '收盤價', '開盤價', '最高價', '最低價', '成交股數'}
        return all(col in df.columns for col in required_columns)
        
    def _batch_preprocess_data(self, df: pd.DataFrame) -> pd.DataFrame:
        """批次處理數據"""
        chunk_size = 1000
        chunks = [df[i:i + chunk_size] for i in range(0, len(df), chunk_size)]
        
        processed_chunks = []
        for chunk in chunks:
            processed_chunk = self.preprocessor.preprocess_data(chunk)
            processed_chunks.append(processed_chunk)
            
        return pd.concat(processed_chunks, ignore_index=True)
        
    def _clear_feature_cache(self):
        """清理特徵計算快取"""
        self._feature_cache.clear()
        gc.collect()
            
    def _add_technical_indicators(self, df: pd.DataFrame) -> pd.DataFrame:
        """優化的技術指標計算"""
        try:
            # 優化：將常用數據轉換為numpy數組以提高性能
            close_prices = df['收盤價'].values
            high_prices = df['最高價'].values
            low_prices = df['最低價'].values
            
            # 使用快取檢查是否已經計算過
            cache_key = f"tech_{len(df)}_{df['日期'].iloc[-1]}"
            if cache_key in self._feature_cache:
                return self._feature_cache[cache_key]
            
            # 優化：批次計算移動平均線
            ma_periods = [30]  # 可以輕鬆添加其他週期
            for period in ma_periods:
                df[f'SMA{period}'] = self._calculate_ma(close_prices, period, 'simple')
                df[f'EMA{period}'] = self._calculate_ma(close_prices, period, 'exp')
                df[f'DEMA{period}'] = self._calculate_ma(close_prices, period, 'double_exp')
            
            # 優化：並行計算動量指標
            with concurrent.futures.ThreadPoolExecutor(max_workers=3) as executor:
                futures = {
                    executor.submit(self._calculate_rsi, close_prices): 'RSI',
                    executor.submit(self._calculate_macd, close_prices): 'MACD',
                    executor.submit(self._calculate_kd, high_prices, low_prices, close_prices): 'KD'
                }
                
                for future in concurrent.futures.as_completed(futures):
                    indicator_name = futures[future]
                    try:
                        result = future.result()
                        if indicator_name == 'MACD':
                            df['MACD'], df['MACD_signal'], df['MACD_hist'] = result
                        elif indicator_name == 'KD':
                            df['slowk'], df['slowd'] = result
                        else:
                            df[indicator_name] = result
                    except Exception as e:
                        self.logger.error(f"計算{indicator_name}時發生錯誤: {str(e)}")
            
            # 布林通道計算
            df['middleband'] = df['SMA30']
            std = close_prices.std()
            df['upperband'] = df['middleband'] + (2 * std)
            df['lowerband'] = df['middleband'] - (2 * std)
            
            # 快取結果
            self._feature_cache[cache_key] = df
            
            return df
            
        except Exception as e:
            self.logger.error(f"技術指標計算失敗: {str(e)}")
            raise
            
    def _add_price_features(self, df: pd.DataFrame) -> pd.DataFrame:
        """優化的價格特徵計算"""
        try:
            # 使用向量化操作代替循環
            df['振幅'] = (df['最高價'] - df['最低價']) / df['收盤價']
            df['漲跌幅'] = df['收盤價'].pct_change()
            
            # 優化MA糾結度計算
            ma_columns = ['SMA30', 'DEMA30', 'EMA30']
            df['MA糾結度'] = df[ma_columns].apply(lambda x: x.std() / x.mean(), axis=1)
            
            # 優化趨勢計算
            price_sma = df['收盤價'].rolling(window=20).mean()
            df['趨勢強度'] = (df['收盤價'] - price_sma) / price_sma
            
            # 新增：價格突破特徵
            df['上突破'] = (df['收盤價'] > df['upperband']).astype(int)
            df['下突破'] = (df['收盤價'] < df['lowerband']).astype(int)
            
            return df
            
        except Exception as e:
            self.logger.error(f"價格特徵計算失敗: {str(e)}")
            raise

    def _calculate_ma(self, data: np.ndarray, period: int, ma_type: str) -> np.ndarray:
        """優化的移動平均線計算"""
        try:
            if ma_type == 'simple':
                return pd.Series(data).rolling(window=period).mean().values
            elif ma_type == 'exp':
                return pd.Series(data).ewm(span=period, adjust=False).mean().values
            elif ma_type == 'double_exp':
                ema = pd.Series(data).ewm(span=period, adjust=False).mean()
        except Exception as e:
            self.logger.error(f"MA計算失敗: {str(e)}")
            return None
            
    def _calculate_rsi(self, prices: np.ndarray, period: int = 14) -> np.ndarray:
        """優化的RSI計算"""
        deltas = np.diff(prices)
        seed = deltas[:period+1]
        up = seed[seed >= 0].sum()/period
        down = -seed[seed < 0].sum()/period
        rs = up/down
        rsi = np.zeros_like(prices)
        rsi[period] = 100. - 100./(1. + rs)

        for i in range(period+1, len(prices)):
            delta = deltas[i-1]
            if delta > 0:
                upval = delta
                downval = 0.
            else:
                upval = 0.
                downval = -delta

            up = (up*(period-1) + upval)/period
            down = (down*(period-1) + downval)/period
            rs = up/down
            rsi[i] = 100. - 100./(1. + rs)
            
        return rsi
            
    def _add_volume_features(self, df: pd.DataFrame) -> pd.DataFrame:
        """優化的量能特徵計算"""
        try:
            # 檢查快取
            cache_key = f"volume_{len(df)}_{df['日期'].iloc[-1]}"
            if cache_key in self._feature_cache:
                return self._feature_cache[cache_key]
            
            # 基礎量能數據準備
            volume = df['成交股數'].values
            close = df['收盤價'].values
            
            # 使用向量化操作計算基本量能指標
            df['量比'] = self._calculate_volume_ratio(volume)
            df['量增率'] = self._calculate_volume_change_rate(volume)
            
            # 優化：使用numpy操作計算移動平均
            volume_ma5 = self._moving_average(volume, 5)
            volume_ma20 = self._moving_average(volume, 20)
            
            df['量能趨勢'] = volume_ma5 / volume_ma20
            df['放量程度'] = df['量比'].rolling(window=5).mean()
            
            # 優化：向量化計算量價關係
            price_direction = np.sign(np.diff(close, prepend=close[0]))
            volume_direction = np.sign(np.diff(volume, prepend=volume[0]))
            df['量價背離'] = ((price_direction == 1) & (volume_direction == -1)).astype(int)
            
            # 新增：進階量能特徵
            df['量能波動'] = self._calculate_volume_volatility(volume)
            df['量價比'] = self._calculate_volume_price_ratio(volume, close)
            df['相對量能'] = self._calculate_relative_volume(volume)
            
            # 快取結果
            self._feature_cache[cache_key] = df
            
            return df
            
        except Exception as e:
            self.logger.error(f"量能特徵計算失敗: {str(e)}")
            raise
            
    def _add_volatility_features(self, df: pd.DataFrame) -> pd.DataFrame:
        """優化的波動特徵計算"""
        try:
            cache_key = f"volatility_{len(df)}_{df['日期'].iloc[-1]}"
            if cache_key in self._feature_cache:
                return self._feature_cache[cache_key]
            
            # 基礎數據準備
            close = df['收盤價'].values
            high = df['最高價'].values
            low = df['最低價'].values
            
            # 優化：使用numpy操作計算波動率
            returns = np.diff(np.log(close), prepend=np.log(close[0]))
            rolling_std = pd.Series(returns).rolling(20).std()
            
            df['波動率'] = rolling_std * np.sqrt(252)  # 年化波動率
            df['日內波動率'] = (high - low) / df['開盤價']
            
            # 布林通道相關特徵優化
            df['布林通道寬度'] = (df['upperband'] - df['lowerband']) / df['middleband']
            df['布林通道位置'] = (close - df['lowerband'].values) / (df['upperband'].values - df['lowerband'].values)
            
            # 新增：進階波動特徵
            df['波動趨勢'] = self._calculate_volatility_trend(returns)
            df['波動率變化'] = rolling_std.pct_change()
            df['相對波動率'] = self._calculate_relative_volatility(returns)
            
            # 快取結果
            self._feature_cache[cache_key] = df
            
            return df
            
        except Exception as e:
            self.logger.error(f"波動特徵計算失敗: {str(e)}")
            raise
            
    def _add_advanced_features(self, df: pd.DataFrame) -> pd.DataFrame:
        """添加進階技術特徵"""
        try:
            # 趨勢強度指標
            df['趨勢強度'] = (df['收盤價'] - df['SMA30']) / df['SMA30']
            
            # KD和RSI組合指標
            df['KD_差值'] = df['slowk'] - df['slowd']
            df['RSI_動能'] = df['RSI'] - df['RSI'].rolling(window=5).mean()
            
            # MACD相關指標
            df['MACD_動能'] = df['MACD'] - df['MACD'].rolling(window=5).mean()
            df['MACD_趨勢'] = np.where(df['MACD'] > df['MACD_signal'], 1, -1)
            
            # 綜合技術評分
            df['技術綜合評分'] = (
                (df['RSI'] - 50) / 20 +  # RSI貢獻
                df['MACD_hist'] / df['收盤價'] +  # MACD貢獻
                (df['slowk'] - 50) / 20 +  # KD貢獻
                df['趨勢強度'] * 0.5 +  # 趨勢貢獻
                (df['量比'] - 1) * 0.3  # 量能貢獻
            )
            
            return df
            
        except Exception as e:
            self.logger.error(f"計算進階特徵時發生錯誤: {str(e)}")
            raise

    # 輔助計算方法
    def _moving_average(self, data: np.ndarray, window: int) -> np.ndarray:
        """優化的移動平均計算"""
        weights = np.ones(window) / window
        return np.convolve(data, weights, mode='valid')
        
    def _calculate_volume_ratio(self, volume: np.ndarray) -> np.ndarray:
        """計算量比"""
        volume_ma20 = pd.Series(volume).rolling(20).mean()
        return volume / volume_ma20
        
    def _calculate_volume_change_rate(self, volume: np.ndarray) -> np.ndarray:
        """計算量增率"""
        return pd.Series(volume).pct_change()
        
    def _calculate_volume_volatility(self, volume: np.ndarray) -> np.ndarray:
        """計算量能波動"""
        return pd.Series(volume).rolling(20).std() / pd.Series(volume).rolling(20).mean()
        
    def _calculate_volume_price_ratio(self, volume: np.ndarray, close: np.ndarray) -> np.ndarray:
        """計算量價比"""
        return volume * close / (volume * close).mean()
        
    def _calculate_relative_volume(self, volume: np.ndarray) -> np.ndarray:
        """計算相對量能"""
        volume_ma = pd.Series(volume).rolling(20).mean()
        volume_std = pd.Series(volume).rolling(20).std()
        return (volume - volume_ma) / volume_std
        
    def _calculate_volatility_trend(self, returns: np.ndarray) -> np.ndarray:
        """計算波動趨勢"""
        vol_short = pd.Series(returns).rolling(5).std()
        vol_long = pd.Series(returns).rolling(20).std()
        return vol_short / vol_long
        
    def _calculate_relative_volatility(self, returns: np.ndarray) -> np.ndarray:
        """計算相對波動率"""
        vol = pd.Series(returns).rolling(20).std()
        vol_ma = vol.rolling(20).mean()
        return vol / vol_ma
    
    def _remove_correlated_features(self, df: pd.DataFrame) -> pd.DataFrame:
        """移除高度相關的特徵"""
        try:
            # 獲取數值型欄位
            numeric_cols = df.select_dtypes(include=[np.number]).columns
            
            # 計算相關係數矩陣
            corr_matrix = df[numeric_cols].corr()
            
            # 尋找高相關性特徵對
            features_to_remove = set()
            
            for i in range(len(numeric_cols)):
                for j in range(i+1, len(numeric_cols)):
                    if abs(corr_matrix.iloc[i, j]) > self.config.DATA_QUALITY['correlation_threshold']:
                        feature1 = numeric_cols[i]
                        feature2 = numeric_cols[j]
                        
                        # 不移除受保護的特徵
                        if self.config.is_protected_feature(feature1):
                            features_to_remove.add(feature2)
                        elif self.config.is_protected_feature(feature2):
                            features_to_remove.add(feature1)
                        else:
                            # 根據優先級決定要移除哪個特徵
                            priority1 = self.config.get_feature_priority(feature1)
                            priority2 = self.config.get_feature_priority(feature2)
                            features_to_remove.add(
                                feature2 if priority1 < priority2 else feature1
                            )
            
            if features_to_remove:
                self.logger.info(f"移除 {len(features_to_remove)} 個高相關性特徵")
                
            # 保留未被移除的特徵
            return df.drop(columns=list(features_to_remove))
            
        except Exception as e:
            self.logger.error(f"移除相關特徵時發生錯誤: {str(e)}")
            raise
            
    def _save_features(self, df: pd.DataFrame, stock_id: str):
        """保存特徵數據"""
        try:
            # 創建時間戳記
            timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
            
            # 保存特徵數據
            features_file = f"{stock_id}_features_{timestamp}.csv"
            features_path = self.config.features_path / features_file
            
            # 創建備份
            backup_path = self.config.backup_path / features_file
            
            # 保存數據
            df.to_csv(features_path, index=False, encoding='utf-8-sig')
            shutil.copy2(features_path, backup_path)
            
            self.logger.info(f"特徵數據已保存: {features_path}")
            self.logger.info(f"備份已創建: {backup_path}")
            
            # 清理舊備份
            self._cleanup_old_backups(stock_id)
            
        except Exception as e:
            self.logger.error(f"保存特徵時發生錯誤: {str(e)}")
            raise
            
    def _cleanup_old_backups(self, stock_id: str):
        """清理舊的備份文件"""
        try:
            backup_pattern = self.config.backup_path / f"{stock_id}_features_*.csv"
            backup_files = sorted(glob.glob(str(backup_pattern)), reverse=True)
            
            # 保留最新的N個備份
            keep_days = self.config.DATA_PROCESSING['backup_days']
            for old_backup in backup_files[keep_days:]:
                os.remove(old_backup)
                self.logger.debug(f"已刪除舊備份: {old_backup}")
                
        except Exception as e:
            self.logger.error(f"清理備份時發生錯誤: {str(e)}")

# %%
class BatchFeatureGenerator:
    """批次特徵生成處理器"""
    
    def __init__(self, config: FeatureConfig):
        self.config = config
        self.logger = FeatureLogger(config)
        self.feature_generator = FeatureGenerator(config)
        
    def process_all_stocks(self, df: pd.DataFrame) -> Dict[str, pd.DataFrame]:
        """處理所有股票的特徵生成
        
        Args:
            df: 包含所有股票數據的DataFrame
            
        Returns:
            Dict[str, pd.DataFrame]: 股票代碼到特徵DataFrame的映射
        """
        try:
            # 獲取唯一的股票代碼
            stock_ids = df['證券代號'].unique()
            total_stocks = len(stock_ids)
            self.logger.info(f"開始處理 {total_stocks} 支股票的特徵生成")
            
            # 初始化結果容器
            results = {}
            failed_stocks = []
            
            # 使用tqdm創建進度條
            with tqdm(total=total_stocks, desc="特徵生成進度") as pbar:
                # 批次處理
                for i in range(0, total_stocks, self.config.DATA_PROCESSING['batch_size']):
                    batch_stocks = stock_ids[i:i + self.config.DATA_PROCESSING['batch_size']]
                    batch_results = self._process_batch(df, batch_stocks)
                    
                    # 更新結果
                    results.update(batch_results['success'])
                    failed_stocks.extend(batch_results['failed'])
                    
                    # 更新進度條
                    pbar.update(len(batch_stocks))
                    pbar.set_postfix({
                        'Success': len(results),
                        'Failed': len(failed_stocks)
                    })
                    
                    # 清理記憶體
                    gc.collect()
            
            # 生成處理報告
            self._generate_processing_report(results, failed_stocks)
            
            return results
            
        except Exception as e:
            self.logger.error(f"批次處理過程中發生錯誤: {str(e)}")
            raise
            
    def _process_batch(self, df: pd.DataFrame, stock_ids: List[str]) -> Dict:
        """處理一批股票的特徵生成
        
        Args:
            df: 完整的數據DataFrame
            stock_ids: 要處理的股票代碼列表
            
        Returns:
            Dict: 包含成功和失敗結果的字典
        """
        batch_results = {
            'success': {},
            'failed': []
        }
        
        # 使用線程池進行並行處理
        with ThreadPoolExecutor(max_workers=4) as executor:
            future_to_stock = {
                executor.submit(self._process_single_stock, df, stock_id): stock_id
                for stock_id in stock_ids
            }
            
            for future in as_completed(future_to_stock):
                stock_id = future_to_stock[future]
                try:
                    result = future.result()
                    if isinstance(result, pd.DataFrame):
                        batch_results['success'][stock_id] = result
                    else:
                        batch_results['failed'].append(stock_id)
                except Exception as e:
                    self.logger.error(f"處理股票 {stock_id} 時發生錯誤: {str(e)}")
                    batch_results['failed'].append(stock_id)
                    
        return batch_results
        
    def _process_single_stock(self, df: pd.DataFrame, stock_id: str) -> Optional[pd.DataFrame]:
        """處理單一股票的特徵生成
        
        Args:
            df: 完整的數據DataFrame
            stock_id: 股票代碼
            
        Returns:
            Optional[pd.DataFrame]: 生成的特徵DataFrame，失敗時返回None
        """
        try:
            # 獲取該股票的數據
            stock_data = df[df['證券代號'] == stock_id].copy()
            
            if stock_data.empty:
                self.logger.warning(f"股票 {stock_id} 無數據")
                return None
                
            # 生成特徵
            return self.feature_generator.generate_features(stock_data, stock_id)
            
        except Exception as e:
            self.logger.error(f"處理股票 {stock_id} 時發生錯誤: {str(e)}")
            return None
            
    def _generate_processing_report(self, results: Dict[str, pd.DataFrame], 
                                 failed_stocks: List[str]):
        """生成特徵處理報告
        
        Args:
            results: 成功處理的結果
            failed_stocks: 處理失敗的股票列表
        """
        try:
            report_path = self.config.meta_data_path / 'feature_generation_report.txt'
            
            with open(report_path, 'w', encoding='utf-8') as f:
                f.write("特徵生成處理報告\n")
                f.write(f"生成時間: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n\n")
                
                # 成功統計
                f.write(f"成功處理數量: {len(results)}\n")
                if results:
                    example_stock = next(iter(results))
                    example_df = results[example_stock]
                    f.write(f"特徵數量: {len(example_df.columns)}\n")
                    f.write("\n特徵列表:\n")
                    for col in example_df.columns:
                        f.write(f"- {col}\n")
                        
                # 失敗統計
                f.write(f"\n失敗處理數量: {len(failed_stocks)}\n")
                if failed_stocks:
                    f.write("失敗的股票代碼:\n")
                    for stock_id in failed_stocks:
                        f.write(f"- {stock_id}\n")
                        
            self.logger.info(f"處理報告已保存至: {report_path}")
            
        except Exception as e:
            self.logger.error(f"生成處理報告時發生錯誤: {str(e)}")

# %%
def main():
    """主程序邏輯"""
    try:
        # 初始化配置
        config = FeatureConfig()
        logger = FeatureLogger(config)
        logger.info("開始執行特徵生成主程序")
        
        # 驗證執行環境
        validate_environment(config, logger)
        
        # 讀取股票數據
        df = load_stock_data(config, logger)
        
        # 初始化批次處理器
        batch_processor = BatchFeatureGenerator(config)
        
        # 執行特徵生成
        results = process_feature_generation(batch_processor, df, logger)
        
        # 保存結果
        save_results(results, config, logger)
        
        # 生成報告
        generate_execution_report(results, config, logger)
        
        return True
        
    except Exception as e:
        if logger:
            logger.error(f"主程序執行錯誤: {str(e)}")
            logger.error(traceback.format_exc())
        else:
            print(f"執行錯誤: {str(e)}")
        return False

def validate_environment(config: FeatureConfig, logger: FeatureLogger) -> bool:
    """驗證執行環境"""
    try:
        logger.info("開始驗證執行環境")
        
        # 檢查必要目錄
        required_dirs = [
            config.meta_data_path,
            config.features_path,
            config.backup_path
        ]
        
        for directory in required_dirs:
            if not directory.exists():
                directory.mkdir(parents=True, exist_ok=True)
                logger.info(f"創建目錄: {directory}")
                
        # 檢查系統資源
        memory_check = check_memory_requirements()
        disk_check = check_disk_space(config)
        
        if not (memory_check and disk_check):
            raise ResourceWarning("系統資源不足")
            
        logger.info("環境驗證完成")
        return True
        
    except Exception as e:
        logger.error(f"環境驗證失敗: {str(e)}")
        raise

def load_stock_data(config: FeatureConfig, logger: FeatureLogger) -> pd.DataFrame:
    """讀取股票數據"""
    try:
        logger.info("開始讀取股票數據")
        
        file_path = config.meta_data_path / 'stock_data_whole.csv'
        if not file_path.exists():
            raise FileNotFoundError(f"找不到數據文件: {file_path}")
            
        # 讀取數據
        df = pd.read_csv(
            file_path,
            dtype={
                '證券代號': str,
                '證券名稱': str,
                '日期': str
            },
            na_values=['--'],
            keep_default_na=True,
            low_memory=False
        )
        
        # 數據基本驗證
        if df.empty:
            raise ValueError("讀取到的數據為空")
            
        # 數據清理
        df = clean_stock_data(df)
        
        logger.info(f"成功讀取數據: {len(df)} 筆記錄")
        return df
        
    except Exception as e:
        logger.error(f"數據讀取失敗: {str(e)}")
        raise

def clean_stock_data(df: pd.DataFrame) -> pd.DataFrame:
    """清理股票數據"""
    # 移除重複資料
    df = df.drop_duplicates(subset=['證券代號', '日期'], keep='last')
    
    # 處理缺失值
    numeric_columns = ['開盤價', '最高價', '最低價', '收盤價', '成交股數', '成交金額']
    for col in numeric_columns:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors='coerce')
            
    # 排序數據
    df = df.sort_values(['證券代號', '日期'])
    
    return df

def process_feature_generation(batch_processor: BatchFeatureGenerator,
                           df: pd.DataFrame,
                           logger: FeatureLogger) -> Dict[str, pd.DataFrame]:
    """執行特徵生成流程"""
    try:
        logger.info("開始生成特徵")
        start_time = time.time()
        
        # 取得股票清單
        stock_ids = df['證券代號'].unique()
        logger.info(f"預計處理 {len(stock_ids)} 支股票")
        
        # 執行批次處理
        results = batch_processor.process_all_stocks(df)
        
        # 驗證結果
        validate_results(results, stock_ids, logger)
        
        execution_time = time.time() - start_time
        logger.info(f"特徵生成完成，耗時: {execution_time:.2f} 秒")
        
        return results
        
    except Exception as e:
        logger.error(f"特徵生成失敗: {str(e)}")
        raise

def validate_results(results: Dict[str, pd.DataFrame],
                   stock_ids: np.ndarray,
                   logger: FeatureLogger) -> bool:
    """驗證特徵生成結果"""
    try:
        processed_stocks = set(results.keys())
        expected_stocks = set(stock_ids)
        
        # 檢查是否有遺漏的股票
        missing_stocks = expected_stocks - processed_stocks
        if missing_stocks:
            logger.warning(f"有 {len(missing_stocks)} 支股票未成功處理")
            logger.debug(f"未處理股票: {', '.join(missing_stocks)}")
            
        # 驗證每個股票的特徵
        for stock_id, features_df in results.items():
            if features_df.empty:
                logger.warning(f"股票 {stock_id} 的特徵數據為空")
                continue
                
            # 檢查必要特徵
            required_features = [
                'RSI', 'MACD', 'KD_差值', 'SMA30',
                'DEMA30', 'EMA30', '趨勢強度', '量能趨勢'
            ]
            missing_features = [f for f in required_features if f not in features_df.columns]
            if missing_features:
                logger.warning(f"股票 {stock_id} 缺少特徵: {', '.join(missing_features)}")
                
        return True
        
    except Exception as e:
        logger.error(f"結果驗證失敗: {str(e)}")
        return False

def save_results(results: Dict[str, pd.DataFrame],
               config: FeatureConfig,
               logger: FeatureLogger):
    """保存特徵生成結果"""
    try:
        logger.info("開始保存特徵數據")
        
        # 建立保存目錄
        save_time = datetime.now().strftime('%Y%m%d_%H%M%S')
        save_dir = config.features_path / f"features_{save_time}"
        save_dir.mkdir(parents=True, exist_ok=True)
        
        # 保存各股票特徵
        successful_saves = 0
        for stock_id, features_df in results.items():
            try:
                file_path = save_dir / f"{stock_id}_features.csv"
                features_df.to_csv(file_path, index=False, encoding='utf-8-sig')
                successful_saves += 1
            except Exception as e:
                logger.error(f"保存股票 {stock_id} 特徵失敗: {str(e)}")
                
        # 保存處理摘要
        save_summary(results, save_dir, logger)
        
        # 建立備份
        backup_path = config.backup_path / f"features_{save_time}"
        shutil.copytree(save_dir, backup_path)
        
        logger.info(f"成功保存 {successful_saves}/{len(results)} 支股票的特徵")
        
    except Exception as e:
        logger.error(f"結果保存失敗: {str(e)}")
        raise

def save_summary(results: Dict[str, pd.DataFrame],
               save_dir: Path,
               logger: FeatureLogger):
    """保存處理摘要"""
    try:
        summary_path = save_dir / "summary.txt"
        with open(summary_path, 'w', encoding='utf-8') as f:
            f.write("特徵生成處理摘要\n")
            f.write(f"生成時間: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n\n")
            
            # 統計資訊
            f.write(f"處理股票總數: {len(results)}\n")
            
            if results:
                example_stock = next(iter(results.values()))
                f.write(f"特徵數量: {len(example_stock.columns)}\n")
                f.write("\n特徵列表:\n")
                for col in example_stock.columns:
                    f.write(f"- {col}\n")
                    
    except Exception as e:
        logger.error(f"摘要保存失敗: {str(e)}")

def generate_execution_report(results: Dict[str, pd.DataFrame],
                          config: FeatureConfig,
                          logger: FeatureLogger):
    """生成執行報告"""
    try:
        logger.info("生成執行報告")
        
        # 計算成功率
        total_stocks = len(results)
        successful_stocks = sum(1 for df in results.values() if not df.empty)
        success_rate = (successful_stocks / total_stocks * 100) if total_stocks > 0 else 0
        
        # 記錄執行統計
        logger.info(f"""
        執行統計:
        - 總處理股票數: {total_stocks}
        - 成功處理數量: {successful_stocks}
        - 成功率: {success_rate:.2f}%
        """)
        
        # 特徵統計
        if successful_stocks > 0:
            example_df = next(df for df in results.values() if not df.empty)
            logger.info(f"""
            特徵統計:
            - 特徵數量: {len(example_df.columns)}
            - 數據時間範圍: {example_df['日期'].min()} 到 {example_df['日期'].max()}
            """)
            
    except Exception as e:
        logger.error(f"報告生成失敗: {str(e)}")

def check_memory_requirements() -> bool:
    """檢查記憶體需求"""
    import psutil
    
    available_memory = psutil.virtual_memory().available / (1024 * 1024 * 1024)  # GB
    return available_memory >= 4  # 需要至少4GB可用記憶體

def check_disk_space(config: FeatureConfig) -> bool:
    """檢查硬碟空間"""
    import psutil
    
    # 檢查特徵目錄所在磁碟的可用空間
    disk_usage = psutil.disk_usage(str(config.features_path))
    available_space = disk_usage.free / (1024 * 1024 * 1024)  # GB
    return available_space >= 10

# %%
class FeatureGeneratorTester:
    """特徵生成器測試類"""
    
    def __init__(self):
        self.logger = logging.getLogger(__name__)
        self.base_dir = Path("D:/Min/Python/Project/FA_Data")
        self.test_results_dir = self.base_dir / 'test_results'
        self.test_results_dir.mkdir(parents=True, exist_ok=True)
        
        # 設置測試參數
        self.test_params = {
            'stock_id': '2330',
            'start_date': '2023-01-01',
            'end_date': '2023-12-31'
        }
    
    def _validate_simple_features(self, df: pd.DataFrame) -> bool:
        """簡單的特徵驗證"""
        # 檢查技術指標的合理性
        if 'RSI' in df.columns:
            if not ((df['RSI'] >= 0) & (df['RSI'] <= 100)).all():
                self.logger.error("RSI值超出合理範圍")
                return False
        return True

    def run_tests(self) -> bool:
        try:
            self.logger.info(f"開始測試特徵生成器 - 股票代碼: {self.test_params['stock_id']}")
            
            # 1. 環境檢查
            if not self._check_environment():
                return False
            
            # 2. 載入測試數據
            try:
                # 直接讀取數據文件
                df = pd.read_csv(
                    self.base_dir / 'meta_data' / 'stock_data_whole.csv',
                    dtype={'證券代號': str, '證券名稱': str, '日期': str},
                    na_values=['--'],
                    keep_default_na=True,
                    low_memory=False
                )
                
                # 轉換數值欄位
                numeric_cols = ['開盤價', '最高價', '最低價', '收盤價', '成交股數', '成交金額']
                for col in numeric_cols:
                    df[col] = pd.to_numeric(df[col], errors='coerce')
                
                # 過濾數據
                stock_df = df[
                    (df['證券代號'] == self.test_params['stock_id']) &
                    (df['日期'] >= self.test_params['start_date']) &
                    (df['日期'] <= self.test_params['end_date'])
                ].copy()
                
            except Exception as e:
                self.logger.error(f"讀取數據時發生錯誤: {str(e)}")
                return False
                
            if stock_df.empty:
                self.logger.error("無法載入測試數據")
                return False
            
            # 3. 生成特徵
            config = FeatureConfig()
            generator = FeatureGenerator(config)
            features_df = generator.generate_features(stock_df, self.test_params['stock_id'])
            
            # 4. 驗證特徵
            if not self._validate_features(features_df):
                return False
            
            # 5. 保存測試結果
            self._save_test_results(features_df)
            
            # 6. 打印測試報告
            self._print_test_report(features_df)
            
            return True
            
        except Exception as e:
            self.logger.error(f"特徵生成器測試失敗: {str(e)}")
            return False
            
    def _check_environment(self) -> bool:
        """檢查測試環境"""
        try:
            # 檢查必要目錄
            required_dirs = ['meta_data', 'technical_analysis', 'features']
            for dir_name in required_dirs:
                if not (self.base_dir / dir_name).exists():
                    self.logger.error(f"缺少必要目錄: {dir_name}")
                    return False
            
            # 檢查必要文件
            required_files = [
                'meta_data/all_stocks_data.csv',
                f"technical_analysis/{self.test_params['stock_id']}_indicators.csv"
            ]
            for file_path in required_files:
                if not (self.base_dir / file_path).exists():
                    self.logger.error(f"缺少必要文件: {file_path}")
                    return False
                    
            return True
            
        except Exception as e:
            self.logger.error(f"環境檢查失敗: {str(e)}")
            return False
            
    def _validate_features(self, df: pd.DataFrame) -> bool:
        """特徵驗證"""
        try:
            # 1. 檢查必要特徵
            required_features = [
                'SMA30', 'DEMA30', 'EMA30', 'RSI', 'MACD',
                'slowk', 'slowd', 'SAR', '趨勢強度', '均線糾結度',
                '波動率', '量能趨勢', '技術綜合評分'
            ]
            missing_features = [f for f in required_features if f not in df.columns]
            if missing_features:
                self.logger.error(f"缺少必要特徵: {missing_features}")
                return False
            
            # 2. 檢查數據品質
            null_counts = df[required_features].isnull().sum()
            if null_counts.any():
                self.logger.warning("存在缺失值:")
                for feature, count in null_counts[null_counts > 0].items():
                    self.logger.warning(f"- {feature}: {count} 個缺失值")
            
            # 3. 檢查數據範圍
            value_ranges = {
                'RSI': (0, 100),
                '量比': (0, None),
                '趨勢強度': (None, None),
                '波動率': (0, None)
            }
            
            for feature, (min_val, max_val) in value_ranges.items():
                if feature not in df.columns:
                    continue
                    
                if min_val is not None and df[feature].min() < min_val:
                    self.logger.error(f"{feature} 值小於最小值 {min_val}")
                    return False
                    
                if max_val is not None and df[feature].max() > max_val:
                    self.logger.error(f"{feature} 值大於最大值 {max_val}")
                    return False
            
            return True
            
        except Exception as e:
            self.logger.error(f"特徵驗證失敗: {str(e)}")
            return False
            
    def _save_test_results(self, df: pd.DataFrame):
        """保存測試結果"""
        try:
            timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
            
            # 保存特徵數據
            features_file = self.test_results_dir / f'features_{timestamp}.csv'
            df.to_csv(features_file, index=False, encoding='utf-8-sig')
            
            # 保存統計報告
            report_file = self.test_results_dir / f'test_report_{timestamp}.txt'
            with open(report_file, 'w', encoding='utf-8') as f:
                f.write(f"特徵生成器測試報告\n")
                f.write(f"測試時間: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
                f.write(f"測試股票: {self.test_params['stock_id']}\n")
                f.write(f"數據期間: {self.test_params['start_date']} 到 {self.test_params['end_date']}\n")
                f.write(f"數據筆數: {len(df)}\n")
                f.write(f"特徵數量: {len(df.columns)}\n\n")
                
                f.write("特徵統計摘要:\n")
                f.write(df.describe().to_string())
            
            self.logger.info(f"測試結果已保存至: {self.test_results_dir}")
            
        except Exception as e:
            self.logger.error(f"保存測試結果失敗: {str(e)}")
            
    def _print_test_report(self, df: pd.DataFrame):
        """打印測試報告"""
        print("\n=== 特徵生成測試報告 ===")
        print(f"測試股票: {self.test_params['stock_id']}")
        print(f"特徵數量: {len(df.columns)}")
        print("\n特徵列表:")
        for i, col in enumerate(df.columns, 1):
            print(f"{i}. {col}")
        print("\n特徵統計摘要:")
        print(df.describe())

# %%
def initialize_system():
    """系統初始化"""
    config = FeatureConfig()
    logger = FeatureLogger(config)
    logger.info("系統初始化開始")
    
    # 確保目錄結構
    config._ensure_directories()
    
    # 檢查系統資源
    check_system_resources(logger)
    
    return config, logger

def check_system_resources(logger):
    """檢查系統資源"""
    import psutil
    
    # 檢查記憶體
    mem = psutil.virtual_memory()
    available_memory = mem.available / (1024 * 1024 * 1024)  # GB
    logger.info(f"可用記憶體: {available_memory:.2f}GB")
    if available_memory < 4:
        raise ResourceWarning("可用記憶體不足 4GB")
    
    # 檢查CPU
    cpu_percent = psutil.cpu_percent(interval=1)
    logger.info(f"CPU使用率: {cpu_percent}%")
    if cpu_percent > 90:
        raise ResourceWarning("CPU使用率過高")
    
    # 檢查硬碟空間
    disk = psutil.disk_usage('/')
    available_space = disk.free / (1024 * 1024 * 1024)  # GB
    logger.info(f"可用硬碟空間: {available_space:.2f}GB")
    if available_space < 10:
        raise ResourceWarning("可用硬碟空間不足 10GB")

def run_with_profiling(func):
    """性能分析裝飾器"""
    import cProfile
    import pstats
    
    def wrapper(*args, **kwargs):
        profiler = cProfile.Profile()
        try:
            return profiler.runcall(func, *args, **kwargs)
        finally:
            stats = pstats.Stats(profiler)
            stats.sort_stats('cumulative')
            stats.dump_stats('profile_stats.prof')
    return wrapper

def cleanup():
    """清理資源"""
    import gc
    
    # 強制垃圾回收
    gc.collect()
    
    # 清理暫存檔案
    temp_files = Path('.').glob('*.tmp')
    for file in temp_files:
        try:
            file.unlink()
        except Exception:
            pass
    
    # 清理舊的分析檔案
    profile_files = Path('.').glob('*.prof')
    for file in profile_files:
        if (datetime.now() - datetime.fromtimestamp(file.stat().st_mtime)).days > 7:
            try:
                file.unlink()
            except Exception:
                pass

if __name__ == "__main__":
    start_time = time.time()
    logger = None
    success = False
    
    try:
        # 初始化系統
        config, logger = initialize_system()
        
        # 設置性能監控
        import psutil
        process = psutil.Process()
        initial_memory = process.memory_info().rss / 1024 / 1024  # MB
        
        # 驗證配置
        is_valid, errors = config.validate()
        if not is_valid:
            for error in errors:
                logger.error(f"配置錯誤: {error}")
            sys.exit(1)
        
        logger.info(f"""
        === 特徵生成程序開始 ===
        時間: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}
        初始記憶體使用: {initial_memory:.2f}MB
        Python版本: {sys.version}
        """)
        
        # 執行主程序
        with ThreadPoolExecutor() as executor:
            future = executor.submit(run_with_profiling(main))
            result = future.result(timeout=3600)  # 1小時超時
            
            if not result:
                raise RuntimeError("主程序執行失敗")
        
        # 執行測試
        logger.info("開始執行測試")
        test_start_time = time.time()
        
        tester = FeatureGeneratorTester()
        test_result = tester.run_tests()
        
        test_time = time.time() - test_start_time
        if test_result:
            logger.info(f"測試完成，耗時: {test_time:.2f}秒")
            success = True
        else:
            logger.error("測試失敗")
        
        # 資源使用報告
        final_memory = process.memory_info().rss / 1024 / 1024
        memory_change = final_memory - initial_memory
        
        logger.info(f"""
        === 執行統計 ===
        總執行時間: {time.time() - start_time:.2f}秒
        記憶體變化: {memory_change:+.2f}MB
        最終記憶體使用: {final_memory:.2f}MB
        CPU使用率: {process.cpu_percent()}%
        測試結果: {"成功" if success else "失敗"}
        """)
        
    except TimeoutError:
        if logger:
            logger.error("程序執行超時")
        sys.exit(2)
        
    except ResourceWarning as rw:
        if logger:
            logger.error(f"資源不足: {str(rw)}")
        sys.exit(3)
        
    except Exception as e:
        if logger:
            logger.error(f"程序執行出錯: {str(e)}")
            logger.error(traceback.format_exc())
        else:
            print(f"嚴重錯誤: {str(e)}")
        sys.exit(1)
        
    finally:
        try:
            # 清理資源
            cleanup()
            
            if logger:
                logger.info("""
                === 程序執行結束 ===
                清理完成
                結束時間: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}
                """)
                
        except Exception as cleanup_error:
            if logger:
                logger.error(f"清理過程出錯: {str(cleanup_error)}")
                
        # 使用不同的退出碼表示不同的結束狀態
        sys.exit(0 if success else 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 79
#      76                 pass
#      78 if __name__ == "__main__":
# ---> 79     start_time = time.time()
#      80     logger = None
#      81     success = False
#
# NameError: name 'time' is not defined

# %%
if __name__ == "__main__":
    # 設置日誌
    logging.basicConfig(
        level=logging.INFO,
        format='%(asctime)s - %(levelname)s - %(message)s'
    )
    
    # 運行測試
    tester = FeatureGeneratorTester()
    if tester.run_tests():
        logging.info("特徵生成器測試完成")
    else:
        logging.error("特徵生成器測試失敗")
