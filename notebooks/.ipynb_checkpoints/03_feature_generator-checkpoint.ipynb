# %%
# !pip install C:\Users\archi\Downloads\TA_Lib-0.4.28-cp310-cp310-win_amd64.whl

# %%
# 系統和路徑相關
import os
import sys
import warnings
import gc
from pathlib import Path

# 設置專案路徑
project_path = r'C:\Users\archi\Python\Project\tw_stock_analysis'
sys.path.append(project_path)

# 日期和時間
import time
from datetime import datetime

# 數據處理和分析
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
import talib

# 並行處理
from concurrent.futures import ThreadPoolExecutor, as_completed

# 類型提示
from typing import Dict, List, Tuple, Optional, Any

# 數據類
from dataclasses import dataclass, field

# 工具函數
import logging
import traceback
import shutil
from tqdm import tqdm

# 專案特定導入
from utils.config_utils import ConfigLoader, config_to_yaml
import concurrent.futures

# 關閉警告（如果需要）
warnings.filterwarnings('ignore')

# %%
@dataclass
class FeatureConfig:
    """台股特徵生成配置類"""
    
    # 基礎路徑設定
    BASE_DIR: str = "D:/Min/Python/Project/FA_Data"
    META_DATA_DIR: str = "meta_data"
    BACKUP_DIR: str = "backup"
    LOG_DIR: str = "logs"
    FEATURES_DIR: str = "features"
    
    # 資料處理參數
    DATA_PROCESSING: Dict = field(default_factory=lambda: {
        'min_data_points': 30,
        'backup_days': 7,
        'batch_size': 1000
    })
    
    # 特徵配置
    FEATURE_PARAMS: Dict = field(default_factory=lambda: {
        'volume': {
            'short_period': 5,
            'long_period': 20
        },
        'volatility': {
            'short_period': 5,
            'long_period': 20
        },
        'trend': {
            'ma_period': 20,
            'channel_period': 20
        }
    })
    
    # 日誌設定
    LOGGING: Dict = field(default_factory=lambda: {
        'file_level': 'DEBUG',
        'console_level': 'INFO',
        'format': '%(asctime)s - %(name)s - %(levelname)s - %(message)s',
        'file_encoding': 'utf-8'
    })
    
    def __post_init__(self):
        """初始化後設定路徑"""
        # 設定基礎路徑
        self.base_path = Path(self.BASE_DIR)
        
        # 設定各個子目錄路徑
        self.meta_data_path = self.base_path / self.META_DATA_DIR
        self.backup_path = self.meta_data_path / self.BACKUP_DIR
        self.log_path = self.base_path / self.LOG_DIR
        self.features_path = self.base_path / self.FEATURES_DIR
        
        # 確保所需目錄存在
        self._ensure_directories()
        
    def _ensure_directories(self):
        """確保必要的目錄結構存在"""
        directories = [
            self.base_path,
            self.meta_data_path,
            self.backup_path,
            self.log_path,
            self.features_path
        ]
        for directory in directories:
            directory.mkdir(parents=True, exist_ok=True)
    
    def get_stock_data_path(self) -> Path:
        """獲取股票數據文件路徑"""
        return self.meta_data_path / 'stock_data_whole.csv'
    
    def get_technical_path(self) -> Path:
        """獲取技術指標文件路徑"""
        return self.meta_data_path / 'all_stocks_data.csv'
    
    def get_enhanced_features_path(self) -> Path:
        """獲取增強特徵文件路徑"""
        return self.meta_data_path / 'enhanced_features.csv'
    
    def get_log_path(self) -> Path:
        """獲取日誌文件路徑"""
        return self.log_path / f"feature_generator_{datetime.now().strftime('%Y%m%d')}.log"
    
    def get_backup_path(self, filename: str) -> Path:
        """獲取備份文件路徑"""
        timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
        return self.backup_path / f"{filename}_{timestamp}"

# %%
class FeatureLogger:
    """特徵生成日誌處理類"""
    
    def __init__(self, config: FeatureConfig):
        """初始化日誌處理器
        
        Args:
            config: FeatureConfig實例
        """
        self.config = config
        self.logger = self._setup_logger()
        
    def _setup_logger(self) -> logging.Logger:
        """設置日誌系統"""
        logger = logging.getLogger('FeatureGenerator')
        logger.setLevel(logging.INFO)
        
        # 清除現有的處理器
        logger.handlers.clear()
        
        # 設定日誌格式
        formatter = logging.Formatter(
            '%(asctime)s - %(name)s - %(levelname)s - %(message)s'
        )
        
        # 檔案處理器
        log_file = self.config.log_path / f"feature_generator_{datetime.now().strftime('%Y%m%d')}.log"
        file_handler = logging.FileHandler(log_file, encoding='utf-8')
        file_handler.setFormatter(formatter)
        file_handler.setLevel(logging.DEBUG)
        
        # 控制台處理器
        console_handler = logging.StreamHandler()
        console_handler.setFormatter(formatter)
        console_handler.setLevel(logging.INFO)
        
        logger.addHandler(file_handler)
        logger.addHandler(console_handler)
        
        return logger
    
    def info(self, msg: str):
        """記錄信息級別日誌"""
        self.logger.info(msg)
        
    def warning(self, msg: str):
        """記錄警告級別日誌"""
        self.logger.warning(msg)
        
    def error(self, msg: str):
        """記錄錯誤級別日誌"""
        self.logger.error(msg)
        
    def debug(self, msg: str):
        """記錄調試級別日誌"""
        self.logger.debug(msg)
        
    def critical(self, msg: str):
        """記錄嚴重錯誤級別日誌"""
        self.logger.critical(msg)

# %%
class FeatureGenerator:
    """特徵生成器 - 專注於生成額外的量能、波動和趨勢特徵"""
    
    def __init__(self, config: FeatureConfig):
        self.config = config
        self.logger = logging.getLogger(__name__)

    def _preprocess_data(self, df: pd.DataFrame) -> pd.DataFrame:
        """數據預處理，處理數據類型和清理異常值"""
        try:
            df = df.copy()
            
            # 確保證券代號為字串類型
            df['證券代號'] = df['證券代號'].astype(str)
            
            # 處理日期格式
            df['日期'] = pd.to_datetime(df['日期']).dt.strftime('%Y-%m-%d')
            
            # 處理價格欄位
            price_columns = ['開盤價', '最高價', '最低價', '收盤價', '最後揭示買價', '最後揭示賣價']
            for col in price_columns:
                if col in df.columns:
                    df[col] = df[col].replace('--', np.nan)
                    df[col] = df[col].apply(lambda x: str(x).replace(',', '') if isinstance(x, str) else x)
                    df[col] = pd.to_numeric(df[col], errors='coerce')
            
            # 處理成交量相關欄位
            volume_columns = ['成交股數', '成交筆數', '成交金額']
            for col in volume_columns:
                if col in df.columns:
                    df[col] = df[col].replace('--', np.nan)
                    df[col] = df[col].apply(lambda x: str(x).replace(',', '') if isinstance(x, str) else x)
                    df[col] = pd.to_numeric(df[col], errors='coerce')
            
            return df
            
        except Exception as e:
            self.logger.error(f"數據預處理失敗: {str(e)}")
            return None
    
    def generate_features(self, df: pd.DataFrame, stock_id: str) -> pd.DataFrame:
        """生成新的特徵並與現有技術指標合併"""
        try:
            if df.empty:
                self.logger.warning(f"股票 {stock_id} 數據為空")
                return None
            
            # 預處理數據
            df = self._preprocess_data(df)
            if df is None:
                return None
                
            # 驗證數據完整性
            required_columns = ['開盤價', '最高價', '最低價', '收盤價', '成交股數']
            if not all(col in df.columns for col in required_columns):
                self.logger.warning(f"股票 {stock_id} 缺少必要欄位")
                return None
                
            if df[required_columns].isnull().all().any():
                self.logger.warning(f"股票 {stock_id} 數據存在全空欄位")
                return None
    
            # 讀取技術指標
            tech_file = Path(f"D:/Min/Python/Project/FA_Data/technical_analysis/{stock_id}_indicators.csv")
            if not tech_file.exists():
                self.logger.warning(f"找不到股票 {stock_id} 的技術指標文件")
                return None
    
            try:
                tech_df = pd.read_csv(tech_file, dtype={'證券代號': str})
                tech_df['日期'] = pd.to_datetime(tech_df['日期']).dt.strftime('%Y-%m-%d')
            except Exception as e:
                self.logger.error(f"讀取技術指標文件時發生錯誤: {str(e)}")
                return None
    
            # 依序添加新特徵
            df = self._add_volume_features(df)
            df = self._add_volatility_features(df)
            df = self._add_trend_features(df)
    
            # 合併技術指標數據 - 使用精確的合併條件
            df = pd.merge(
                df, 
                tech_df,
                on=['證券代號', '日期'],
                how='left',
                validate='1:1'  # 確保一對一合併
            )
    
            # 最後的數據驗證
            if df.empty:
                self.logger.warning(f"股票 {stock_id} 合併後數據為空")
                return None
    
            # 檢查關鍵特徵是否生成
            expected_features = ['量比', '量增率', '量能趨勢', '日內波動率', '振幅', '趨勢強度']
            missing_features = [feat for feat in expected_features if feat not in df.columns]
            if missing_features:
                self.logger.warning(f"股票 {stock_id} 缺少以下特徵: {', '.join(missing_features)}")
    
            # 清理可能的無限值
            df = df.replace([np.inf, -np.inf], np.nan)
    
            # 排序並重設索引
            df = df.sort_values('日期').reset_index(drop=True)
    
            return df
    
        except Exception as e:
            self.logger.error(f"處理股票 {stock_id} 時發生錯誤: {str(e)}")
            self.logger.error(traceback.format_exc())  # 添加堆疊追蹤
            return None
    
    def _load_technical_data(self, stock_id: str) -> pd.DataFrame:
        """載入技術指標數據"""
        try:
            tech_path = self.config.get_technical_path()
            if not tech_path.exists():
                return None
            
            tech_df = pd.read_csv(tech_path)
            return tech_df[tech_df['證券代號'] == stock_id]
            
        except Exception as e:
            self.logger.error(f"載入技術指標數據時發生錯誤: {str(e)}")
            return None
    
    def _add_volume_features(self, df: pd.DataFrame) -> pd.DataFrame:
        """添加量能特徵"""
        try:
            # 確保數據已經過預處理
            if df['成交股數'].dtype == object:
                self.logger.warning("成交量數據類型不正確，跳過量能特徵計算")
                return df
                
            params = self.config.FEATURE_PARAMS['volume']
            short_period = params['short_period']
            long_period = params['long_period']
            
            # 使用rolling前先確保沒有無限值
            df['成交股數'] = df['成交股數'].replace([np.inf, -np.inf], np.nan)
            
            # 計算量比 (當日成交量/20日平均成交量)
            df['量比'] = df['成交股數'] / df['成交股數'].rolling(long_period).mean()
            
            # 計算量增率 (當日成交量相對前一日變化率)
            df['量增率'] = df['成交股數'].pct_change()
            
            # 計算量能趨勢 (短期平均量/長期平均量)
            short_ma = df['成交股數'].rolling(short_period).mean()
            long_ma = df['成交股數'].rolling(long_period).mean()
            df['量能趨勢'] = short_ma / long_ma
            
            return df
            
        except Exception as e:
            self.logger.error(f"計算量能特徵時發生錯誤: {str(e)}")
            return df
    
    def _add_volatility_features(self, df: pd.DataFrame) -> pd.DataFrame:
        """添加波動特徵"""
        try:
            params = self.config.FEATURE_PARAMS['volatility']
            short_period = params['short_period']
            long_period = params['long_period']
            
            # 計算日內波動率
            df['日內波動率'] = (df['最高價'] - df['最低價']) / df['開盤價']
            
            # 計算價格振幅
            df['振幅'] = (df['最高價'] - df['最低價']) / df['收盤價'].shift(1)
            
            # 計算漲跌幅
            df['漲跌幅'] = df['收盤價'].pct_change()
            
            # 計算波動率趨勢 (短期波動率/長期波動率)
            short_vol = df['收盤價'].rolling(short_period).std()
            long_vol = df['收盤價'].rolling(long_period).std()
            df['波動率趨勢'] = short_vol / long_vol
            
            return df
            
        except Exception as e:
            self.logger.error(f"計算波動特徵時發生錯誤: {str(e)}")
            return df
    
    def _add_trend_features(self, df: pd.DataFrame) -> pd.DataFrame:
        """添加趨勢特徵"""
        try:
            params = self.config.FEATURE_PARAMS['trend']
            ma_period = params['ma_period']
            
            # 計算趨勢強度 (收盤價相對於移動平均的偏離程度)
            ma = df['收盤價'].rolling(ma_period).mean()
            df['趨勢強度'] = (df['收盤價'] - ma) / ma
            
            # 布林通道寬度變化（如果有布林通道數據）
            if all(col in df.columns for col in ['upperband', 'lowerband', 'middleband']):
                df['通道寬度變化'] = (df['upperband'] - df['lowerband']) / df['middleband']
                df['通道寬度變化'] = df['通道寬度變化'].pct_change()
            
            return df
            
        except Exception as e:
            self.logger.error(f"計算趨勢特徵時發生錯誤: {str(e)}")
            return df

# %%
def main():
    """主程序"""
    try:
        # 初始化配置與日誌
        config = FeatureConfig()
        logger = FeatureLogger(config)
        logger.info("開始執行特徵生成主程序")
        
        # 執行特徵生成
        success = process_all_stocks(config)
        
        return success
        
    except Exception as e:
        logging.error(f"主程序執行錯誤: {str(e)}")
        return False

def process_all_stocks(config: FeatureConfig, date_range: Optional[Tuple[str, str]] = None) -> bool:
    """主要處理函數"""
    logger = logging.getLogger(__name__)
    
    try:
        logger.info("開始處理股票特徵生成")
        
        # 讀取股票數據
        df = pd.read_csv(config.get_stock_data_path(), 
                        dtype={'證券代號': str},
                        parse_dates=['日期'])
        
        # 基本數據清理
        df = df.drop_duplicates(subset=['證券代號', '日期'], keep='last')
        df = df.sort_values(['證券代號', '日期'])
        
        # 過濾日期範圍
        if date_range:
            start_date, end_date = date_range
            df = df[(df['日期'] >= start_date) & (df['日期'] <= end_date)]
        
        # 初始化特徵生成器
        generator = FeatureGenerator(config)
        
        # 分組處理每支股票
        results = []
        unique_stocks = sorted(df['證券代號'].unique())
        
        with tqdm(unique_stocks, desc="特徵生成進度") as pbar:
            for stock_id in pbar:
                stock_df = df[df['證券代號'] == stock_id].copy()
                result_df = generator.generate_features(stock_df, stock_id)
                
                if result_df is not None:
                    results.append(result_df)
                pbar.set_postfix({'處理': f"{len(results)}/{len(unique_stocks)}"})
        
        # 合併結果並保存
        if results:
            final_df = pd.concat(results, ignore_index=True)
            output_file = config.get_enhanced_features_path()
            final_df.to_csv(output_file, index=False, encoding='utf-8-sig')
            
            # 生成報告
            generate_report(final_df, len(unique_stocks), len(results), config)
            logger.info(f"特徵生成完成，處理成功率: {(len(results)/len(unique_stocks))*100:.2f}%")
            return True
        
        logger.error("沒有成功處理的數據")
        return False
        
    except Exception as e:
        logger.error(f"特徵生成過程發生錯誤: {str(e)}")
        return False


def generate_report(df: pd.DataFrame, total_stocks: int, processed_stocks: int, config: FeatureConfig):
    """生成處理報告"""
    logger = logging.getLogger(__name__)
    
    try:
        report_path = config.meta_data_path / 'feature_generation_report.txt'
        
        with open(report_path, 'w', encoding='utf-8') as f:
            # 基本資訊
            f.write("特徵生成處理報告\n")
            f.write(f"生成時間: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n\n")
            
            # 處理統計
            f.write(f"總股票數: {total_stocks}\n")
            f.write(f"成功處理: {processed_stocks}\n")
            f.write(f"處理比率: {(processed_stocks/total_stocks)*100:.2f}%\n\n")
            
            # 特徵統計
            f.write(f"特徵數量: {len(df.columns)}\n")
            f.write("\n特徵列表:\n")
            
            # 分類特徵列表
            feature_categories = {
                "基本資料": ['證券代號', '證券名稱', '日期', '開盤價', '最高價', '最低價', '收盤價', '成交股數'],
                "量能特徵": ['量比', '量增率', '量能趨勢', '量能波動', '量價背離'],
                "波動特徵": ['日內波動率', '振幅', '漲跌幅', '波動率趨勢'],
                "趨勢特徵": ['趨勢強度', '通道寬度變化']
            }
            
            for category, features in feature_categories.items():
                f.write(f"\n{category}:\n")
                present_features = [feat for feat in features if feat in df.columns]
                for feature in present_features:
                    f.write(f"  - {feature}\n")
            
            # 數據範圍資訊
            f.write(f"\n數據時間範圍: {df['日期'].min()} 到 {df['日期'].max()}\n")
            
        logger.info(f"處理報告已保存至: {report_path}")
        
    except Exception as e:
        logger.error(f"生成報告時發生錯誤: {str(e)}")

# %%
if __name__ == "__main__":
    # 設置日誌
    logging.basicConfig(
        level=logging.INFO,
        format='%(asctime)s - %(levelname)s - %(message)s'
    )
    
    # 執行主程序
    if main():
        logging.info("特徵生成完成")
    else:
        logging.error("特徵生成失敗")
# Out:
# 2024-11-04 15:26:04,765 - FeatureGenerator - INFO - 開始執行特徵生成主程序
# 2024-11-04 15:26:04,765 - INFO - 開始執行特徵生成主程序
# 2024-11-04 15:26:04,767 - INFO - 開始處理股票特徵生成
# 特徵生成進度:  95%|█████████████████████████████████████████████▋  | 1093/1148 [04:59<00:16,  3.42it/s, 處理=1093/1148]s]2024-11-04 15:31:21,495 - WARNING - 股票 911201 數據存在全空欄位
# 特徵生成進度: 100%|████████████████████████████████████████████████| 1148/1148 [05:14<00:00,  3.65it/s, 處理=1147/1148]
# 2024-11-04 15:33:40,573 - INFO - 處理報告已保存至: D:\Min\Python\Project\FA_Data\meta_data\feature_generation_report.txt
# 2024-11-04 15:33:40,575 - INFO - 特徵生成完成，處理成功率: 99.91%
# 2024-11-04 15:33:40,997 - INFO - 特徵生成完成
