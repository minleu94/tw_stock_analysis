# %%
# !pip install C:\Users\archi\Downloads\TA_Lib-0.4.28-cp310-cp310-win_amd64.whl

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import logging
import talib
from typing import Dict, List, Tuple, Optional
from dataclasses import dataclass, field
from pathlib import Path
from datetime import datetime
import os
import shutil
from tqdm import tqdm

# %%
@dataclass
class FeatureConfig:
    """特徵設定類別"""
    # 基礎目錄設定
    BASE_DIR: str = "D:/Min/Python/Project/FA_Data"
    META_DATA_DIR: str = "meta_data"
    BACKUP_DIR: str = "backup"
    LOG_DIR: str = "logs"
    
    # 資料處理參數
    DATA_PROCESSING: Dict = field(default_factory=lambda: {
        'min_data_points': 30,
        'backup_days': 7,
        'missing_threshold': 0.1,
        'correlation_threshold': 0.95,
        'min_date_range': 30
    })
    
    # 添加缺失的 TECHNICAL_FEATURES 配置
    TECHNICAL_FEATURES: Dict = field(default_factory=lambda: {
        'trend': ['SMA30', 'DEMA30', 'EMA30', 'TSF'],
        'momentum': ['RSI', 'MACD', 'MACD_signal', 'MACD_hist'],
        'volatility': ['slowk', 'slowd', 'upperband', 'lowerband', 'middleband', 'SAR'],
        'volume': ['量比', '量增率', '量能趨勢'],
        'price': ['振幅', '漲跌幅', '相對強弱']
    })
    
    # 技術指標參數
    TECH_PARAMS: Dict = field(default_factory=lambda: {
        'SMA': {'timeperiod': 30},
        'RSI': {'timeperiod': 14},
        'MACD': {'fastperiod': 12, 'slowperiod': 26, 'signalperiod': 9},
        'STOCH': {'fastk_period': 5, 'slowk_period': 3, 'slowd_period': 3},
        'BBANDS': {'timeperiod': 30, 'nbdevup': 2, 'nbdevdn': 2},
        'SAR': {'acceleration': 0.02, 'maximum': 0.2}
    })
    
    # 資料品質參數
    DATA_QUALITY: Dict = field(default_factory=lambda: {
        'min_price': 1.0,
        'min_volume': 1000,
        'max_missing_ratio': 0.1,
        'outlier_std_threshold': 3.0,
        'correlation_threshold': 0.95,
        'min_data_points': 30
    })
    
    # 特徵優先級設定
    FEATURE_PRIORITY: Dict[str, int] = field(default_factory=lambda: {
        '收盤價': 1,
        'RSI': 2,
        'MACD': 3,
        'KD_差值': 4,
        'SMA30': 5,
        'DEMA30': 6,
        'EMA30': 7,
        '波動率': 8,
        '趨勢強度': 9,
        '量能趨勢': 10
    })
    
    def get_base_path(self) -> Path:
        """取得基礎路徑"""
        return Path(self.BASE_DIR)
    
    def get_meta_path(self) -> Path:
        """取得元數據路徑"""
        return self.get_base_path() / self.META_DATA_DIR
    
    def get_backup_path(self) -> Path:
        """取得備份路徑"""
        return self.get_meta_path() / self.BACKUP_DIR
    
    def validate_paths(self):
        """驗證並建立必要的目錄"""
        paths = [
            self.get_base_path(),
            self.get_meta_path(),
            self.get_backup_path()
        ]
        for path in paths:
            path.mkdir(parents=True, exist_ok=True)
            
    def get_feature_priority(self, feature_name: str) -> int:
        """取得特徵優先級"""
        return self.FEATURE_PRIORITY.get(feature_name, 100)

# %%
class DataLoader:
    """數據加載類"""
    def __init__(self):
        self.base_dir = Path("D:/Min/Python/Project/FA_Data")
        self.meta_data_dir = self.base_dir / "meta_data"
        
    def load_stock_data(self, stock_id: str, start_date: str, end_date: str) -> pd.DataFrame:
        """加載個股數據"""
        try:
            logging.info(f"正在讀取數據文件: {self.meta_data_dir}/all_stocks_data.csv")
            df = pd.read_csv(self.meta_data_dir / "all_stocks_data.csv", low_memory=False)
            
            # 過濾指定股票
            df = df[df['證券代號'] == stock_id]
            logging.info(f"過濾後的數據形狀 (股票 {stock_id}): {df.shape}")
            
            # 日期過濾
            df = df[(df['日期'] >= start_date) & (df['日期'] <= end_date)]
            logging.info(f"日期過濾後的數據形狀: {df.shape}")
            
            # 基本統計信息
            self._print_stock_summary(df, stock_id)
            
            return df
            
        except Exception as e:
            logging.error(f"加載股票數據時出錯: {str(e)}")
            raise

    def load_market_data(self, start_date: str, end_date: str) -> pd.DataFrame:
        """加載大盤數據"""
        try:
            df = pd.read_csv(self.meta_data_dir / "market_index.csv")
            return df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]
        except Exception as e:
            logging.error(f"加載大盤數據時出錯: {str(e)}")
            raise

    def load_industry_data(self, start_date: str, end_date: str) -> pd.DataFrame:
        """加載產業數據"""
        try:
            df = pd.read_csv(self.meta_data_dir / "industry_index.csv")
            return df[(df['日期'] >= start_date) & (df['日期'] <= end_date)]
        except Exception as e:
            logging.error(f"加載產業數據時出錯: {str(e)}")
            raise

    def _print_stock_summary(self, df: pd.DataFrame, stock_id: str):
        """打印股票數據摘要"""
        print(f"\n=== 股票數據摘要 ===")
        print(f"股票代碼: {stock_id}")
        print(f"股票名稱: {df['證券名稱'].iloc[0]}")
        print(f"數據期間: {df['日期'].min()} 到 {df['日期'].max()}")
        print(f"交易天數: {len(df)} 天\n")

        print("--- 價格統計 ---")
        print(f"平均收盤價: {df['收盤價'].mean():.2f}")
        print(f"最高價: {df['最高價'].max():.2f}")
        print(f"最低價: {df['最低價'].min():.2f}")
        print(f"價格波動範圍: {df['最高價'].max() - df['最低價'].min():.2f}")
        print(f"標準差: {df['收盤價'].std():.2f}\n")

        print("--- 交易統計 ---")
        print(f"平均日成交量: {df['成交股數'].mean():,.2f}")
        print(f"平均日成交筆數: {df['成交筆數'].mean():.2f}")
        print(f"平均日成交金額: {df['成交金額'].mean():,.2f}\n")

# %%
class DataQualityChecker:
    """數據品質檢查器"""
    def __init__(self, config: FeatureConfig):
        self.config = config
        self.quality_report = {}
        
    def check_data_quality(self, df: pd.DataFrame) -> Tuple[pd.DataFrame, dict]:
        """執行完整的數據品質檢查"""
        try:
            # 1. 基本數據驗證
            self._validate_basic_data(df)
            
            # 2. 處理缺失值
            df = self._handle_missing_values(df)
            
            # 3. 檢測異常值
            df = self._handle_outliers(df)
            
            # 4. 檢查數據連續性
            self._check_data_continuity(df)
            
            # 5. 特徵相關性分析
            self._analyze_feature_correlation(df)
            
            return df, self.quality_report
            
        except Exception as e:
            logging.error(f"數據品質檢查失敗: {str(e)}")
            raise
            
    def _validate_basic_data(self, df: pd.DataFrame):
        """基本數據驗證"""
        # 檢查必要欄位
        required_columns = ['收盤價', '開盤價', '最高價', '最低價', '成交股數', '本益比']
        missing_cols = [col for col in required_columns if col not in df.columns]
        if missing_cols:
            raise ValueError(f"缺少必要欄位: {missing_cols}")
            
        # 檢查數據類型
        for col in required_columns:
            if not pd.api.types.is_numeric_dtype(df[col]):
                raise ValueError(f"欄位 {col} 不是數值類型")
                
        # 檢查基本限制
        if len(df) < self.config.DATA_PROCESSING['min_data_points']:
            raise ValueError(f"數據量不足: {len(df)} < {self.config.DATA_PROCESSING['min_data_points']}")
            
        self.quality_report['basic_validation'] = 'Pass'
        
    def _handle_missing_values(self, df: pd.DataFrame) -> pd.DataFrame:
        """處理缺失值"""
        # 價格類使用前向填充
        price_cols = ['開盤價', '最高價', '最低價', '收盤價']
        df[price_cols] = df[price_cols].ffill()
        
        # 技術指標使用插值
        tech_cols = [col for col in df.select_dtypes(include=[np.number]).columns 
                    if col not in price_cols]
        df[tech_cols] = df[tech_cols].interpolate(method='linear')
        
        # 其他欄位使用前向後向填充
        df = df.ffill().bfill()
        
        return df
        
    def _handle_outliers(self, df: pd.DataFrame) -> pd.DataFrame:
        """處理異常值"""
        numeric_cols = df.select_dtypes(include=[np.number]).columns
        outliers_info = {}
        
        for col in numeric_cols:
            # 確保數據類型一致性
            series = df[col].astype(float)
            
            # 計算Z-score
            z_scores = np.abs((series - series.mean()) / series.std())
            outliers = z_scores > self.config.DATA_QUALITY['outlier_std']
            
            if outliers.any():
                outliers_info[col] = {
                    'count': outliers.sum(),
                    'indices': outliers[outliers].index.tolist(),
                    'values': series[outliers].tolist()
                }
                
                # 使用winsorization並保持數據類型
                lower = series.quantile(0.01)
                upper = series.quantile(0.99)
                df.loc[outliers, col] = series[outliers].clip(lower=lower, upper=upper)
        
        return df, outliers_info
        
    def _check_data_continuity(self, df: pd.DataFrame):
        """檢查數據連續性"""
        df['日期'] = pd.to_datetime(df['日期'])
        
        # 生成預期的交易日期範圍
        trading_days = pd.date_range(
            start=df['日期'].min(),
            end=df['日期'].max(),
            freq='B'  # 使用營業日頻率
        )
        
        # 檢查缺失的交易日
        missing_days = trading_days[~trading_days.isin(df['日期'])]
        
        # 計算實際間隔
        date_gaps = df['日期'].diff().dt.days
        
        # 過濾掉週末的間隔
        business_gaps = date_gaps[date_gaps > 3]  # 超過3天才算異常間隔
        
        if not business_gaps.empty:
            logging.warning(f"發現工作日數據間隔過大: {business_gaps.to_dict()}")
        
        return {
            'missing_days': missing_days.tolist(),
            'max_business_gap': business_gaps.max() if not business_gaps.empty else 0,
            'mean_gap': date_gaps.mean()
        }
        
    def _analyze_feature_correlation(self, df: pd.DataFrame):
        """分析特徵相關性"""
        numeric_cols = df.select_dtypes(include=[np.number]).columns
        corr_matrix = df[numeric_cols].corr()
        
        # 找出高度相關的特徵對
        high_correlation = []
        for i in range(len(numeric_cols)):
            for j in range(i+1, len(numeric_cols)):
                corr = corr_matrix.iloc[i, j]
                if abs(corr) > self.config.DATA_QUALITY['correlation_threshold']:
                    high_correlation.append({
                        'feature1': numeric_cols[i],
                        'feature2': numeric_cols[j],
                        'correlation': corr
                    })
                    
        self.quality_report['correlation'] = {
            'high_correlation_pairs': high_correlation,
            'correlation_matrix': corr_matrix.to_dict()
        }

# %%
class EnhancedFeatureGenerator:
    """特徵生成器"""
    def __init__(self, config: Optional[FeatureConfig] = None):
        self.config = config or FeatureConfig()
        self.scaler = StandardScaler()
        self.base_dir = Path(self.config.BASE_DIR)
        self.meta_dir = self.base_dir / self.config.META_DATA_DIR
        self.backup_dir = self.meta_dir / self.config.BACKUP_DIR
        self.log_dir = self.base_dir / self.config.LOG_DIR
        
        # 設置logger
        self.logger = logging.getLogger(__name__)
        self._setup_directories()
        
    def _setup_directories(self):
        """初始化目錄"""
        try:
            for d in [self.base_dir, self.meta_dir, self.backup_dir, self.log_dir]:
                d.mkdir(parents=True, exist_ok=True)
            self.logger.info(f"目錄結構已初始化: {self.meta_dir}")
        except Exception as e:
            self.logger.error(f"創建目錄時出錯: {str(e)}")
            raise

    def _setup_logging(self):
        """設置日誌"""
        log_file = self.log_dir / f"feature_generator_{datetime.now().strftime('%Y%m%d')}.log"
        formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
        
        file_handler = logging.FileHandler(log_file, encoding='utf-8')
        file_handler.setFormatter(formatter)
        
        console_handler = logging.StreamHandler()
        console_handler.setFormatter(formatter)
        
        self.logger = logging.getLogger('FeatureGenerator')
        self.logger.setLevel(logging.INFO)
        self.logger.addHandler(file_handler)
        self.logger.addHandler(console_handler)

    
    def _add_technical_indicators(self, df: pd.DataFrame) -> pd.DataFrame:
        """添加技術指標"""
        try:
            self.logger.info("計算技術指標...")
            
            close_prices = df['收盤價'].values
            high_prices = df['最高價'].values
            low_prices = df['最低價'].values
            
            # Trend指標
            df['SMA30'] = talib.SMA(close_prices, timeperiod=30)
            df['DEMA30'] = talib.DEMA(close_prices, timeperiod=30)
            df['EMA30'] = talib.EMA(close_prices, timeperiod=30)
            df['TSF'] = talib.TSF(close_prices, timeperiod=14)
            
            # Momentum指標
            df['RSI'] = talib.RSI(close_prices, timeperiod=14)
            df['MACD'], df['MACD_signal'], df['MACD_hist'] = talib.MACD(
                close_prices,
                fastperiod=12,
                slowperiod=26,
                signalperiod=9
            )
            
            # Volatility指標
            df['slowk'], df['slowd'] = talib.STOCH(
                high_prices,
                low_prices,
                close_prices,
                fastk_period=5,
                slowk_period=3,
                slowd_period=3
            )
            df['upperband'], df['middleband'], df['lowerband'] = talib.BBANDS(
                close_prices,
                timeperiod=30
            )
            df['SAR'] = talib.SAR(
                high_prices,
                low_prices,
                acceleration=0.02,
                maximum=0.2
            )
            
            return df
            
        except Exception as e:
            self.logger.error(f"計算技術指標時發生錯誤: {str(e)}")
            raise

    def _add_price_features(self, df: pd.DataFrame) -> pd.DataFrame:
        """添加價格特徵"""
        try:
            self.logger.info("計算價格特徵...")
            
            # 基本價格特徵
            df['振幅'] = (df['最高價'] - df['最低價']) / df['收盤價']
            df['漲跌幅'] = df['收盤價'].pct_change()
            df['相對強弱'] = df['收盤價'] / df['SMA30']
            
            # 價格趨勢特徵
            df['價格趨勢'] = np.where(df['收盤價'] > df['收盤價'].shift(1), 1, -1)
            df['連續上漲'] = (df['價格趨勢'] > 0).astype(int).rolling(window=5).sum()
            df['連續下跌'] = (df['價格趨勢'] < 0).astype(int).rolling(window=5).sum()
            
            return df
            
        except Exception as e:
            self.logger.error(f"計算價格特徵時發生錯誤: {str(e)}")
            raise

    def _add_volume_features(self, df: pd.DataFrame) -> pd.DataFrame:
        """添加量能特徵"""
        try:
            self.logger.info("計算量能特徵...")
            
            df['量比'] = df['成交股數'] / df['成交股數'].rolling(20).mean()
            df['量增率'] = df['成交股數'].pct_change()
            df['量能趨勢'] = df['成交股數'].rolling(window=5).mean() / df['成交股數'].rolling(window=20).mean()
            
            # 放量特徵
            df['放量程度'] = df['量比'].rolling(window=5).mean()
            df['量價背離'] = (df['漲跌幅'] > 0).astype(int) * (df['量增率'] < 0).astype(int)
            
            return df
            
        except Exception as e:
            self.logger.error(f"計算量能特徵時發生錯誤: {str(e)}")
            raise

    def _add_volatility_features(self, df: pd.DataFrame) -> pd.DataFrame:
        """添加波動特徵"""
        try:
            self.logger.info("計算波動特徵...")
            
            df['波動率'] = df['收盤價'].rolling(20).std() / df['收盤價'].rolling(20).mean()
            df['價格趨勢'] = np.where(df['收盤價'] > df['收盤價'].shift(1), 1, -1)
            
            # 額外波動特徵
            df['日內波動率'] = (df['最高價'] - df['最低價']) / df['開盤價']
            df['波動率變化'] = df['波動率'].pct_change()
            
            return df
            
        except Exception as e:
            self.logger.error(f"計算波動特徵時發生錯誤: {str(e)}")
            raise

    def _add_advanced_features(self, df: pd.DataFrame) -> pd.DataFrame:
        """添加進階技術特徵"""
        try:
            self.logger.info("計算進階特徵...")
            
            # 趨勢強度
            df['趨勢強度'] = (df['收盤價'] - df['SMA30']) / df['SMA30']
            
            # 均線糾結度
            df['均線糾結度'] = pd.DataFrame({
                'SMA30': df['SMA30'],
                'DEMA30': df['DEMA30'],
                'EMA30': df['EMA30']
            }).std(axis=1) / df['收盤價']
            
            # KD差值
            df['KD_差值'] = df['slowk'] - df['slowd']
            
            # 本益比相對值
            df['本益比_相對值'] = (df['本益比'] - df['本益比'].rolling(60).mean()) / df['本益比'].rolling(60).std()
            
            # RSI動能
            df['RSI_動能'] = df['RSI'] - df['RSI'].rolling(window=5).mean()
            
            # MACD動能
            df['MACD_動能'] = df['MACD'] - df['MACD'].rolling(window=5).mean()
            
            # 布林通道相關
            df['布林通道寬度'] = (df['upperband'] - df['lowerband']) / df['middleband']
            df['布林通道位置'] = (df['收盤價'] - df['lowerband']) / (df['upperband'] - df['lowerband'])
            
            # 技術綜合評分
            df['技術綜合評分'] = (
                (df['RSI'] - 50) / 20 +  # RSI貢獻
                df['MACD_hist'] / df['收盤價'] +  # MACD貢獻
                (df['slowk'] - 50) / 20 +  # KD貢獻
                df['趨勢強度'] * 0.5 +  # 趨勢貢獻
                (df['量比'] - 1) * 0.3  # 量能貢獻
            )
            
            return df
            
        except Exception as e:
            self.logger.error(f"計算進階特徵時發生錯誤: {str(e)}")
            raise

    def generate_features(self, df: pd.DataFrame) -> pd.DataFrame:
        """生成特徵主函數"""
        try:
            self.logger.info("開始生成特徵...")
            features_df = df.copy()
            
            features_df = self._add_technical_indicators(features_df)
            features_df = self._add_price_features(features_df)
            features_df = self._add_volume_features(features_df)
            features_df = self._add_volatility_features(features_df)
            features_df = self._add_advanced_features(features_df)
            
            features_df = self._remove_correlated_features(features_df)
            features_df = self._handle_missing_values(features_df)
            
            # 只在成功生成所有特徵後才打印摘要
            if hasattr(self.config, 'TECHNICAL_FEATURES'):
                self._print_technical_summary(features_df)
            
            return features_df
            
        except Exception as e:
            self.logger.error(f"生成特徵失敗: {str(e)}")
            raise

    def _handle_missing_values(self, df: pd.DataFrame) -> pd.DataFrame:
        """處理缺失值"""
        try:
            # 向前填充價格相關特徵
            price_cols = ['開盤價', '最高價', '最低價', '收盤價', 'SMA30', 'EMA30', 'DEMA30']
            df[price_cols] = df[price_cols].fillna(method='ffill')
            
            # 使用插值法處理技術指標
            tech_cols = ['RSI', 'MACD', 'slowk', 'slowd', 'SAR']
            df[tech_cols] = df[tech_cols].interpolate(method='linear')
            
            # 其他特徵使用前後填充
            df = df.fillna(method='ffill').fillna(method='bfill')
            
            return df
            
        except Exception as e:
            self.logger.error(f"處理缺失值時發生錯誤: {str(e)}")
            raise

    def normalize_features(self, df: pd.DataFrame, feature_columns: List[str]) -> pd.DataFrame:
        """特徵標準化"""
        try:
            df_normalized = df.copy()
            df_normalized[feature_columns] = self.scaler.fit_transform(df[feature_columns])
            return df_normalized
            
        except Exception as e:
            self.logger.error(f"特徵標準化時發生錯誤: {str(e)}")
            raise

# %%
def main():
    """主函數"""
    try:
        # 1. 初始化
        data_loader = DataLoader()
        feature_generator = EnhancedFeatureGenerator()
        
        # 2. 設置參數
        stock_id = '2330'  # 台積電
        start_date = '2023-01-01'
        end_date = '2023-12-31'
        
        # 3. 加載數據
        print(f"\n正在載入{stock_id}的數據...")
        stock_df = data_loader.load_stock_data(stock_id, start_date, end_date)
        
        # 4. 生成特徵
        print(f"\n正在處理 {stock_id} 的特徵...")
        features_df = feature_generator.generate_features(stock_df)
        
        # 5. 標準化特徵
        feature_columns = [
            '趨勢強度', '均線糾結度', '波動率', '振幅', 
            '量能趨勢', '量比', 'RSI_動能', 'MACD_動能',
            'RSI', 'MACD', 'KD_差值', '本益比_相對值', 
            '技術綜合評分'
        ]
        
        # 確認所有特徵都存在
        missing_features = [col for col in feature_columns if col not in features_df.columns]
        if missing_features:
            raise ValueError(f"缺少以下特徵: {missing_features}")
            
        normalized_df = feature_generator.normalize_features(features_df, feature_columns)
        
        # 6. 輸出結果
        print("\n=== 特徵生成完成 ===")
        print(f"特徵數量: {len(feature_columns)}")
        print(f"特徵名稱: {feature_columns}")
        print("\n特徵統計:")
        print(normalized_df[feature_columns].describe())
        
        return normalized_df
        
        # 添加數據質量報告的保存
        quality_report_file = Path('quality_reports') / f'quality_report_{datetime.now().strftime("%Y%m%d_%H%M%S")}.json'
        with open(quality_report_file, 'w', encoding='utf-8') as f:
            json.dump(feature_generator.quality_checker.quality_report, f, 
                     ensure_ascii=False, indent=2)
        
        return normalized_df, feature_generator.quality_checker.quality_report
        
    except Exception as e:
        logging.error(f"程序執行出錯: {str(e)}")
        raise

# %%
# 測試功能
def test_feature_generator():
    """測試特徵生成器"""
    logger = logging.getLogger(__name__)
    
    try:
        # 1. 設置測試參數
        test_stock_id = '2330'
        test_start_date = '2023-01-01'
        test_end_date = '2023-12-31'
        
        logger.info(f"開始測試特徵生成器 - 股票代碼: {test_stock_id}")
        
        # 2. 載入測試數據
        data_loader = DataLoader()
        stock_df = data_loader.load_stock_data(test_stock_id, test_start_date, test_end_date)
        
        # 3. 初始化特徵生成器
        generator = EnhancedFeatureGenerator()
        
        # 4. 生成特徵
        features_df = generator.generate_features(stock_df)
        
        # 5. 特徵驗證
        validate_features(features_df)
        
        # 6. 打印測試結果
        print_test_results(features_df)
        
        return True
        
    except Exception as e:
        logger.error(f"特徵生成器測試失敗: {str(e)}")
        return False

def validate_features(df: pd.DataFrame) -> bool:
    """特徵驗證"""
    try:
        # 檢查必要的特徵是否存在
        required_features = [
            'SMA30', 'DEMA30', 'EMA30', 'RSI', 'MACD',
            'slowk', 'slowd', 'SAR'
        ]
        for feature in required_features:
            if feature not in df.columns:
                raise ValueError(f"缺少必要特徵: {feature}")
        
        # 檢查數據質量
        if df.isnull().sum().sum() > 0:
            logging.warning("存在缺失值，請檢查")
            
        # 檢查數據範圍
        if df['RSI'].max() > 100 or df['RSI'].min() < 0:
            raise ValueError("RSI值超出合理範圍")
            
        return True
        
    except Exception as e:
        logging.error(f"特徵驗證失敗: {str(e)}")
        return False

def print_test_results(df: pd.DataFrame):
    """打印測試結果"""
    print("\n=== 特徵生成完成 ===")
    print(f"特徵數量: {len(df.columns)}")
    print("\n特徵列表:")
    for i, col in enumerate(df.columns, 1):
        print(f"{i}. {col}")
            
    print("\n=== 特徵統計摘要 ===")
    print(df.describe())

def save_test_results(df: pd.DataFrame):
    """保存測試結果"""
    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
    test_results_dir = 'test_results'
    os.makedirs(test_results_dir, exist_ok=True)
    
    # 保存特徵數據
    df.to_csv(f'{test_results_dir}/features_{timestamp}.csv')
    
    # 保存統計信息
    df.describe().to_csv(f'{test_results_dir}/statistics_{timestamp}.csv')
    
    print(f"\n測試結果已保存至 {test_results_dir} 目錄")

# %%
if __name__ == "__main__":
    import logging
    
    # 創建日誌處理器
    file_handler = logging.FileHandler('feature_generator.log', encoding='utf-8')
    console_handler = logging.StreamHandler()
    
    # 設置格式
    formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
    file_handler.setFormatter(formatter)
    console_handler.setFormatter(formatter)
    
    # 配置根日誌記錄器
    logger = logging.getLogger()
    logger.setLevel(logging.INFO)
    logger.addHandler(file_handler)
    logger.addHandler(console_handler)
    
    # 執行測試
    try:
        if test_feature_generator():
            print("\n特徵生成器測試成功!")
            
            # 執行主程序
            df_result = main()
            print("\n程序執行完成!")
        else:
            print("\n特徵生成器測試失敗，請檢查錯誤日誌。")
            
    except Exception as e:
        logger.error(f"程序執行出錯: {str(e)}")
        raise
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\ProgramData\anaconda3\envs\Archie\lib\logging\__init__.py", line 1103, in emit
#     stream.write(msg + self.terminator)
#   File "C:\ProgramData\anaconda3\envs\Archie\lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 33-41: character maps to <undefined>
# Call stack:
#   File "C:\ProgramData\anaconda3\envs\Archie\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\ProgramData\anaconda3\envs\Archie\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "C:\ProgramData\anaconda3\envs\Archie\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
# ...
