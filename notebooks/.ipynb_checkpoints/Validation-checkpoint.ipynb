# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
def validate_stock_data():
    """驗證enhanced_features.csv中的股票數據"""
    # 設定檔案路徑
    file_path = Path("D:/Min/Python/Project/FA_Data/meta_data/enhanced_features.csv")
    
    print("開始驗證數據...")
    
    try:
        # 讀取CSV文件
        df = pd.read_csv(file_path, low_memory=False)
        
        # 基本信息
        print(f"\n檔案總行數: {len(df):,}")
        print(f"總股票數: {df['證券代號'].nunique():,}")
        
        # 檢查特定股票
        test_stocks = ['2330', '2317', '2454']
        print("\n特定股票資料檢查:")
        
        for stock_id in test_stocks:
            stock_data = df[df['證券代號'].astype(str) == stock_id]
            if not stock_data.empty:
                print(f"\n股票 {stock_id}:")
                print(f"- 資料筆數: {len(stock_data):,}")
                print(f"- 日期範圍: {stock_data['日期'].min()} 到 {stock_data['日期'].max()}")
                # 顯示最新5筆資料的關鍵欄位
                print("\n最新5筆資料:")
                latest_data = stock_data.sort_values('日期', ascending=False).head()
                print(latest_data[['日期', '證券代號', '收盤價', 'RSI', '技術綜合評分']].to_string())
            else:
                print(f"\n股票 {stock_id}: 查無資料")
    
    except Exception as e:
        print(f"讀取文件時發生錯誤: {str(e)}")

# %%
if __name__ == "__main__":
    validate_stock_data()
