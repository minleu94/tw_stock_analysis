# %%
import pandas as pd
import numpy as np
from typing import Dict, List, Tuple, Optional
from pathlib import Path
from datetime import datetime, timedelta
from enum import Enum
import logging
from scipy import stats
from tqdm import tqdm
from sklearn.linear_model import LinearRegression
import warnings
warnings.filterwarnings('ignore')

# %%
class IndexType(Enum):
    """指數類型"""
    PRICE = "價格指數"    # 不含股利
    RETURN = "報酬指數"   # 含股利再投資

class TimeFrequency(Enum):
    """時間頻率"""
    WEEKLY = 'W'
    MONTHLY = 'ME'

# %%
class IndustryAnalysisSystem:
    """產業分析系統"""
    
    def __init__(self, base_path: str = "D:/Min/Python/Project/FA_Data"):
        self.base_path = Path(base_path)
        self.logger = logging.getLogger(self.__class__.__name__)
        
        # 建立必要的目錄結構
        self._initialize_directories()
        
        try:
            # 載入基礎資料
            self.company_data = pd.read_csv(self.base_path / "meta_data/companies.csv")
            self.logger.info("成功載入公司資料")
            
            self.industry_index = pd.read_csv(self.base_path / "meta_data/industry_index.csv")
            self.logger.info("成功載入產業指數資料")
            
            self.market_index = pd.read_csv(self.base_path / "meta_data/market_index.csv")
            self.logger.info("成功載入市場指數資料")
            
            # 處理日期格式
            self.industry_index['日期'] = pd.to_datetime(self.industry_index['日期'])
            self.market_index['Date'] = pd.to_datetime(self.market_index['Date'])
            
            # 建立產業對應關係
            self.industry_mapping = self._create_industry_mapping()
            
        except FileNotFoundError as e:
            self.logger.error(f"找不到必要的資料檔案: {str(e)}")
            raise
        except pd.errors.EmptyDataError as e:
            self.logger.error(f"資料檔案是空的: {str(e)}")
            raise
        except Exception as e:
            self.logger.error(f"初始化時發生未預期的錯誤: {str(e)}")
            raise

    def _initialize_directories(self):
        """初始化目錄結構"""
        directories = [
            "industry_correlation/weekly",
            "industry_correlation/monthly",
            "industry_analysis/price_index",
            "industry_analysis/return_index",
            "meta_data/backup"
        ]
        
        for directory in directories:
            (self.base_path / directory).mkdir(parents=True, exist_ok=True)

    def get_industry_stocks(self, industry_name: str) -> List[str]:
        """獲取特定產業的所有股票"""
        base_name = industry_name.replace('類報酬指數', '').replace('類指數', '').replace('業', '').strip()
        all_stocks = set()
        
        if base_name in self.industry_mapping:
            # 獲取所有相關的產業類別
            categories = self.industry_mapping[base_name]['categories']
            
            # 對每個類別獲取股票
            for category in categories:
                stocks = self.company_data[
                    self.company_data['industry_category'] == category
                ]['stock_id'].unique()
                all_stocks.update(stocks)
        
        return list(all_stocks)
    
    def get_industry_performance(self, 
                               industry_name: str, 
                               index_type: IndexType = None,
                               start_date: str = None, 
                               end_date: str = None) -> pd.DataFrame:
        """獲取產業指數表現"""
        base_name = industry_name.replace('類報酬指數', '').replace('類指數', '').replace('業', '').strip()
        
        if base_name in self.industry_mapping:
            # 根據指數類型選擇指數
            if index_type is None:
                # 如果未指定類型，優先使用報酬指數
                index_names = (self.industry_mapping[base_name][IndexType.RETURN] or 
                             self.industry_mapping[base_name][IndexType.PRICE])
            else:
                index_names = self.industry_mapping[base_name][index_type]
                
            if not index_names:
                return pd.DataFrame()
            
            # 獲取所有相關指數的數據
            industry_data = self.industry_index[
                self.industry_index['指數名稱'].isin(index_names)
            ].copy()
            
            # 日期過濾
            if start_date:
                industry_data = industry_data[
                    industry_data['日期'] >= pd.to_datetime(start_date)
                ]
            if end_date:
                industry_data = industry_data[
                    industry_data['日期'] <= pd.to_datetime(end_date)
                ]
            
            if not industry_data.empty:
                # 計算相關指標
                industry_data['daily_return'] = industry_data.groupby('指數名稱')['收盤指數'].pct_change()
                industry_data['volatility'] = industry_data.groupby('指數名稱')['daily_return'].rolling(20).std().values
            
            return industry_data
        
        return pd.DataFrame()
    
    def _create_industry_mapping(self) -> Dict:
        """建立產業分類對應關係"""
        mapping = {}
        
        # 建立指數類型分類
        index_types = {
            name: IndexType.RETURN if '報酬指數' in name else IndexType.PRICE
            for name in self.industry_index['指數名稱'].unique()
        }
        
        # 產業名稱標準化
        def get_base_name(name: str) -> str:
            """獲取基礎產業名稱"""
            return name.replace('類報酬指數', '').replace('類指數', '').replace('業', '').strip()
        
        # 建立產業分類到指數的映射
        for index_name in self.industry_index['指數名稱'].unique():
            base_name = get_base_name(index_name)
            if base_name not in mapping:
                mapping[base_name] = {
                    IndexType.PRICE: [],
                    IndexType.RETURN: [],
                    'categories': set()  # 改用set來存儲相關的industry_category
                }
            
            # 根據指數類型分類
            index_type = index_types[index_name]
            mapping[base_name][index_type].append(index_name)
        
        # 添加產業類別對應關係
        for category in self.company_data['industry_category'].unique():
            base_name = get_base_name(category)
            if base_name in mapping:
                mapping[base_name]['categories'].add(category)
                
            # 特殊處理：如果類別名稱本身就是一個完整的產業名稱
            if category.endswith('業'):
                base_name_from_category = get_base_name(category)
                if base_name_from_category in mapping:
                    mapping[base_name_from_category]['categories'].add(category)
        
        # 將set轉換回list
        for base_name in mapping:
            mapping[base_name]['categories'] = list(mapping[base_name]['categories'])
        
        return mapping

    def analyze_time_series_patterns(self, 
                                   industry_name: str,
                                   start_date: Optional[str] = None,
                                   end_date: Optional[str] = None) -> Dict:
        """分析產業指數的時間序列特性"""
        result = {
            'trend': {},
            'seasonality': {},
            'lead_lag': {}
        }
        
        # 優先使用報酬指數
        industry_data = self.get_industry_performance(
            industry_name,
            index_type=IndexType.RETURN,  # 優先使用報酬指數
            start_date=start_date,
            end_date=end_date
        )
        
        # 如果沒有報酬指數,則使用價格指數
        if industry_data.empty:
            industry_data = self.get_industry_performance(
                industry_name,
                index_type=IndexType.PRICE,
                start_date=start_date,
                end_date=end_date
            )
        
        if industry_data.empty:
            return result
        
        # 記錄使用的指數類型
        index_type = '報酬指數' if '報酬指數' in industry_data['指數名稱'].iloc[0] else '價格指數'
        self.logger.info(f"分析 {industry_name} 使用的是 {index_type}")
        
        # 其他分析邏輯保持不變...
        result['trend'] = self._analyze_trend(industry_data)
        result['seasonality'] = self._analyze_seasonality(industry_data)
        result['lead_lag'] = self._analyze_lead_lag_relationship(industry_data)
        
        return result
    
    def _analyze_trend(self, data: pd.DataFrame) -> Dict:
        """分析趨勢特性"""
        trend_analysis = {}
        
        # 計算線性趨勢
        X = np.arange(len(data)).reshape(-1, 1)
        y = data['收盤指數'].values
        model = LinearRegression()
        model.fit(X, y)
        
        trend_analysis['slope'] = model.coef_[0]
        trend_analysis['trend_direction'] = 'upward' if model.coef_[0] > 0 else 'downward'
        trend_analysis['r2_score'] = model.score(X, y)
        
        # 趨勢強度分析
        trend_analysis['trend_strength'] = abs(model.coef_[0]) / np.mean(y)
        
        return trend_analysis
    
    def _analyze_seasonality(self, data: pd.DataFrame) -> Dict:
        """分析季節性特性"""
        seasonality = {}
        
        # 添加月份和季度信息
        data = data.copy()
        data['month'] = data['日期'].dt.month
        data['quarter'] = data['日期'].dt.quarter
        
        # 月度季節性
        monthly_means = data.groupby('month')['收盤指數'].mean()
        monthly_std = data.groupby('month')['收盤指數'].std()
        
        seasonality['monthly'] = {
            'strongest_month': monthly_means.idxmax(),
            'weakest_month': monthly_means.idxmin(),
            'monthly_pattern': monthly_means.to_dict(),
            'monthly_volatility': monthly_std.to_dict()
        }
        
        # 季度季節性
        quarterly_means = data.groupby('quarter')['收盤指數'].mean()
        quarterly_std = data.groupby('quarter')['收盤指數'].std()
        
        seasonality['quarterly'] = {
            'strongest_quarter': quarterly_means.idxmax(),
            'weakest_quarter': quarterly_means.idxmin(),
            'quarterly_pattern': quarterly_means.to_dict(),
            'quarterly_volatility': quarterly_std.to_dict()
        }
        
        return seasonality
    
    def _analyze_lead_lag_relationship(self, data: pd.DataFrame) -> Dict:
        """分析領先/落後關係"""
        lead_lag = {}
        
        # 與大盤指數的領先/落後關係
        market_data = self.market_index.copy()
        market_data = market_data.rename(columns={'Date': '日期'})
        
        # 合併數據
        merged_data = pd.merge(
            data[['日期', '收盤指數']],
            market_data[['日期', 'Close']],
            on='日期'
        )
        
        # 計算收益率
        merged_data['industry_return'] = merged_data['收盤指數'].pct_change()
        merged_data['market_return'] = merged_data['Close'].pct_change()
        
        # 計算不同lag的相關性
        correlations = {}
        for lag in range(-10, 11):  # 檢查前後10天
            if lag < 0:
                corr = merged_data['industry_return'].shift(abs(lag)).corr(merged_data['market_return'])
                correlations[lag] = corr
            else:
                corr = merged_data['industry_return'].corr(merged_data['market_return'].shift(lag))
                correlations[lag] = corr
        
        # 找出最強的領先/落後關係
        max_corr_lag = max(correlations.items(), key=lambda x: abs(x[1]))
        
        lead_lag['max_correlation_lag'] = max_corr_lag[0]
        lead_lag['max_correlation_value'] = max_corr_lag[1]
        lead_lag['relationship_type'] = 'leading' if max_corr_lag[0] < 0 else 'lagging' if max_corr_lag[0] > 0 else 'concurrent'
        lead_lag['all_correlations'] = correlations
        
        return lead_lag

    def analyze_risk_metrics(self, 
                           industry_name: str,
                           start_date: Optional[str] = None,
                           end_date: Optional[str] = None) -> Dict:
        """分析風險指標"""
        # 獲取產業數據
        industry_data = self.get_industry_performance(
            industry_name,
            start_date=start_date,
            end_date=end_date
        )
        
        if industry_data.empty:
            return {}
        
        # 計算日收益率
        returns = industry_data['收盤指數'].pct_change()
        
        # 計算綜合風險指標
        risk_metrics = self.calculate_risk_metrics(returns)
        
        # 添加回撤分析
        risk_metrics['drawdown'] = self._calculate_drawdown_metrics(industry_data['收盤指數'])
        
        return risk_metrics
    
    def _calculate_downside_risk(self, returns: pd.Series) -> Dict:
        """計算下跌風險指標"""
        downside = {}
        
        # 下跌風險
        negative_returns = returns[returns < 0]
        downside['avg_loss'] = negative_returns.mean()
        downside['loss_std'] = negative_returns.std()
        downside['loss_frequency'] = len(negative_returns) / len(returns)
        
        # 下跌波動率
        downside_returns = returns[returns < 0]
        downside['downside_volatility'] = np.sqrt(np.sum(downside_returns ** 2) / len(returns)) * np.sqrt(252)
        
        return downside
    
    def _calculate_drawdown_metrics(self, prices: pd.Series) -> Dict:
        """計算回撤相關指標"""
        drawdown = {}
        
        # 計算回撤序列
        roll_max = prices.expanding().max()
        drawdowns = (prices - roll_max) / roll_max
        
        # 最大回撤
        drawdown['max_drawdown'] = drawdowns.min()
        
        # 平均回撤
        drawdown['avg_drawdown'] = drawdowns[drawdowns < 0].mean()
        
        # 回撤持續時間分析
        drawdown_periods = self._analyze_drawdown_periods(prices)
        drawdown['avg_recovery_time'] = drawdown_periods['avg_recovery_time']
        drawdown['max_recovery_time'] = drawdown_periods['max_recovery_time']
        
        return drawdown
    
    def _analyze_drawdown_periods(self, prices: pd.Series) -> Dict:
        """分析回撤期間"""
        result = {'avg_recovery_time': 0, 'max_recovery_time': 0}
        
        high_water_mark = prices.expanding().max()
        drawdowns = (prices - high_water_mark) / high_water_mark
        
        # 找出回撤開始和結束點
        in_drawdown = False
        drawdown_starts = []
        recovery_times = []
        
        for i in range(1, len(prices)):
            if not in_drawdown and drawdowns[i] < 0:
                in_drawdown = True
                drawdown_starts.append(i)
            elif in_drawdown and prices[i] >= high_water_mark[i]:
                in_drawdown = False
                recovery_times.append(i - drawdown_starts[-1])
        
        if recovery_times:
            result['avg_recovery_time'] = np.mean(recovery_times)
            result['max_recovery_time'] = max(recovery_times)
        
        return result

    def calculate_risk_metrics(self, returns: pd.Series, risk_free_rate: float = 0.02) -> Dict:
        """整合計算風險指標"""
        metrics = {}
        
        # 基礎風險指標計算
        annual_return = returns.mean() * 252
        annual_volatility = returns.std() * np.sqrt(252)
        
        # 風險調整後收益比率
        metrics['ratios'] = {
            'annual_return': annual_return,
            'annual_volatility': annual_volatility,
            'sharpe_ratio': (annual_return - risk_free_rate) / annual_volatility if annual_volatility != 0 else 0,
        }
        
        # 下檔風險指標
        downside_returns = returns[returns < 0]
        downside_volatility = downside_returns.std() * np.sqrt(252)
        
        metrics['downside'] = {
            'downside_volatility': downside_volatility,
            'sortino_ratio': (annual_return - risk_free_rate) / downside_volatility if downside_volatility != 0 else 0,
            'loss_frequency': len(downside_returns) / len(returns),
            'avg_loss': downside_returns.mean()
        }
        
        # 尾部風險指標
        metrics['tail_risk'] = {
            'var_95': returns.quantile(0.05),
            'var_99': returns.quantile(0.01),
            'cvar_95': returns[returns <= returns.quantile(0.05)].mean(),
            'cvar_99': returns[returns <= returns.quantile(0.01)].mean(),
            'skewness': returns.skew(),
            'kurtosis': returns.kurtosis()
        }
        
        return metrics

    def analyze_industry_rotation(self, 
                                lookback_period: int = 120,
                                momentum_period: int = 20) -> Dict:
        """分析產業輪動"""
        rotation_analysis = {
            'strength_ranking': {},
            'momentum_ranking': {},
            'flow_analysis': {},
            'rotation_cycles': {}
        }
        
        # 獲取所有產業的數據
        industry_data = self.industry_index.copy()
        industry_data['base_industry'] = industry_data['指數名稱'].apply(
            lambda x: x.replace('類報酬指數', '').replace('類指數', '').replace('業', '').strip()
        )
        
        # 計算產業強弱勢排名
        rotation_analysis['strength_ranking'] = self._analyze_industry_strength(
            industry_data,
            lookback_period
        )
        
        # 計算產業動能排名
        rotation_analysis['momentum_ranking'] = self._analyze_industry_momentum(
            industry_data,
            momentum_period
        )
        
        # 分析資金流向
        rotation_analysis['flow_analysis'] = self._analyze_fund_flow(
            industry_data,
            lookback_period
        )
        
        # 分析輪動週期
        rotation_analysis['rotation_cycles'] = self._analyze_rotation_cycles(
            industry_data
        )
        
        return rotation_analysis

    def _analyze_industry_strength(self, data: pd.DataFrame, lookback_period: int) -> Dict:
        """分析產業強弱勢"""
        strength = {}
        
        # 計算各產業最近期的表現
        latest_date = data['日期'].max()
        start_date = latest_date - pd.Timedelta(days=lookback_period)
        
        period_data = data[data['日期'] >= start_date].copy()
        
        # 計算期間報酬率
        period_returns = {}
        for industry in period_data['base_industry'].unique():
            industry_data = period_data[period_data['base_industry'] == industry]
            if not industry_data.empty:
                start_price = industry_data.loc[industry_data['日期'].idxmin(), '收盤指數']
                end_price = industry_data.loc[industry_data['日期'].idxmax(), '收盤指數']
                period_returns[industry] = (end_price / start_price - 1) * 100
        
        # 計算相對強度指標
        strength['period_returns'] = period_returns
        strength['ranking'] = pd.Series(period_returns).sort_values(ascending=False)
        
        # 計算強弱分界
        returns_series = pd.Series(period_returns)
        strength['strong_industries'] = returns_series[returns_series > returns_series.mean()].index.tolist()
        strength['weak_industries'] = returns_series[returns_series <= returns_series.mean()].index.tolist()
        
        return strength
    
    def _analyze_industry_momentum(self, data: pd.DataFrame, momentum_period: int) -> Dict:
        """分析產業動能"""
        momentum = {}
        
        latest_date = data['日期'].max()
        start_date = latest_date - pd.Timedelta(days=momentum_period)
        
        # 計算動能指標
        momentum_scores = {}
        for industry in data['base_industry'].unique():
            industry_data = data[
                (data['base_industry'] == industry) & 
                (data['日期'] >= start_date)
            ].copy()
            
            if not industry_data.empty:
                # 計算價格動能
                price_momentum = industry_data['收盤指數'].pct_change().mean()
                
                # 計算成交量動能 (如果有成交量數據)
                volume_momentum = 0
                if '成交金額' in industry_data.columns:
                    volume_momentum = industry_data['成交金額'].pct_change().mean()
                
                # 綜合動能分數
                momentum_scores[industry] = {
                    'price_momentum': price_momentum,
                    'volume_momentum': volume_momentum,
                    'composite_score': price_momentum + 0.5 * volume_momentum
                }
        
        # 動能排名
        composite_scores = {k: v['composite_score'] for k, v in momentum_scores.items()}
        momentum['scores'] = momentum_scores
        momentum['ranking'] = pd.Series(composite_scores).sort_values(ascending=False)
        
        return momentum
    
    def _analyze_fund_flow(self, data: pd.DataFrame, lookback_period: int) -> Dict:
        """資金流向分析"""
        # 準備數據
        latest_date = data['日期'].max()
        start_date = latest_date - pd.Timedelta(days=lookback_period)
        period_data = data[data['日期'] >= start_date].copy()
        
        # 計算基本指標
        period_data['daily_return'] = period_data.groupby('base_industry')['收盤指數'].pct_change()
        period_data['volume_change'] = period_data.groupby('base_industry')['成交金額'].pct_change() if '成交金額' in period_data.columns else 0
        
        flow_analysis = {}
        
        # 按產業分組計算
        for industry in period_data['base_industry'].unique():
            industry_data = period_data[period_data['base_industry'] == industry]
            
            # 計算綜合指標
            price_momentum = industry_data['daily_return'].mean()
            volume_momentum = industry_data['volume_change'].mean() if isinstance(industry_data['volume_change'], pd.Series) else 0
            volatility = industry_data['daily_return'].std()
            
            flow_score = price_momentum * (1 + 0.5 * abs(volume_momentum))
            
            flow_analysis[industry] = {
                'momentum': price_momentum,
                'volume_trend': volume_momentum,
                'volatility': volatility,
                'flow_score': flow_score
            }
        
        # 轉換為 DataFrame 方便排序和分析
        flow_df = pd.DataFrame.from_dict(flow_analysis, orient='index')
        
        return {
            'indicators': flow_analysis,
            'inflow_industries': flow_df[flow_df['flow_score'] > 0].sort_values('flow_score', ascending=False).index.tolist(),
            'outflow_industries': flow_df[flow_df['flow_score'] < 0].sort_values('flow_score').index.tolist(),
            'rankings': {
                'momentum': flow_df.sort_values('momentum', ascending=False).index.tolist(),
                'volume': flow_df.sort_values('volume_trend', ascending=False).index.tolist()
            }
        }
    
    def _analyze_rotation_cycles(self, data: pd.DataFrame) -> Dict:
        """分析輪動週期"""
        cycles = {}
        
        # 計算每個產業的相對強度
        industry_returns = {}
        for industry in data['base_industry'].unique():
            industry_data = data[data['base_industry'] == industry].copy()
            if not industry_data.empty:
                industry_data['returns'] = industry_data['收盤指數'].pct_change()
                industry_returns[industry] = industry_data['returns']
        
        # 計算產業輪動特徵
        rotation_features = {}
        for industry, returns in industry_returns.items():
            if len(returns) > 0:
                # 計算產業週期特徵
                rotation_features[industry] = {
                    'mean_return': returns.mean(),
                    'volatility': returns.std(),
                    'skewness': returns.skew(),
                    'autocorrelation': returns.autocorr()
                }
        
        cycles['features'] = rotation_features
        
        # 識別當前輪動階段
        latest_returns = {industry: returns.iloc[-20:].mean() for industry, returns in industry_returns.items()}
        sorted_industries = pd.Series(latest_returns).sort_values(ascending=False)
        
        # 定義輪動階段
        top_quartile = sorted_industries[:len(sorted_industries)//4]
        cycles['current_leaders'] = top_quartile.index.tolist()
        
        # 計算產業間的領先/落後關係
        lead_lag_matrix = {}
        for ind1 in industry_returns.keys():
            lead_lag_matrix[ind1] = {}
            for ind2 in industry_returns.keys():
                if ind1 != ind2:
                    correlation = industry_returns[ind1].corr(industry_returns[ind2])
                    lead_lag_matrix[ind1][ind2] = correlation
        
        cycles['lead_lag_matrix'] = lead_lag_matrix
        
        return cycles

    def generate_enhanced_report(self, 
                               industry_name: str,
                               start_date: Optional[str] = None,
                               end_date: Optional[str] = None) -> Dict:
        """生成增強版產業分析報告"""
        report = {
            'basic_info': {},
            'time_series_analysis': {},
            'risk_analysis': {},
            'rotation_analysis': {},
            'technical_analysis': {},
            'investment_suggestions': {}
        }
        
        # 基本信息
        report['basic_info'] = {
            'industry_name': industry_name,
            'period': {'start': start_date, 'end': end_date},
            'stocks': self.get_industry_stocks(industry_name)
        }
        
        # 時間序列分析
        report['time_series_analysis'] = self.analyze_time_series_patterns(
            industry_name, start_date, end_date
        )
        
        # 風險分析
        report['risk_analysis'] = self.analyze_risk_metrics(
            industry_name, start_date, end_date
        )
        
        # 產業輪動分析
        report['rotation_analysis'] = self.analyze_industry_rotation()
        
        # 生成投資建議
        report['investment_suggestions'] = self._generate_investment_suggestions(report)
        
        return report
    
    def _generate_investment_suggestions(self, analysis_report: Dict) -> Dict:
        """生成投資建議"""
        # 從 basic_info 中獲取產業名稱
        industry_name = analysis_report['basic_info']['industry_name']
        suggestions = {
            'risk_assessment': '',
            'timing_suggestions': '',
            'position_suggestions': '',
            'key_points': []
        }
        
        # 評估風險水平
        risk_analysis = analysis_report['risk_analysis']
        if risk_analysis['ratios']['sharpe_ratio'] > 1:
            risk_level = '較低'
        elif risk_analysis['ratios']['sharpe_ratio'] > 0:
            risk_level = '中等'
        else:
            risk_level = '較高'
            
        suggestions['risk_assessment'] = f"當前風險水平: {risk_level}"
        
        # 時間序列分析建議
        time_series = analysis_report['time_series_analysis']
        if time_series['trend']['trend_direction'] == 'upward':
            if time_series['trend']['trend_strength'] > 0.1:
                suggestions['timing_suggestions'] = "當前處於強勢上升趨勢，可考慮逢回調布局"
            else:
                suggestions['timing_suggestions'] = "當前處於溫和上升趨勢，建議分批布局"
        else:
            suggestions['timing_suggestions'] = "當前處於下降趨勢，建議觀望或降低持倉"
        
        # 產業輪動建議
        rotation = analysis_report['rotation_analysis']
        if industry_name in rotation['strength_ranking']['strong_industries']:
            suggestions['position_suggestions'] = "產業處於強勢地位，可維持較高持倉"
        else:
            suggestions['position_suggestions'] = "產業強度偏弱，建議控制持倉比例"
        
        # 關鍵要點
        suggestions['key_points'] = [
            f"夏普比率: {risk_analysis['ratios']['sharpe_ratio']:.2f}",
            f"最大回撤: {risk_analysis['drawdown']['max_drawdown']:.2%}",
            f"產業相對強度排名: {rotation['strength_ranking']['ranking'].index.get_loc(industry_name) + 1}",
            f"建議持倉水位: {'70-90%' if risk_level == '較低' else '50-70%' if risk_level == '中等' else '30-50%'}"
        ]
        
        return suggestions

    def generate_correlation_matrix(self, date: str) -> pd.DataFrame:
        """生成特定日期的產業相關性矩陣"""
        # 確保日期格式正確
        date = pd.to_datetime(date)
        
        # 獲取計算相關性的時間範圍(使用前20個交易日的數據)
        start_date = date - pd.Timedelta(days=30)
        
        # 獲取時間範圍內的所有產業數據
        historical_data = self.industry_index[
            (self.industry_index['日期'] >= start_date) & 
            (self.industry_index['日期'] <= date)
        ].copy()
        
        if historical_data.empty:
            self.logger.warning(f"日期 {date.strftime('%Y-%m-%d')} 無可用數據")
            return pd.DataFrame()
        
        # 優先使用報酬指數,如果沒有則使用價格指數
        def get_preferred_index(group):
            return_index = group[group['指數名稱'].str.contains('報酬指數')]
            if not return_index.empty:
                return return_index
            return group[~group['指數名稱'].str.contains('報酬指數')]
        
        # 標準化產業名稱並選擇合適的指數類型
        historical_data['base_industry'] = historical_data['指數名稱'].apply(
            lambda x: x.replace('類報酬指數', '').replace('類指數', '').replace('業', '').strip()
        )
        
        # 對每個產業選擇合適的指數類型
        selected_data = []
        for industry in historical_data['base_industry'].unique():
            industry_group = historical_data[historical_data['base_industry'] == industry]
            preferred_index = get_preferred_index(industry_group)
            selected_data.append(preferred_index)
        
        historical_data = pd.concat(selected_data)
        
        # 計算每個產業的日收益率
        historical_data['daily_return'] = historical_data.groupby('base_industry')['收盤指數'].pct_change()
        
        # 構建收益率數據框
        industries = historical_data['base_industry'].unique()
        returns_data = pd.DataFrame(index=historical_data['日期'].unique())
        
        for industry in industries:
            industry_returns = historical_data[historical_data['base_industry'] == industry]
            returns_data[industry] = industry_returns.set_index('日期')['daily_return']
        
        # 計算相關性矩陣
        corr_matrix = returns_data.corr(method='pearson')
        
        # 確保對角線為1,且矩陣對稱
        np.fill_diagonal(corr_matrix.values, 1)
        corr_matrix = (corr_matrix + corr_matrix.T) / 2
        
        # 添加指數類型信息到日誌
        index_types = historical_data.groupby('base_industry')['指數名稱'].first()
        self.logger.info("使用的指數類型:")
        for industry, index_name in index_types.items():
            self.logger.info(f"{industry}: {index_name}")
        
        return corr_matrix

    def generate_correlation_series(self, frequency: TimeFrequency,
                                 start_date: str = None,
                                 end_date: str = None):
        """生成並儲存時間序列相關性數據"""
        try:
            # 準備數據
            data = self.industry_index.copy()
            
            # 確保 data 包含日期欄位
            if '日期' not in data.columns:
                self.logger.error("找不到 '日期' 欄位")
                return
                
            # 確保日期格式正確
            data['日期'] = pd.to_datetime(data['日期'])
            
            # 日期過濾
            if start_date:
                data = data[data['日期'] >= pd.to_datetime(start_date)]
            if end_date:
                data = data[data['日期'] <= pd.to_datetime(end_date)]
                
            # 確保有足夠的數據
            if data.empty:
                self.logger.warning(f"指定時間範圍內無數據: {start_date} 到 {end_date}")
                return
                
            # 根據頻率重採樣
            if frequency == TimeFrequency.WEEKLY:
                # 使用 groupby 而不是 resample
                dates = data.groupby(pd.Grouper(key='日期', freq='W'))['日期'].last().dropna()
            else:  # MONTHLY
                dates = data.groupby(pd.Grouper(key='日期', freq='M'))['日期'].last().dropna()
            
            # 使用tqdm顯示進度
            freq_name = "週" if frequency == TimeFrequency.WEEKLY else "月"
            for date in tqdm(dates, desc=f"生成{freq_name}度相關性矩陣"):
                if pd.notnull(date):
                    corr_matrix = self.generate_correlation_matrix(date)
                    if not corr_matrix.empty:
                        self.save_correlation_series(corr_matrix, date, frequency)
                        
        except Exception as e:
            self.logger.error(f"生成相關性序列時發生錯誤: {str(e)}")
            raise

    def save_correlation_series(self, matrix: pd.DataFrame, date: str, frequency: TimeFrequency):
        """儲存時間序列的相關性數據"""
        date_str = pd.to_datetime(date).strftime('%Y%m%d')
        
        # 根據頻率選擇保存路徑
        if frequency == TimeFrequency.WEEKLY:
            save_dir = self.base_path / "industry_correlation/weekly"
        else:  # MONTHLY
            save_dir = self.base_path / "industry_correlation/monthly"
        
        # 確保目錄存在
        save_dir.mkdir(parents=True, exist_ok=True)
        
        # 保存文件
        filename = f"industry_correlation_{date_str}.csv"
        save_path = save_dir / filename
        
        try:
            # 將相關性係數四捨五入到4位小數
            matrix = matrix.round(4)
            # 保存為CSV,保留中文編碼
            matrix.to_csv(save_path, encoding='utf-8-sig')
            self.logger.info(f"已保存相關性矩陣到: {save_path}")
        except Exception as e:
            self.logger.error(f"保存相關性矩陣時發生錯誤: {str(e)}")

# %%
if __name__ == "__main__":
    try:
        # 設定logging
        logging.basicConfig(
            level=logging.INFO,
            format='%(asctime)s - %(levelname)s - %(message)s'
        )
        logger = logging.getLogger(__name__)
        
        logger.info("開始執行產業分析系統")
        
        # 初始化系統
        analyzer = IndustryAnalysisSystem()
        
        # 設置分析期間
        start_date = '2023-01-01'
        end_date = '2024-11-12'
        target_industry = '光電'
        
        logger.info(f"分析期間: {start_date} 到 {end_date}")
        logger.info(f"目標產業: {target_industry}")
        
        # 生成產業相關性分析
        logger.info("開始生成週度相關性資料...")
        analyzer.generate_correlation_series(
            TimeFrequency.WEEKLY,
            start_date=start_date,
            end_date=end_date
        )
        
        logger.info("開始生成月度相關性資料...")
        analyzer.generate_correlation_series(
            TimeFrequency.MONTHLY,
            start_date=start_date,
            end_date=end_date
        )
        
        # 生成完整產業分析報告
        logger.info("開始生成產業分析報告...")
        report = analyzer.generate_enhanced_report(
            target_industry,
            start_date=start_date,
            end_date=end_date
        )
        
        # 輸出報告結果
        if report and 'basic_info' in report:
            print("\n產業分析報告：")
            print(f"產業：{report['basic_info']['industry_name']}")
            print(f"分析期間：{report['basic_info']['period']['start']} 到 {report['basic_info']['period']['end']}")
            print(f"股票數量：{len(report['basic_info']['stocks'])}")
            
            # 輸出風險分析
            if 'risk_analysis' in report:
                print("\n風險分析：")
                ratios = report['risk_analysis'].get('ratios', {})
                print(f"夏普比率: {ratios.get('sharpe_ratio', 0):.2f}")
                print(f"年化波動率: {ratios.get('annual_volatility', 0):.2%}")
            
            # 輸出時間序列分析
            if 'time_series_analysis' in report:
                print("\n趨勢分析：")
                trend = report['time_series_analysis'].get('trend', {})
                print(f"趨勢方向: {trend.get('trend_direction', 'N/A')}")
                print(f"趨勢強度: {trend.get('trend_strength', 0):.4f}")
            
            # 輸出投資建議
            if 'investment_suggestions' in report:
                print("\n投資建議：")
                suggestions = report['investment_suggestions']
                print(f"風險評估: {suggestions.get('risk_assessment', 'N/A')}")
                print(f"進場建議: {suggestions.get('timing_suggestions', 'N/A')}")
                print(f"部位建議: {suggestions.get('position_suggestions', 'N/A')}")
                
    except Exception as e:
        logger.error(f"程式執行錯誤: {str(e)}")
        import traceback
        logger.error(f"錯誤追蹤:\n{traceback.format_exc()}")
# Out:
# 2024-11-13 21:59:07,938 - INFO - 開始執行產業分析系統
# 2024-11-13 21:59:07,954 - INFO - 成功載入公司資料
# 2024-11-13 21:59:08,259 - INFO - 成功載入產業指數資料
# 2024-11-13 21:59:08,281 - INFO - 成功載入市場指數資料
# 2024-11-13 21:59:08,473 - INFO - 分析期間: 2023-01-01 到 2024-11-12
# 2024-11-13 21:59:08,476 - INFO - 目標產業: 光電
# 2024-11-13 21:59:08,478 - INFO - 開始生成週度相關性資料...
# 生成週度相關性矩陣:   0%|                                                                       | 0/97 [00:00<?, ?it/s]2024-11-13 21:59:08,695 - INFO - 使用的指數類型:
# 2024-11-13 21:59:08,696 - INFO - 光電: 光電類報酬指數
# 2024-11-13 21:59:08,700 - INFO - 其他: 其他類報酬指數
# 2024-11-13 21:59:08,701 - INFO - 其他電子: 其他電子類報酬指數
# 2024-11-13 21:59:08,703 - INFO - 化學: 化學類報酬指數
# 2024-11-13 21:59:08,703 - INFO - 化學生技醫療: 化學生技醫療類報酬指數
# 2024-11-13 21:59:08,704 - INFO - 半導體: 半導體類報酬指數
# 2024-11-13 21:59:08,705 - INFO - 塑膠: 塑膠類報酬指數
# 2024-11-13 21:59:08,707 - INFO - 塑膠化工: 塑膠化工類指數
# 2024-11-13 21:59:08,708 - INFO - 建材營造: 建材營造類報酬指數
# 2024-11-13 21:59:08,709 - INFO - 橡膠: 橡膠類報酬指數
# 2024-11-13 21:59:08,710 - INFO - 水泥: 水泥類報酬指數
# 2024-11-13 21:59:08,712 - INFO - 水泥窯製: 水泥窯製類指數
# 2024-11-13 21:59:08,713 - INFO - 汽車: 汽車類報酬指數
# 2024-11-13 21:59:08,714 - INFO - 油電燃氣: 油電燃氣類報酬指數
# 2024-11-13 21:59:08,716 - INFO - 玻璃陶瓷: 玻璃陶瓷類報酬指數
# 2024-11-13 21:59:08,717 - INFO - 生技醫療: 生技醫療類報酬指數
# 2024-11-13 21:59:08,718 - INFO - 紡織纖維: 紡織纖維類報酬指數
# 2024-11-13 21:59:08,719 - INFO - 航運: 航運類報酬指數
# 2024-11-13 21:59:08,720 - INFO - 觀光: 觀光類報酬指數
# 2024-11-13 21:59:08,721 - INFO - 貿易百貨: 貿易百貨類報酬指數
# 2024-11-13 21:59:08,722 - INFO - 資訊服務: 資訊服務類報酬指數
# 2024-11-13 21:59:08,724 - INFO - 通信網路: 通信網路類報酬指數
# 2024-11-13 21:59:08,725 - INFO - 造紙: 造紙類報酬指數
# 2024-11-13 21:59:08,726 - INFO - 鋼鐵: 鋼鐵類報酬指數
# 2024-11-13 21:59:08,727 - INFO - 電器電纜: 電器電纜類報酬指數
# 2024-11-13 21:59:08,728 - INFO - 電子工: 電子工業類指數
# 2024-11-13 21:59:08,730 - INFO - 電子通路: 電子通路類報酬指數
# 2024-11-13 21:59:08,731 - INFO - 電子零組件: 電子零組件類報酬指數
# 2024-11-13 21:59:08,732 - INFO - 電機機械: 電機機械類報酬指數
# 2024-11-13 21:59:08,734 - INFO - 電腦及週邊設備: 電腦及週邊設備類報酬指數
# 2024-11-13 21:59:08,739 - INFO - 已保存相關性矩陣到: D:\Min\Python\Project\FA_Data\industry_correlation\weekly\industry_correlation_20230106.csv
# 生成週度相關性矩陣:   1%|▋                                                              | 1/97 [00:00<00:19,  4.85it/s]2024-11-13 21:59:08,859 - INFO - 使用的指數類型:
# 2024-11-13 21:59:08,861 - INFO - 光電: 光電類報酬指數
# 2024-11-13 21:59:08,862 - INFO - 其他: 其他類報酬指數
# 2024-11-13 21:59:08,862 - INFO - 其他電子: 其他電子類報酬指數
# 2024-11-13 21:59:08,863 - INFO - 化學: 化學類報酬指數
# 2024-11-13 21:59:08,864 - INFO - 化學生技醫療: 化學生技醫療類報酬指數
# 2024-11-13 21:59:08,866 - INFO - 半導體: 半導體類報酬指數
# 2024-11-13 21:59:08,867 - INFO - 塑膠: 塑膠類報酬指數
# 2024-11-13 21:59:08,868 - INFO - 塑膠化工: 塑膠化工類指數
# 2024-11-13 21:59:08,869 - INFO - 建材營造: 建材營造類報酬指數
# 2024-11-13 21:59:08,869 - INFO - 橡膠: 橡膠類報酬指數
# 2024-11-13 21:59:08,870 - INFO - 水泥: 水泥類報酬指數
# 2024-11-13 21:59:08,871 - INFO - 水泥窯製: 水泥窯製類指數
# 2024-11-13 21:59:08,876 - INFO - 汽車: 汽車類報酬指數
# 2024-11-13 21:59:08,877 - INFO - 油電燃氣: 油電燃氣類報酬指數
# 2024-11-13 21:59:08,879 - INFO - 玻璃陶瓷: 玻璃陶瓷類報酬指數
# 2024-11-13 21:59:08,881 - INFO - 生技醫療: 生技醫療類報酬指數
# 2024-11-13 21:59:08,883 - INFO - 紡織纖維: 紡織纖維類報酬指數
# 2024-11-13 21:59:08,885 - INFO - 航運: 航運類報酬指數
# 2024-11-13 21:59:08,887 - INFO - 觀光: 觀光類報酬指數
# 2024-11-13 21:59:08,888 - INFO - 貿易百貨: 貿易百貨類報酬指數
# 2024-11-13 21:59:08,889 - INFO - 資訊服務: 資訊服務類報酬指數
# 2024-11-13 21:59:08,892 - INFO - 通信網路: 通信網路類報酬指數
# 2024-11-13 21:59:08,894 - INFO - 造紙: 造紙類報酬指數
# 2024-11-13 21:59:08,897 - INFO - 鋼鐵: 鋼鐵類報酬指數
# 2024-11-13 21:59:08,899 - INFO - 電器電纜: 電器電纜類報酬指數
# 2024-11-13 21:59:08,902 - INFO - 電子工: 電子工業類指數
# 2024-11-13 21:59:08,904 - INFO - 電子通路: 電子通路類報酬指數
# 2024-11-13 21:59:08,906 - INFO - 電子零組件: 電子零組件類報酬指數
# 2024-11-13 21:59:08,908 - INFO - 電機機械: 電機機械類報酬指數
# 2024-11-13 21:59:08,910 - INFO - 電腦及週邊設備: 電腦及週邊設備類報酬指數
# 2024-11-13 21:59:08,918 - INFO - 已保存相關性矩陣到: D:\Min\Python\Project\FA_Data\industry_correlation\weekly\industry_correlation_20230113.csv
# 生成週度相關性矩陣:   2%|█▎                                                             | 2/97 [00:00<00:18,  5.25it/s]2024-11-13 21:59:09,091 - INFO - 使用的指數類型:
# 2024-11-13 21:59:09,093 - INFO - 光電: 光電類報酬指數
# 2024-11-13 21:59:09,094 - INFO - 其他: 其他類報酬指數
# 2024-11-13 21:59:09,095 - INFO - 其他電子: 其他電子類報酬指數
# 2024-11-13 21:59:09,097 - INFO - 化學: 化學類報酬指數
# 2024-11-13 21:59:09,098 - INFO - 化學生技醫療: 化學生技醫療類報酬指數
# 2024-11-13 21:59:09,100 - INFO - 半導體: 半導體類報酬指數
# 2024-11-13 21:59:09,102 - INFO - 塑膠: 塑膠類報酬指數
# 2024-11-13 21:59:09,103 - INFO - 塑膠化工: 塑膠化工類指數
# 2024-11-13 21:59:09,105 - INFO - 建材營造: 建材營造類報酬指數
# 2024-11-13 21:59:09,107 - INFO - 橡膠: 橡膠類報酬指數
# 2024-11-13 21:59:09,108 - INFO - 水泥: 水泥類報酬指數
# 2024-11-13 21:59:09,109 - INFO - 水泥窯製: 水泥窯製類指數
# 2024-11-13 21:59:09,111 - INFO - 汽車: 汽車類報酬指數
# 2024-11-13 21:59:09,112 - INFO - 油電燃氣: 油電燃氣類報酬指數
# 2024-11-13 21:59:09,113 - INFO - 玻璃陶瓷: 玻璃陶瓷類報酬指數
# 2024-11-13 21:59:09,114 - INFO - 生技醫療: 生技醫療類報酬指數
# 2024-11-13 21:59:09,116 - INFO - 紡織纖維: 紡織纖維類報酬指數
# 2024-11-13 21:59:09,118 - INFO - 航運: 航運類報酬指數
# 2024-11-13 21:59:09,119 - INFO - 觀光: 觀光類報酬指數
# 2024-11-13 21:59:09,121 - INFO - 貿易百貨: 貿易百貨類報酬指數
# 2024-11-13 21:59:09,121 - INFO - 資訊服務: 資訊服務類報酬指數
# 2024-11-13 21:59:09,124 - INFO - 通信網路: 通信網路類報酬指數
# 2024-11-13 21:59:09,126 - INFO - 造紙: 造紙類報酬指數
# 2024-11-13 21:59:09,128 - INFO - 鋼鐵: 鋼鐵類報酬指數
# 2024-11-13 21:59:09,130 - INFO - 電器電纜: 電器電纜類報酬指數
# 2024-11-13 21:59:09,131 - INFO - 電子工: 電子工業類指數
# 2024-11-13 21:59:09,133 - INFO - 電子通路: 電子通路類報酬指數
# 2024-11-13 21:59:09,136 - INFO - 電子零組件: 電子零組件類報酬指數
# 2024-11-13 21:59:09,138 - INFO - 電機機械: 電機機械類報酬指數
# 2024-11-13 21:59:09,139 - INFO - 電腦及週邊設備: 電腦及週邊設備類報酬指數
# 2024-11-13 21:59:09,145 - INFO - 已保存相關性矩陣到: D:\Min\Python\Project\FA_Data\industry_correlation\weekly\industry_correlation_20230117.csv
# 生成週度相關性矩陣:   3%|█▉                                                             | 3/97 [00:00<00:19,  4.85it/s]2024-11-13 21:59:09,295 - INFO - 使用的指數類型:
# 2024-11-13 21:59:09,297 - INFO - 光電: 光電類報酬指數
# 2024-11-13 21:59:09,299 - INFO - 其他: 其他類報酬指數
# 2024-11-13 21:59:09,300 - INFO - 其他電子: 其他電子類報酬指數
# 2024-11-13 21:59:09,302 - INFO - 化學: 化學類報酬指數
# 2024-11-13 21:59:09,304 - INFO - 化學生技醫療: 化學生技醫療類報酬指數
# 2024-11-13 21:59:09,306 - INFO - 半導體: 半導體類報酬指數
# 2024-11-13 21:59:09,307 - INFO - 塑膠: 塑膠類報酬指數
# 2024-11-13 21:59:09,309 - INFO - 塑膠化工: 塑膠化工類指數
# 2024-11-13 21:59:09,310 - INFO - 建材營造: 建材營造類報酬指數
# 2024-11-13 21:59:09,312 - INFO - 橡膠: 橡膠類報酬指數
# 2024-11-13 21:59:09,314 - INFO - 水泥: 水泥類報酬指數
# 2024-11-13 21:59:09,315 - INFO - 水泥窯製: 水泥窯製類指數
# 2024-11-13 21:59:09,317 - INFO - 汽車: 汽車類報酬指數
# 2024-11-13 21:59:09,319 - INFO - 油電燃氣: 油電燃氣類報酬指數
# 2024-11-13 21:59:09,320 - INFO - 玻璃陶瓷: 玻璃陶瓷類報酬指數
# 2024-11-13 21:59:09,322 - INFO - 生技醫療: 生技醫療類報酬指數
# 2024-11-13 21:59:09,324 - INFO - 紡織纖維: 紡織纖維類報酬指數
# 2024-11-13 21:59:09,325 - INFO - 航運: 航運類報酬指數
# 2024-11-13 21:59:09,327 - INFO - 觀光: 觀光類報酬指數
# 2024-11-13 21:59:09,329 - INFO - 貿易百貨: 貿易百貨類報酬指數
# 2024-11-13 21:59:09,330 - INFO - 資訊服務: 資訊服務類報酬指數
# 2024-11-13 21:59:09,332 - INFO - 通信網路: 通信網路類報酬指數
# 2024-11-13 21:59:09,334 - INFO - 造紙: 造紙類報酬指數
# 2024-11-13 21:59:09,335 - INFO - 鋼鐵: 鋼鐵類報酬指數
# 2024-11-13 21:59:09,337 - INFO - 電器電纜: 電器電纜類報酬指數
# 2024-11-13 21:59:09,339 - INFO - 電子工: 電子工業類指數
# 2024-11-13 21:59:09,340 - INFO - 電子通路: 電子通路類報酬指數
# 2024-11-13 21:59:09,342 - INFO - 電子零組件: 電子零組件類報酬指數
# 2024-11-13 21:59:09,344 - INFO - 電機機械: 電機機械類報酬指數
# 2024-11-13 21:59:09,345 - INFO - 電腦及週邊設備: 電腦及週邊設備類報酬指數
# 2024-11-13 21:59:09,350 - INFO - 已保存相關性矩陣到: D:\Min\Python\Project\FA_Data\industry_correlation\weekly\industry_correlation_20230203.csv
# 生成週度相關性矩陣:   4%|██▌                                                            | 4/97 [00:00<00:19,  4.85it/s]2024-11-13 21:59:09,462 - INFO - 使用的指數類型:
# 2024-11-13 21:59:09,465 - INFO - 光電: 光電類報酬指數
# 2024-11-13 21:59:09,467 - INFO - 其他: 其他類報酬指數
# 2024-11-13 21:59:09,468 - INFO - 其他電子: 其他電子類報酬指數
# 2024-11-13 21:59:09,469 - INFO - 化學: 化學類報酬指數
# 2024-11-13 21:59:09,471 - INFO - 化學生技醫療: 化學生技醫療類報酬指數
# 2024-11-13 21:59:09,472 - INFO - 半導體: 半導體類報酬指數
# 2024-11-13 21:59:09,473 - INFO - 塑膠: 塑膠類報酬指數
# 2024-11-13 21:59:09,474 - INFO - 塑膠化工: 塑膠化工類指數
# 2024-11-13 21:59:09,476 - INFO - 建材營造: 建材營造類報酬指數
# 2024-11-13 21:59:09,477 - INFO - 橡膠: 橡膠類報酬指數
# 2024-11-13 21:59:09,478 - INFO - 水泥: 水泥類報酬指數
# 2024-11-13 21:59:09,480 - INFO - 水泥窯製: 水泥窯製類指數
# 2024-11-13 21:59:09,481 - INFO - 汽車: 汽車類報酬指數
# 2024-11-13 21:59:09,482 - INFO - 油電燃氣: 油電燃氣類報酬指數
# 2024-11-13 21:59:09,483 - INFO - 玻璃陶瓷: 玻璃陶瓷類報酬指數
# 2024-11-13 21:59:09,484 - INFO - 生技醫療: 生技醫療類報酬指數
# 2024-11-13 21:59:09,486 - INFO - 紡織纖維: 紡織纖維類報酬指數
# 2024-11-13 21:59:09,487 - INFO - 航運: 航運類報酬指數
# 2024-11-13 21:59:09,488 - INFO - 觀光: 觀光類報酬指數
# 2024-11-13 21:59:09,490 - INFO - 貿易百貨: 貿易百貨類報酬指數
# 2024-11-13 21:59:09,491 - INFO - 資訊服務: 資訊服務類報酬指數
# 2024-11-13 21:59:09,493 - INFO - 通信網路: 通信網路類報酬指數
# 2024-11-13 21:59:09,494 - INFO - 造紙: 造紙類報酬指數
# 2024-11-13 21:59:09,495 - INFO - 鋼鐵: 鋼鐵類報酬指數
# 2024-11-13 21:59:09,496 - INFO - 電器電纜: 電器電纜類報酬指數
# 2024-11-13 21:59:09,498 - INFO - 電子工: 電子工業類指數
# 2024-11-13 21:59:09,499 - INFO - 電子通路: 電子通路類報酬指數
# 2024-11-13 21:59:09,500 - INFO - 電子零組件: 電子零組件類報酬指數
# 2024-11-13 21:59:09,502 - INFO - 電機機械: 電機機械類報酬指數
# 2024-11-13 21:59:09,503 - INFO - 電腦及週邊設備: 電腦及週邊設備類報酬指數
# 2024-11-13 21:59:09,508 - INFO - 已保存相關性矩陣到: D:\Min\Python\Project\FA_Data\industry_correlation\weekly\industry_correlation_20230210.csv
# 生成週度相關性矩陣:   5%|███▏                                                           | 5/97 [00:00<00:17,  5.29it/s]2024-11-13 21:59:09,671 - INFO - 使用的指數類型:
# 2024-11-13 21:59:09,673 - INFO - 光電: 光電類報酬指數
# 2024-11-13 21:59:09,674 - INFO - 其他: 其他類報酬指數
# 2024-11-13 21:59:09,676 - INFO - 其他電子: 其他電子類報酬指數
# 2024-11-13 21:59:09,678 - INFO - 化學: 化學類報酬指數
# 2024-11-13 21:59:09,679 - INFO - 化學生技醫療: 化學生技醫療類報酬指數
# 2024-11-13 21:59:09,682 - INFO - 半導體: 半導體類報酬指數
# 2024-11-13 21:59:09,683 - INFO - 塑膠: 塑膠類報酬指數
# 2024-11-13 21:59:09,684 - INFO - 塑膠化工: 塑膠化工類指數
# 2024-11-13 21:59:09,686 - INFO - 建材營造: 建材營造類報酬指數
# 2024-11-13 21:59:09,687 - INFO - 橡膠: 橡膠類報酬指數
# 2024-11-13 21:59:09,689 - INFO - 水泥: 水泥類報酬指數
# 2024-11-13 21:59:09,690 - INFO - 水泥窯製: 水泥窯製類指數
# 2024-11-13 21:59:09,691 - INFO - 汽車: 汽車類報酬指數
# 2024-11-13 21:59:09,692 - INFO - 油電燃氣: 油電燃氣類報酬指數
# 2024-11-13 21:59:09,693 - INFO - 玻璃陶瓷: 玻璃陶瓷類報酬指數
# 2024-11-13 21:59:09,695 - INFO - 生技醫療: 生技醫療類報酬指數
# 2024-11-13 21:59:09,696 - INFO - 紡織纖維: 紡織纖維類報酬指數
# 2024-11-13 21:59:09,697 - INFO - 航運: 航運類報酬指數
# 2024-11-13 21:59:09,699 - INFO - 觀光: 觀光類報酬指數
# 2024-11-13 21:59:09,700 - INFO - 貿易百貨: 貿易百貨類報酬指數
# 2024-11-13 21:59:09,702 - INFO - 資訊服務: 資訊服務類報酬指數
# 2024-11-13 21:59:09,703 - INFO - 通信網路: 通信網路類報酬指數
# 2024-11-13 21:59:09,704 - INFO - 造紙: 造紙類報酬指數
# 2024-11-13 21:59:09,705 - INFO - 鋼鐵: 鋼鐵類報酬指數
# 2024-11-13 21:59:09,705 - INFO - 電器電纜: 電器電纜類報酬指數
# 2024-11-13 21:59:09,707 - INFO - 電子工: 電子工業類指數
# 2024-11-13 21:59:09,708 - INFO - 電子通路: 電子通路類報酬指數
# 2024-11-13 21:59:09,709 - INFO - 電子零組件: 電子零組件類報酬指數
# 2024-11-13 21:59:09,710 - INFO - 電機機械: 電機機械類報酬指數
# 2024-11-13 21:59:09,711 - INFO - 電腦及週邊設備: 電腦及週邊設備類報酬指數
# 2024-11-13 21:59:09,715 - INFO - 已保存相關性矩陣到: D:\Min\Python\Project\FA_Data\industry_correlation\weekly\industry_correlation_20230217.csv
# 生成週度相關性矩陣:   6%|███▉                                                           | 6/97 [00:01<00:17,  5.14it/s]2024-11-13 21:59:09,835 - INFO - 使用的指數類型:
# 2024-11-13 21:59:09,837 - INFO - 光電: 光電類報酬指數
# 2024-11-13 21:59:09,839 - INFO - 其他: 其他類報酬指數
# 2024-11-13 21:59:09,841 - INFO - 其他電子: 其他電子類報酬指數
# 2024-11-13 21:59:09,842 - INFO - 化學: 化學類報酬指數
# 2024-11-13 21:59:09,844 - INFO - 化學生技醫療: 化學生技醫療類報酬指數
# 2024-11-13 21:59:09,845 - INFO - 半導體: 半導體類報酬指數
# 2024-11-13 21:59:09,846 - INFO - 塑膠: 塑膠類報酬指數
# 2024-11-13 21:59:09,847 - INFO - 塑膠化工: 塑膠化工類指數
# 2024-11-13 21:59:09,848 - INFO - 建材營造: 建材營造類報酬指數
# 2024-11-13 21:59:09,850 - INFO - 橡膠: 橡膠類報酬指數
# 2024-11-13 21:59:09,852 - INFO - 水泥: 水泥類報酬指數
# 2024-11-13 21:59:09,853 - INFO - 水泥窯製: 水泥窯製類指數
# 2024-11-13 21:59:09,855 - INFO - 汽車: 汽車類報酬指數
# 2024-11-13 21:59:09,857 - INFO - 油電燃氣: 油電燃氣類報酬指數
# 2024-11-13 21:59:09,858 - INFO - 玻璃陶瓷: 玻璃陶瓷類報酬指數
# 2024-11-13 21:59:09,859 - INFO - 生技醫療: 生技醫療類報酬指數
# 2024-11-13 21:59:09,860 - INFO - 紡織纖維: 紡織纖維類報酬指數
# 2024-11-13 21:59:09,861 - INFO - 航運: 航運類報酬指數
# 2024-11-13 21:59:09,862 - INFO - 觀光: 觀光類報酬指數
# 2024-11-13 21:59:09,863 - INFO - 貿易百貨: 貿易百貨類報酬指數
# 2024-11-13 21:59:09,864 - INFO - 資訊服務: 資訊服務類報酬指數
# 2024-11-13 21:59:09,866 - INFO - 通信網路: 通信網路類報酬指數
# 2024-11-13 21:59:09,867 - INFO - 造紙: 造紙類報酬指數
# 2024-11-13 21:59:09,868 - INFO - 鋼鐵: 鋼鐵類報酬指數
# 2024-11-13 21:59:09,869 - INFO - 電器電纜: 電器電纜類報酬指數
# 2024-11-13 21:59:09,871 - INFO - 電子工: 電子工業類指數
# 2024-11-13 21:59:09,872 - INFO - 電子通路: 電子通路類報酬指數
# 2024-11-13 21:59:09,874 - INFO - 電子零組件: 電子零組件類報酬指數
# 2024-11-13 21:59:09,875 - INFO - 電機機械: 電機機械類報酬指數
# 2024-11-13 21:59:09,877 - INFO - 電腦及週邊設備: 電腦及週邊設備類報酬指數
# 2024-11-13 21:59:09,882 - INFO - 已保存相關性矩陣到: D:\Min\Python\Project\FA_Data\industry_correlation\weekly\industry_correlation_20230224.csv
# 生成週度相關性矩陣:   7%|████▌                                                          | 7/97 [00:01<00:16,  5.38it/s]2024-11-13 21:59:10,031 - INFO - 使用的指數類型:
# 2024-11-13 21:59:10,033 - INFO - 光電: 光電類報酬指數
# 2024-11-13 21:59:10,035 - INFO - 其他: 其他類報酬指數
# 2024-11-13 21:59:10,036 - INFO - 其他電子: 其他電子類報酬指數
# 2024-11-13 21:59:10,038 - INFO - 化學: 化學類報酬指數
# 2024-11-13 21:59:10,040 - INFO - 化學生技醫療: 化學生技醫療類報酬指數
# 2024-11-13 21:59:10,042 - INFO - 半導體: 半導體類報酬指數
# 2024-11-13 21:59:10,044 - INFO - 塑膠: 塑膠類報酬指數
# 2024-11-13 21:59:10,046 - INFO - 塑膠化工: 塑膠化工類指數
# 2024-11-13 21:59:10,047 - INFO - 建材營造: 建材營造類報酬指數
# 2024-11-13 21:59:10,051 - INFO - 橡膠: 橡膠類報酬指數
# 2024-11-13 21:59:10,053 - INFO - 水泥: 水泥類報酬指數
# 2024-11-13 21:59:10,056 - INFO - 水泥窯製: 水泥窯製類指數
# 2024-11-13 21:59:10,059 - INFO - 汽車: 汽車類報酬指數
# 2024-11-13 21:59:10,061 - INFO - 油電燃氣: 油電燃氣類報酬指數
# 2024-11-13 21:59:10,062 - INFO - 玻璃陶瓷: 玻璃陶瓷類報酬指數
# 2024-11-13 21:59:10,064 - INFO - 生技醫療: 生技醫療類報酬指數
# 2024-11-13 21:59:10,066 - INFO - 紡織纖維: 紡織纖維類報酬指數
# 2024-11-13 21:59:10,068 - INFO - 航運: 航運類報酬指數
# 2024-11-13 21:59:10,070 - INFO - 觀光: 觀光類報酬指數
# 2024-11-13 21:59:10,072 - INFO - 貿易百貨: 貿易百貨類報酬指數
# 2024-11-13 21:59:10,075 - INFO - 資訊服務: 資訊服務類報酬指數
# 2024-11-13 21:59:10,076 - INFO - 通信網路: 通信網路類報酬指數
# 2024-11-13 21:59:10,078 - INFO - 造紙: 造紙類報酬指數
# 2024-11-13 21:59:10,080 - INFO - 鋼鐵: 鋼鐵類報酬指數
# 2024-11-13 21:59:10,082 - INFO - 電器電纜: 電器電纜類報酬指數
# 2024-11-13 21:59:10,083 - INFO - 電子工: 電子工業類指數
# 2024-11-13 21:59:10,085 - INFO - 電子通路: 電子通路類報酬指數
# 2024-11-13 21:59:10,087 - INFO - 電子零組件: 電子零組件類報酬指數
# 2024-11-13 21:59:10,088 - INFO - 電機機械: 電機機械類報酬指數
# 2024-11-13 21:59:10,090 - INFO - 電腦及週邊設備: 電腦及週邊設備類報酬指數
# 2024-11-13 21:59:10,095 - INFO - 已保存相關性矩陣到: D:\Min\Python\Project\FA_Data\industry_correlation\weekly\industry_correlation_20230303.csv
# 生成週度相關性矩陣:   8%|█████▏                                                         | 8/97 [00:01<00:17,  5.14it/s]2024-11-13 21:59:10,233 - INFO - 使用的指數類型:
# 2024-11-13 21:59:10,235 - INFO - 光電: 光電類報酬指數
# 2024-11-13 21:59:10,236 - INFO - 其他: 其他類報酬指數
# 2024-11-13 21:59:10,238 - INFO - 其他電子: 其他電子類報酬指數
# 2024-11-13 21:59:10,239 - INFO - 化學: 化學類報酬指數
# 2024-11-13 21:59:10,242 - INFO - 化學生技醫療: 化學生技醫療類報酬指數
# 2024-11-13 21:59:10,243 - INFO - 半導體: 半導體類報酬指數
# 2024-11-13 21:59:10,245 - INFO - 塑膠: 塑膠類報酬指數
# 2024-11-13 21:59:10,246 - INFO - 塑膠化工: 塑膠化工類指數
# 2024-11-13 21:59:10,248 - INFO - 建材營造: 建材營造類報酬指數
# 2024-11-13 21:59:10,250 - INFO - 橡膠: 橡膠類報酬指數
# 2024-11-13 21:59:10,251 - INFO - 水泥: 水泥類報酬指數
# 2024-11-13 21:59:10,252 - INFO - 水泥窯製: 水泥窯製類指數
# 2024-11-13 21:59:10,254 - INFO - 汽車: 汽車類報酬指數
# 2024-11-13 21:59:10,255 - INFO - 油電燃氣: 油電燃氣類報酬指數
# 2024-11-13 21:59:10,256 - INFO - 玻璃陶瓷: 玻璃陶瓷類報酬指數
# 2024-11-13 21:59:10,257 - INFO - 生技醫療: 生技醫療類報酬指數
# 2024-11-13 21:59:10,258 - INFO - 紡織纖維: 紡織纖維類報酬指數
# 2024-11-13 21:59:10,259 - INFO - 航運: 航運類報酬指數
# 2024-11-13 21:59:10,261 - INFO - 觀光: 觀光類報酬指數
# 2024-11-13 21:59:10,262 - INFO - 貿易百貨: 貿易百貨類報酬指數
# 2024-11-13 21:59:10,264 - INFO - 資訊服務: 資訊服務類報酬指數
# 2024-11-13 21:59:10,265 - INFO - 通信網路: 通信網路類報酬指數
# 2024-11-13 21:59:10,266 - INFO - 造紙: 造紙類報酬指數
# 2024-11-13 21:59:10,267 - INFO - 鋼鐵: 鋼鐵類報酬指數
# 2024-11-13 21:59:10,268 - INFO - 電器電纜: 電器電纜類報酬指數
# 2024-11-13 21:59:10,270 - INFO - 電子工: 電子工業類指數
# 2024-11-13 21:59:10,271 - INFO - 電子通路: 電子通路類報酬指數
# 2024-11-13 21:59:10,272 - INFO - 電子零組件: 電子零組件類報酬指數
# 2024-11-13 21:59:10,273 - INFO - 電機機械: 電機機械類報酬指數
# 2024-11-13 21:59:10,275 - INFO - 電腦及週邊設備: 電腦及週邊設備類報酬指數
# 2024-11-13 21:59:10,280 - INFO - 已保存相關性矩陣到: D:\Min\Python\Project\FA_Data\industry_correlation\weekly\industry_correlation_20230310.csv
# 生成週度相關性矩陣:   9%|█████▊                                                         | 9/97 [00:01<00:16,  5.22it/s]2024-11-13 21:59:10,404 - INFO - 使用的指數類型:
# 2024-11-13 21:59:10,407 - INFO - 光電: 光電類報酬指數
# 2024-11-13 21:59:10,408 - INFO - 其他: 其他類報酬指數
# 2024-11-13 21:59:10,410 - INFO - 其他電子: 其他電子類報酬指數
# 2024-11-13 21:59:10,411 - INFO - 化學: 化學類報酬指數
# 2024-11-13 21:59:10,412 - INFO - 化學生技醫療: 化學生技醫療類報酬指數
# 2024-11-13 21:59:10,413 - INFO - 半導體: 半導體類報酬指數
# 2024-11-13 21:59:10,414 - INFO - 塑膠: 塑膠類報酬指數
# 2024-11-13 21:59:10,416 - INFO - 塑膠化工: 塑膠化工類指數
# 2024-11-13 21:59:10,417 - INFO - 建材營造: 建材營造類報酬指數
# 2024-11-13 21:59:10,419 - INFO - 橡膠: 橡膠類報酬指數
# 2024-11-13 21:59:10,420 - INFO - 水泥: 水泥類報酬指數
# 2024-11-13 21:59:10,421 - INFO - 水泥窯製: 水泥窯製類指數
# 2024-11-13 21:59:10,423 - INFO - 汽車: 汽車類報酬指數
# 2024-11-13 21:59:10,425 - INFO - 油電燃氣: 油電燃氣類報酬指數
# 2024-11-13 21:59:10,426 - INFO - 玻璃陶瓷: 玻璃陶瓷類報酬指數
# 2024-11-13 21:59:10,427 - INFO - 生技醫療: 生技醫療類報酬指數
# 2024-11-13 21:59:10,429 - INFO - 紡織纖維: 紡織纖維類報酬指數
# 2024-11-13 21:59:10,430 - INFO - 航運: 航運類報酬指數
# 2024-11-13 21:59:10,431 - INFO - 觀光: 觀光類報酬指數
# 2024-11-13 21:59:10,432 - INFO - 貿易百貨: 貿易百貨類報酬指數
# 2024-11-13 21:59:10,433 - INFO - 資訊服務: 資訊服務類報酬指數
# 2024-11-13 21:59:10,435 - INFO - 通信網路: 通信網路類報酬指數
# 2024-11-13 21:59:10,436 - INFO - 造紙: 造紙類報酬指數
# 2024-11-13 21:59:10,437 - INFO - 鋼鐵: 鋼鐵類報酬指數
# 2024-11-13 21:59:10,438 - INFO - 電器電纜: 電器電纜類報酬指數
# 2024-11-13 21:59:10,440 - INFO - 電子工: 電子工業類指數
# 2024-11-13 21:59:10,441 - INFO - 電子通路: 電子通路類報酬指數
# 2024-11-13 21:59:10,442 - INFO - 電子零組件: 電子零組件類報酬指數
# 2024-11-13 21:59:10,444 - INFO - 電機機械: 電機機械類報酬指數
# 2024-11-13 21:59:10,445 - INFO - 電腦及週邊設備: 電腦及週邊設備類報酬指數
# 2024-11-13 21:59:10,451 - INFO - 已保存相關性矩陣到: D:\Min\Python\Project\FA_Data\industry_correlation\weekly\industry_correlation_20230317.csv
# 生成週度相關性矩陣:  10%|██████▍                                                       | 10/97 [00:01<00:16,  5.40it/s]2024-11-13 21:59:10,596 - INFO - 使用的指數類型:
# 2024-11-13 21:59:10,598 - INFO - 光電: 光電類報酬指數
# 2024-11-13 21:59:10,600 - INFO - 其他: 其他類報酬指數
# 2024-11-13 21:59:10,601 - INFO - 其他電子: 其他電子類報酬指數
# 2024-11-13 21:59:10,602 - INFO - 化學: 化學類報酬指數
# 2024-11-13 21:59:10,604 - INFO - 化學生技醫療: 化學生技醫療類報酬指數
# 2024-11-13 21:59:10,605 - INFO - 半導體: 半導體類報酬指數
# 2024-11-13 21:59:10,607 - INFO - 塑膠: 塑膠類報酬指數
# 2024-11-13 21:59:10,608 - INFO - 塑膠化工: 塑膠化工類指數
# 2024-11-13 21:59:10,609 - INFO - 建材營造: 建材營造類報酬指數
# 2024-11-13 21:59:10,612 - INFO - 橡膠: 橡膠類報酬指數
# 2024-11-13 21:59:10,612 - INFO - 水泥: 水泥類報酬指數
# 2024-11-13 21:59:10,613 - INFO - 水泥窯製: 水泥窯製類指數
# 2024-11-13 21:59:10,614 - INFO - 汽車: 汽車類報酬指數
# 2024-11-13 21:59:10,615 - INFO - 油電燃氣: 油電燃氣類報酬指數
# 2024-11-13 21:59:10,615 - INFO - 玻璃陶瓷: 玻璃陶瓷類報酬指數
# 2024-11-13 21:59:10,617 - INFO - 生技醫療: 生技醫療類報酬指數
# 2024-11-13 21:59:10,618 - INFO - 紡織纖維: 紡織纖維類報酬指數
# 2024-11-13 21:59:10,620 - INFO - 航運: 航運類報酬指數
# 2024-11-13 21:59:10,622 - INFO - 觀光: 觀光類報酬指數
# 2024-11-13 21:59:10,623 - INFO - 貿易百貨: 貿易百貨類報酬指數
# 2024-11-13 21:59:10,624 - INFO - 資訊服務: 資訊服務類報酬指數
# 2024-11-13 21:59:10,625 - INFO - 通信網路: 通信網路類報酬指數
# 2024-11-13 21:59:10,626 - INFO - 造紙: 造紙類報酬指數
# 2024-11-13 21:59:10,627 - INFO - 鋼鐵: 鋼鐵類報酬指數
# 2024-11-13 21:59:10,628 - INFO - 電器電纜: 電器電纜類報酬指數
# 2024-11-13 21:59:10,629 - INFO - 電子工: 電子工業類指數
# 2024-11-13 21:59:10,630 - INFO - 電子通路: 電子通路類報酬指數
# 2024-11-13 21:59:10,631 - INFO - 電子零組件: 電子零組件類報酬指數
# 2024-11-13 21:59:10,632 - INFO - 電機機械: 電機機械類報酬指數
# 2024-11-13 21:59:10,633 - INFO - 電腦及週邊設備: 電腦及週邊設備類報酬指數
# 2024-11-13 21:59:10,638 - INFO - 已保存相關性矩陣到: D:\Min\Python\Project\FA_Data\industry_correlation\weekly\industry_correlation_20230324.csv
# 生成週度相關性矩陣:  11%|███████                                                       | 11/97 [00:02<00:15,  5.40it/s]2024-11-13 21:59:10,744 - INFO - 使用的指數類型:
# 2024-11-13 21:59:10,745 - INFO - 光電: 光電類報酬指數
# 2024-11-13 21:59:10,746 - INFO - 其他: 其他類報酬指數
# 2024-11-13 21:59:10,749 - INFO - 其他電子: 其他電子類報酬指數
# 2024-11-13 21:59:10,751 - INFO - 化學: 化學類報酬指數
# 2024-11-13 21:59:10,753 - INFO - 化學生技醫療: 化學生技醫療類報酬指數
# 2024-11-13 21:59:10,755 - INFO - 半導體: 半導體類報酬指數
# 2024-11-13 21:59:10,757 - INFO - 塑膠: 塑膠類報酬指數
# 2024-11-13 21:59:10,759 - INFO - 塑膠化工: 塑膠化工類指數
# 2024-11-13 21:59:10,760 - INFO - 建材營造: 建材營造類報酬指數
# 2024-11-13 21:59:10,762 - INFO - 橡膠: 橡膠類報酬指數
# 2024-11-13 21:59:10,764 - INFO - 水泥: 水泥類報酬指數
# 2024-11-13 21:59:10,767 - INFO - 水泥窯製: 水泥窯製類指數
# 2024-11-13 21:59:10,769 - INFO - 汽車: 汽車類報酬指數
# 2024-11-13 21:59:10,770 - INFO - 油電燃氣: 油電燃氣類報酬指數
# 2024-11-13 21:59:10,772 - INFO - 玻璃陶瓷: 玻璃陶瓷類報酬指數
# 2024-11-13 21:59:10,774 - INFO - 生技醫療: 生技醫療類報酬指數
# 2024-11-13 21:59:10,775 - INFO - 紡織纖維: 紡織纖維類報酬指數
# 2024-11-13 21:59:10,777 - INFO - 航運: 航運類報酬指數
# 2024-11-13 21:59:10,779 - INFO - 觀光: 觀光類報酬指數
# 2024-11-13 21:59:10,781 - INFO - 貿易百貨: 貿易百貨類報酬指數
# 2024-11-13 21:59:10,783 - INFO - 資訊服務: 資訊服務類報酬指數
# 2024-11-13 21:59:10,784 - INFO - 通信網路: 通信網路類報酬指數
# 2024-11-13 21:59:10,786 - INFO - 造紙: 造紙類報酬指數
# 2024-11-13 21:59:10,788 - INFO - 鋼鐵: 鋼鐵類報酬指數
# 2024-11-13 21:59:10,790 - INFO - 電器電纜: 電器電纜類報酬指數
# 2024-11-13 21:59:10,791 - INFO - 電子工: 電子工業類指數
# 2024-11-13 21:59:10,792 - INFO - 電子通路: 電子通路類報酬指數
# 2024-11-13 21:59:10,794 - INFO - 電子零組件: 電子零組件類報酬指數
# 2024-11-13 21:59:10,795 - INFO - 電機機械: 電機機械類報酬指數
# 2024-11-13 21:59:10,796 - INFO - 電腦及週邊設備: 電腦及週邊設備類報酬指數
# 2024-11-13 21:59:10,801 - INFO - 已保存相關性矩陣到: D:\Min\Python\Project\FA_Data\industry_correlation\weekly\industry_correlation_20230331.csv
# 生成週度相關性矩陣:  12%|███████▋                                                      | 12/97 [00:02<00:15,  5.60it/s]2024-11-13 21:59:10,938 - INFO - 使用的指數類型:
# 2024-11-13 21:59:10,941 - INFO - 光電: 光電類報酬指數
# 2024-11-13 21:59:10,942 - INFO - 其他: 其他類報酬指數
# 2024-11-13 21:59:10,944 - INFO - 其他電子: 其他電子類報酬指數
# 2024-11-13 21:59:10,945 - INFO - 化學: 化學類報酬指數
# 2024-11-13 21:59:10,947 - INFO - 化學生技醫療: 化學生技醫療類報酬指數
# 2024-11-13 21:59:10,949 - INFO - 半導體: 半導體類報酬指數
# 2024-11-13 21:59:10,950 - INFO - 塑膠: 塑膠類報酬指數
# 2024-11-13 21:59:10,951 - INFO - 塑膠化工: 塑膠化工類指數
# 2024-11-13 21:59:10,952 - INFO - 建材營造: 建材營造類報酬指數
# 2024-11-13 21:59:10,954 - INFO - 橡膠: 橡膠類報酬指數
# 2024-11-13 21:59:10,955 - INFO - 水泥: 水泥類報酬指數
# 2024-11-13 21:59:10,956 - INFO - 水泥窯製: 水泥窯製類指數
# 2024-11-13 21:59:10,957 - INFO - 汽車: 汽車類報酬指數
# 2024-11-13 21:59:10,959 - INFO - 油電燃氣: 油電燃氣類報酬指數
# 2024-11-13 21:59:10,960 - INFO - 玻璃陶瓷: 玻璃陶瓷類報酬指數
# 2024-11-13 21:59:10,961 - INFO - 生技醫療: 生技醫療類報酬指數
# 2024-11-13 21:59:10,963 - INFO - 紡織纖維: 紡織纖維類報酬指數
# 2024-11-13 21:59:10,964 - INFO - 航運: 航運類報酬指數
# 2024-11-13 21:59:10,966 - INFO - 觀光: 觀光類報酬指數
# 2024-11-13 21:59:10,968 - INFO - 貿易百貨: 貿易百貨類報酬指數
# 2024-11-13 21:59:10,969 - INFO - 資訊服務: 資訊服務類報酬指數
# 2024-11-13 21:59:10,971 - INFO - 通信網路: 通信網路類報酬指數
# 2024-11-13 21:59:10,973 - INFO - 造紙: 造紙類報酬指數
# 2024-11-13 21:59:10,975 - INFO - 鋼鐵: 鋼鐵類報酬指數
# 2024-11-13 21:59:10,978 - INFO - 電器電纜: 電器電纜類報酬指數
# 2024-11-13 21:59:10,980 - INFO - 電子工: 電子工業類指數
# 2024-11-13 21:59:10,983 - INFO - 電子通路: 電子通路類報酬指數
# 2024-11-13 21:59:10,984 - INFO - 電子零組件: 電子零組件類報酬指數
# 2024-11-13 21:59:10,985 - INFO - 電機機械: 電機機械類報酬指數
# 2024-11-13 21:59:10,987 - INFO - 電腦及週邊設備: 電腦及週邊設備類報酬指數
# 2024-11-13 21:59:10,991 - INFO - 已保存相關性矩陣到: D:\Min\Python\Project\FA_Data\industry_correlation\weekly\industry_correlation_20230407.csv
# 生成週度相關性矩陣:  13%|████████▎                                                     | 13/97 [00:02<00:15,  5.48it/s]2024-11-13 21:59:11,161 - INFO - 使用的指數類型:
# 2024-11-13 21:59:11,165 - INFO - 光電: 光電類報酬指數
# 2024-11-13 21:59:11,167 - INFO - 其他: 其他類報酬指數
# 2024-11-13 21:59:11,168 - INFO - 其他電子: 其他電子類報酬指數
# 2024-11-13 21:59:11,169 - INFO - 化學: 化學類報酬指數
# 2024-11-13 21:59:11,171 - INFO - 化學生技醫療: 化學生技醫療類報酬指數
# 2024-11-13 21:59:11,172 - INFO - 半導體: 半導體類報酬指數
# 2024-11-13 21:59:11,173 - INFO - 塑膠: 塑膠類報酬指數
# 2024-11-13 21:59:11,174 - INFO - 塑膠化工: 塑膠化工類指數
# 2024-11-13 21:59:11,175 - INFO - 建材營造: 建材營造類報酬指數
# 2024-11-13 21:59:11,176 - INFO - 橡膠: 橡膠類報酬指數
# 2024-11-13 21:59:11,177 - INFO - 水泥: 水泥類報酬指數
# 2024-11-13 21:59:11,179 - INFO - 水泥窯製: 水泥窯製類指數
# 2024-11-13 21:59:11,180 - INFO - 汽車: 汽車類報酬指數
# 2024-11-13 21:59:11,181 - INFO - 油電燃氣: 油電燃氣類報酬指數
# 2024-11-13 21:59:11,182 - INFO - 玻璃陶瓷: 玻璃陶瓷類報酬指數
# 2024-11-13 21:59:11,184 - INFO - 生技醫療: 生技醫療類報酬指數
# 2024-11-13 21:59:11,185 - INFO - 紡織纖維: 紡織纖維類報酬指數
# 2024-11-13 21:59:11,186 - INFO - 航運: 航運類報酬指數
# 2024-11-13 21:59:11,187 - INFO - 觀光: 觀光類報酬指數
# 2024-11-13 21:59:11,189 - INFO - 貿易百貨: 貿易百貨類報酬指數
# 2024-11-13 21:59:11,190 - INFO - 資訊服務: 資訊服務類報酬指數
# 2024-11-13 21:59:11,191 - INFO - 通信網路: 通信網路類報酬指數
# 2024-11-13 21:59:11,192 - INFO - 造紙: 造紙類報酬指數
# 2024-11-13 21:59:11,194 - INFO - 鋼鐵: 鋼鐵類報酬指數
# 2024-11-13 21:59:11,195 - INFO - 電器電纜: 電器電纜類報酬指數
# 2024-11-13 21:59:11,196 - INFO - 電子工: 電子工業類指數
# 2024-11-13 21:59:11,198 - INFO - 電子通路: 電子通路類報酬指數
# 2024-11-13 21:59:11,200 - INFO - 電子零組件: 電子零組件類報酬指數
# 2024-11-13 21:59:11,201 - INFO - 電機機械: 電機機械類報酬指數
# 2024-11-13 21:59:11,202 - INFO - 電腦及週邊設備: 電腦及週邊設備類報酬指數
# 2024-11-13 21:59:11,208 - INFO - 已保存相關性矩陣到: D:\Min\Python\Project\FA_Data\industry_correlation\weekly\industry_correlation_20230414.csv
# 生成週度相關性矩陣:  14%|████████▉                                                     | 14/97 [00:02<00:15,  5.20it/s]2024-11-13 21:59:11,350 - INFO - 使用的指數類型:
# 2024-11-13 21:59:11,352 - INFO - 光電: 光電類報酬指數
# 2024-11-13 21:59:11,353 - INFO - 其他: 其他類報酬指數
# 2024-11-13 21:59:11,354 - INFO - 其他電子: 其他電子類報酬指數
# 2024-11-13 21:59:11,355 - INFO - 化學: 化學類報酬指數
# 2024-11-13 21:59:11,358 - INFO - 化學生技醫療: 化學生技醫療類報酬指數
# 2024-11-13 21:59:11,359 - INFO - 半導體: 半導體類報酬指數
# 2024-11-13 21:59:11,360 - INFO - 塑膠: 塑膠類報酬指數
# 2024-11-13 21:59:11,361 - INFO - 塑膠化工: 塑膠化工類指數
# 2024-11-13 21:59:11,362 - INFO - 建材營造: 建材營造類報酬指數
# 2024-11-13 21:59:11,363 - INFO - 橡膠: 橡膠類報酬指數
# 2024-11-13 21:59:11,364 - INFO - 水泥: 水泥類報酬指數
# 2024-11-13 21:59:11,365 - INFO - 水泥窯製: 水泥窯製類指數
# 2024-11-13 21:59:11,366 - INFO - 汽車: 汽車類報酬指數
# 2024-11-13 21:59:11,367 - INFO - 油電燃氣: 油電燃氣類報酬指數
# 2024-11-13 21:59:11,368 - INFO - 玻璃陶瓷: 玻璃陶瓷類報酬指數
# 2024-11-13 21:59:11,370 - INFO - 生技醫療: 生技醫療類報酬指數
# 2024-11-13 21:59:11,371 - INFO - 紡織纖維: 紡織纖維類報酬指數
# 2024-11-13 21:59:11,372 - INFO - 航運: 航運類報酬指數
# 2024-11-13 21:59:11,373 - INFO - 觀光: 觀光類報酬指數
# 2024-11-13 21:59:11,374 - INFO - 貿易百貨: 貿易百貨類報酬指數
# 2024-11-13 21:59:11,375 - INFO - 資訊服務: 資訊服務類報酬指數
# 2024-11-13 21:59:11,376 - INFO - 通信網路: 通信網路類報酬指數
# 2024-11-13 21:59:11,378 - INFO - 造紙: 造紙類報酬指數
# 2024-11-13 21:59:11,379 - INFO - 鋼鐵: 鋼鐵類報酬指數
# 2024-11-13 21:59:11,380 - INFO - 電器電纜: 電器電纜類報酬指數
# 2024-11-13 21:59:11,381 - INFO - 電子工: 電子工業類指數
# 2024-11-13 21:59:11,382 - INFO - 電子通路: 電子通路類報酬指數
# 2024-11-13 21:59:11,383 - INFO - 電子零組件: 電子零組件類報酬指數
# 2024-11-13 21:59:11,385 - INFO - 電機機械: 電機機械類報酬指數
# 2024-11-13 21:59:11,386 - INFO - 電腦及週邊設備: 電腦及週邊設備類報酬指數
# 2024-11-13 21:59:11,392 - INFO - 已保存相關性矩陣到: D:\Min\Python\Project\FA_Data\industry_correlation\weekly\industry_correlation_20230421.csv
# 生成週度相關性矩陣:  15%|█████████▌                                                    | 15/97 [00:02<00:15,  5.27it/s]2024-11-13 21:59:11,535 - INFO - 使用的指數類型:
# 2024-11-13 21:59:11,536 - INFO - 光電: 光電類報酬指數
# 2024-11-13 21:59:11,538 - INFO - 其他: 其他類報酬指數
# 2024-11-13 21:59:11,540 - INFO - 其他電子: 其他電子類報酬指數
# 2024-11-13 21:59:11,542 - INFO - 化學: 化學類報酬指數
# 2024-11-13 21:59:11,544 - INFO - 化學生技醫療: 化學生技醫療類報酬指數
# 2024-11-13 21:59:11,545 - INFO - 半導體: 半導體類報酬指數
# 2024-11-13 21:59:11,546 - INFO - 塑膠: 塑膠類報酬指數
# 2024-11-13 21:59:11,547 - INFO - 塑膠化工: 塑膠化工類指數
# 2024-11-13 21:59:11,548 - INFO - 建材營造: 建材營造類報酬指數
# 2024-11-13 21:59:11,550 - INFO - 橡膠: 橡膠類報酬指數
# 2024-11-13 21:59:11,551 - INFO - 水泥: 水泥類報酬指數
# 2024-11-13 21:59:11,552 - INFO - 水泥窯製: 水泥窯製類指數
# 2024-11-13 21:59:11,554 - INFO - 汽車: 汽車類報酬指數
# 2024-11-13 21:59:11,555 - INFO - 油電燃氣: 油電燃氣類報酬指數
# 2024-11-13 21:59:11,556 - INFO - 玻璃陶瓷: 玻璃陶瓷類報酬指數
# 2024-11-13 21:59:11,557 - INFO - 生技醫療: 生技醫療類報酬指數
# 2024-11-13 21:59:11,558 - INFO - 紡織纖維: 紡織纖維類報酬指數
# 2024-11-13 21:59:11,560 - INFO - 航運: 航運類報酬指數
# 2024-11-13 21:59:11,561 - INFO - 觀光: 觀光類報酬指數
# 2024-11-13 21:59:11,562 - INFO - 貿易百貨: 貿易百貨類報酬指數
# 2024-11-13 21:59:11,564 - INFO - 資訊服務: 資訊服務類報酬指數
# 2024-11-13 21:59:11,565 - INFO - 通信網路: 通信網路類報酬指數
# 2024-11-13 21:59:11,566 - INFO - 造紙: 造紙類報酬指數
# 2024-11-13 21:59:11,567 - INFO - 鋼鐵: 鋼鐵類報酬指數
# 2024-11-13 21:59:11,569 - INFO - 電器電纜: 電器電纜類報酬指數
# 2024-11-13 21:59:11,570 - INFO - 電子工: 電子工業類指數
# 2024-11-13 21:59:11,571 - INFO - 電子通路: 電子通路類報酬指數
# 2024-11-13 21:59:11,573 - INFO - 電子零組件: 電子零組件類報酬指數
# 2024-11-13 21:59:11,575 - INFO - 電機機械: 電機機械類報酬指數
# 2024-11-13 21:59:11,576 - INFO - 電腦及週邊設備: 電腦及週邊設備類報酬指數
# 2024-11-13 21:59:11,582 - INFO - 已保存相關性矩陣到: D:\Min\Python\Project\FA_Data\industry_correlation\weekly\industry_correlation_20230428.csv
# 生成週度相關性矩陣:  16%|██████████▏                                                   | 16/97 [00:03<00:15,  5.26it/s]2024-11-13 21:59:11,726 - INFO - 使用的指數類型:
# 2024-11-13 21:59:11,729 - INFO - 光電: 光電類報酬指數
# 2024-11-13 21:59:11,731 - INFO - 其他: 其他類報酬指數
# 2024-11-13 21:59:11,732 - INFO - 其他電子: 其他電子類報酬指數
# 2024-11-13 21:59:11,734 - INFO - 化學: 化學類報酬指數
# 2024-11-13 21:59:11,735 - INFO - 化學生技醫療: 化學生技醫療類報酬指數
# 2024-11-13 21:59:11,736 - INFO - 半導體: 半導體類報酬指數
# 2024-11-13 21:59:11,737 - INFO - 塑膠: 塑膠類報酬指數
# 2024-11-13 21:59:11,739 - INFO - 塑膠化工: 塑膠化工類指數
# 2024-11-13 21:59:11,740 - INFO - 建材營造: 建材營造類報酬指數
# 2024-11-13 21:59:11,741 - INFO - 橡膠: 橡膠類報酬指數
# 2024-11-13 21:59:11,743 - INFO - 水泥: 水泥類報酬指數
# 2024-11-13 21:59:11,744 - INFO - 水泥窯製: 水泥窯製類指數
# 2024-11-13 21:59:11,745 - INFO - 汽車: 汽車類報酬指數
# 2024-11-13 21:59:11,747 - INFO - 油電燃氣: 油電燃氣類報酬指數
# 2024-11-13 21:59:11,748 - INFO - 玻璃陶瓷: 玻璃陶瓷類報酬指數
# 2024-11-13 21:59:11,749 - INFO - 生技醫療: 生技醫療類報酬指數
# 2024-11-13 21:59:11,750 - INFO - 紡織纖維: 紡織纖維類報酬指數
# 2024-11-13 21:59:11,752 - INFO - 航運: 航運類報酬指數
# 2024-11-13 21:59:11,753 - INFO - 觀光: 觀光類報酬指數
# 2024-11-13 21:59:11,755 - INFO - 貿易百貨: 貿易百貨類報酬指數
# 2024-11-13 21:59:11,757 - INFO - 資訊服務: 資訊服務類報酬指數
# 2024-11-13 21:59:11,758 - INFO - 通信網路: 通信網路類報酬指數
# 2024-11-13 21:59:11,760 - INFO - 造紙: 造紙類報酬指數
# 2024-11-13 21:59:11,761 - INFO - 鋼鐵: 鋼鐵類報酬指數
# 2024-11-13 21:59:11,762 - INFO - 電器電纜: 電器電纜類報酬指數
# 2024-11-13 21:59:11,764 - INFO - 電子工: 電子工業類指數
# 2024-11-13 21:59:11,766 - INFO - 電子通路: 電子通路類報酬指數
# 2024-11-13 21:59:11,768 - INFO - 電子零組件: 電子零組件類報酬指數
# 2024-11-13 21:59:11,770 - INFO - 電機機械: 電機機械類報酬指數
# 2024-11-13 21:59:11,772 - INFO - 電腦及週邊設備: 電腦及週邊設備類報酬指數
# 2024-11-13 21:59:11,776 - INFO - 已保存相關性矩陣到: D:\Min\Python\Project\FA_Data\industry_correlation\weekly\industry_correlation_20230505.csv
# 生成週度相關性矩陣:  18%|██████████▊                                                   | 17/97 [00:03<00:15,  5.23it/s]2024-11-13 21:59:12,128 - INFO - 使用的指數類型:
# 2024-11-13 21:59:12,130 - INFO - 光電: 光電類報酬指數
# 2024-11-13 21:59:12,132 - INFO - 其他: 其他類報酬指數
# 2024-11-13 21:59:12,134 - INFO - 其他電子: 其他電子類報酬指數
# 2024-11-13 21:59:12,135 - INFO - 化學: 化學類報酬指數
# 2024-11-13 21:59:12,137 - INFO - 化學生技醫療: 化學生技醫療類報酬指數
# 2024-11-13 21:59:12,139 - INFO - 半導體: 半導體類報酬指數
# 2024-11-13 21:59:12,140 - INFO - 塑膠: 塑膠類報酬指數
# 2024-11-13 21:59:12,141 - INFO - 塑膠化工: 塑膠化工類指數
# 2024-11-13 21:59:12,142 - INFO - 建材營造: 建材營造類報酬指數
# 2024-11-13 21:59:12,143 - INFO - 橡膠: 橡膠類報酬指數
# 2024-11-13 21:59:12,144 - INFO - 水泥: 水泥類報酬指數
# 2024-11-13 21:59:12,145 - INFO - 水泥窯製: 水泥窯製類指數
# 2024-11-13 21:59:12,146 - INFO - 汽車: 汽車類報酬指數
# 2024-11-13 21:59:12,148 - INFO - 油電燃氣: 油電燃氣類報酬指數
# 2024-11-13 21:59:12,149 - INFO - 玻璃陶瓷: 玻璃陶瓷類報酬指數
# 2024-11-13 21:59:12,150 - INFO - 生技醫療: 生技醫療類報酬指數
# 2024-11-13 21:59:12,151 - INFO - 紡織纖維: 紡織纖維類報酬指數
# 2024-11-13 21:59:12,153 - INFO - 航運: 航運類報酬指數
# 2024-11-13 21:59:12,154 - INFO - 觀光: 觀光類報酬指數
# 2024-11-13 21:59:12,156 - INFO - 貿易百貨: 貿易百貨類報酬指數
# 2024-11-13 21:59:12,158 - INFO - 資訊服務: 資訊服務類報酬指數
# 2024-11-13 21:59:12,160 - INFO - 通信網路: 通信網路類報酬指數
# 2024-11-13 21:59:12,162 - INFO - 造紙: 造紙類報酬指數
# 2024-11-13 21:59:12,166 - INFO - 鋼鐵: 鋼鐵類報酬指數
# 2024-11-13 21:59:12,168 - INFO - 電器電纜: 電器電纜類報酬指數
# 2024-11-13 21:59:12,171 - INFO - 電子工: 電子工業類指數
# 2024-11-13 21:59:12,174 - INFO - 電子通路: 電子通路類報酬指數
# 2024-11-13 21:59:12,177 - INFO - 電子零組件: 電子零組件類報酬指數
# 2024-11-13 21:59:12,180 - INFO - 電機機械: 電機機械類報酬指數
# 2024-11-13 21:59:12,182 - INFO - 電腦及週邊設備: 電腦及週邊設備類報酬指數
# 2024-11-13 21:59:12,188 - INFO - 已保存相關性矩陣到: D:\Min\Python\Project\FA_Data\industry_correlation\weekly\industry_correlation_20230512.csv
# 生成週度相關性矩陣:  19%|███████████▌                                                  | 18/97 [00:03<00:20,  3.88it/s]2024-11-13 21:59:12,331 - INFO - 使用的指數類型:
# 2024-11-13 21:59:12,333 - INFO - 光電: 光電類報酬指數
# 2024-11-13 21:59:12,335 - INFO - 其他: 其他類報酬指數
# 2024-11-13 21:59:12,336 - INFO - 其他電子: 其他電子類報酬指數
# 2024-11-13 21:59:12,338 - INFO - 化學: 化學類報酬指數
# 2024-11-13 21:59:12,340 - INFO - 化學生技醫療: 化學生技醫療類報酬指數
# 2024-11-13 21:59:12,342 - INFO - 半導體: 半導體類報酬指數
# 2024-11-13 21:59:12,344 - INFO - 塑膠: 塑膠類報酬指數
# 2024-11-13 21:59:12,346 - INFO - 塑膠化工: 塑膠化工類指數
# 2024-11-13 21:59:12,348 - INFO - 建材營造: 建材營造類報酬指數
# 2024-11-13 21:59:12,349 - INFO - 橡膠: 橡膠類報酬指數
# 2024-11-13 21:59:12,351 - INFO - 水泥: 水泥類報酬指數
# 2024-11-13 21:59:12,353 - INFO - 水泥窯製: 水泥窯製類指數
# 2024-11-13 21:59:12,355 - INFO - 汽車: 汽車類報酬指數
# 2024-11-13 21:59:12,356 - INFO - 油電燃氣: 油電燃氣類報酬指數
# 2024-11-13 21:59:12,357 - INFO - 玻璃陶瓷: 玻璃陶瓷類報酬指數
# 2024-11-13 21:59:12,358 - INFO - 生技醫療: 生技醫療類報酬指數
# 2024-11-13 21:59:12,360 - INFO - 紡織纖維: 紡織纖維類報酬指數
# 2024-11-13 21:59:12,361 - INFO - 航運: 航運類報酬指數
# 2024-11-13 21:59:12,362 - INFO - 觀光: 觀光類報酬指數
# 2024-11-13 21:59:12,363 - INFO - 貿易百貨: 貿易百貨類報酬指數
# 2024-11-13 21:59:12,365 - INFO - 資訊服務: 資訊服務類報酬指數
# 2024-11-13 21:59:12,367 - INFO - 通信網路: 通信網路類報酬指數
# 2024-11-13 21:59:12,368 - INFO - 造紙: 造紙類報酬指數
# 2024-11-13 21:59:12,369 - INFO - 鋼鐵: 鋼鐵類報酬指數
# 2024-11-13 21:59:12,371 - INFO - 電器電纜: 電器電纜類報酬指數
# 2024-11-13 21:59:12,373 - INFO - 電子工: 電子工業類指數
# 2024-11-13 21:59:12,373 - INFO - 電子通路: 電子通路類報酬指數
# 2024-11-13 21:59:12,375 - INFO - 電子零組件: 電子零組件類報酬指數
# 2024-11-13 21:59:12,377 - INFO - 電機機械: 電機機械類報酬指數
# 2024-11-13 21:59:12,379 - INFO - 電腦及週邊設備: 電腦及週邊設備類報酬指數
# 2024-11-13 21:59:12,385 - INFO - 已保存相關性矩陣到: D:\Min\Python\Project\FA_Data\industry_correlation\weekly\industry_correlation_20230519.csv
# 生成週度相關性矩陣:  20%|████████████▏                                                 | 19/97 [00:03<00:18,  4.17it/s]2024-11-13 21:59:12,516 - INFO - 使用的指數類型:
# 2024-11-13 21:59:12,518 - INFO - 光電: 光電類報酬指數
# 2024-11-13 21:59:12,519 - INFO - 其他: 其他類報酬指數
# 2024-11-13 21:59:12,520 - INFO - 其他電子: 其他電子類報酬指數
# 2024-11-13 21:59:12,521 - INFO - 化學: 化學類報酬指數
# 2024-11-13 21:59:12,522 - INFO - 化學生技醫療: 化學生技醫療類報酬指數
# 2024-11-13 21:59:12,524 - INFO - 半導體: 半導體類報酬指數
# 2024-11-13 21:59:12,525 - INFO - 塑膠: 塑膠類報酬指數
# 2024-11-13 21:59:12,526 - INFO - 塑膠化工: 塑膠化工類指數
# 2024-11-13 21:59:12,527 - INFO - 建材營造: 建材營造類報酬指數
# 2024-11-13 21:59:12,529 - INFO - 橡膠: 橡膠類報酬指數
# 2024-11-13 21:59:12,530 - INFO - 水泥: 水泥類報酬指數
# 2024-11-13 21:59:12,532 - INFO - 水泥窯製: 水泥窯製類指數
# 2024-11-13 21:59:12,533 - INFO - 汽車: 汽車類報酬指數
# 2024-11-13 21:59:12,535 - INFO - 油電燃氣: 油電燃氣類報酬指數
# 2024-11-13 21:59:12,536 - INFO - 玻璃陶瓷: 玻璃陶瓷類報酬指數
# 2024-11-13 21:59:12,537 - INFO - 生技醫療: 生技醫療類報酬指數
# 2024-11-13 21:59:12,538 - INFO - 紡織纖維: 紡織纖維類報酬指數
# 2024-11-13 21:59:12,540 - INFO - 航運: 航運類報酬指數
# 2024-11-13 21:59:12,541 - INFO - 觀光: 觀光類報酬指數
# 2024-11-13 21:59:12,542 - INFO - 貿易百貨: 貿易百貨類報酬指數
# 2024-11-13 21:59:12,543 - INFO - 資訊服務: 資訊服務類報酬指數
# 2024-11-13 21:59:12,544 - INFO - 通信網路: 通信網路類報酬指數
# 2024-11-13 21:59:12,546 - INFO - 造紙: 造紙類報酬指數
# 2024-11-13 21:59:12,547 - INFO - 鋼鐵: 鋼鐵類報酬指數
# 2024-11-13 21:59:12,548 - INFO - 電器電纜: 電器電纜類報酬指數
# 2024-11-13 21:59:12,549 - INFO - 電子工: 電子工業類指數
# 2024-11-13 21:59:12,550 - INFO - 電子通路: 電子通路類報酬指數
# 2024-11-13 21:59:12,551 - INFO - 電子零組件: 電子零組件類報酬指數
# 2024-11-13 21:59:12,553 - INFO - 電機機械: 電機機械類報酬指數
# 2024-11-13 21:59:12,556 - INFO - 電腦及週邊設備: 電腦及週邊設備類報酬指數
# 2024-11-13 21:59:12,561 - INFO - 已保存相關性矩陣到: D:\Min\Python\Project\FA_Data\industry_correlation\weekly\industry_correlation_20230526.csv
# 生成週度相關性矩陣:  21%|████████████▊                                                 | 20/97 [00:04<00:16,  4.54it/s]2024-11-13 21:59:12,739 - INFO - 使用的指數類型:
# 2024-11-13 21:59:12,742 - INFO - 光電: 光電類報酬指數
# 2024-11-13 21:59:12,744 - INFO - 其他: 其他類報酬指數
# 2024-11-13 21:59:12,746 - INFO - 其他電子: 其他電子類報酬指數
# 2024-11-13 21:59:12,748 - INFO - 化學: 化學類報酬指數
# 2024-11-13 21:59:12,750 - INFO - 化學生技醫療: 化學生技醫療類報酬指數
# 2024-11-13 21:59:12,752 - INFO - 半導體: 半導體類報酬指數
# 2024-11-13 21:59:12,754 - INFO - 塑膠: 塑膠類報酬指數
# 2024-11-13 21:59:12,756 - INFO - 塑膠化工: 塑膠化工類指數
# 2024-11-13 21:59:12,758 - INFO - 建材營造: 建材營造類報酬指數
# 2024-11-13 21:59:12,760 - INFO - 橡膠: 橡膠類報酬指數
# 2024-11-13 21:59:12,763 - INFO - 水泥: 水泥類報酬指數
# 2024-11-13 21:59:12,765 - INFO - 水泥窯製: 水泥窯製類指數
# 2024-11-13 21:59:12,767 - INFO - 汽車: 汽車類報酬指數
# 2024-11-13 21:59:12,770 - INFO - 油電燃氣: 油電燃氣類報酬指數
# 2024-11-13 21:59:12,772 - INFO - 玻璃陶瓷: 玻璃陶瓷類報酬指數
# 2024-11-13 21:59:12,775 - INFO - 生技醫療: 生技醫療類報酬指數
# 2024-11-13 21:59:12,777 - INFO - 紡織纖維: 紡織纖維類報酬指數
# 2024-11-13 21:59:12,779 - INFO - 航運: 航運類報酬指數
# 2024-11-13 21:59:12,781 - INFO - 觀光: 觀光類報酬指數
# 2024-11-13 21:59:12,783 - INFO - 貿易百貨: 貿易百貨類報酬指數
# 2024-11-13 21:59:12,785 - INFO - 資訊服務: 資訊服務類報酬指數
# 2024-11-13 21:59:12,786 - INFO - 通信網路: 通信網路類報酬指數
# 2024-11-13 21:59:12,787 - INFO - 造紙: 造紙類報酬指數
# 2024-11-13 21:59:12,789 - INFO - 鋼鐵: 鋼鐵類報酬指數
# 2024-11-13 21:59:12,790 - INFO - 電器電纜: 電器電纜類報酬指數
# 2024-11-13 21:59:12,793 - INFO - 電子工: 電子工業類指數
# 2024-11-13 21:59:12,794 - INFO - 電子通路: 電子通路類報酬指數
# 2024-11-13 21:59:12,796 - INFO - 電子零組件: 電子零組件類報酬指數
# 2024-11-13 21:59:12,797 - INFO - 電機機械: 電機機械類報酬指數
# 2024-11-13 21:59:12,798 - INFO - 電腦及週邊設備: 電腦及週邊設備類報酬指數
# 2024-11-13 21:59:12,803 - INFO - 已保存相關性矩陣到: D:\Min\Python\Project\FA_Data\industry_correlation\weekly\industry_correlation_20230602.csv
# 生成週度相關性矩陣:  22%|█████████████▍                                                | 21/97 [00:04<00:17,  4.41it/s]2024-11-13 21:59:12,950 - INFO - 使用的指數類型:
# 2024-11-13 21:59:12,953 - INFO - 光電: 光電類報酬指數
# 2024-11-13 21:59:12,955 - INFO - 其他: 其他類報酬指數
# 2024-11-13 21:59:12,957 - INFO - 其他電子: 其他電子類報酬指數
# 2024-11-13 21:59:12,959 - INFO - 化學: 化學類報酬指數
# 2024-11-13 21:59:12,960 - INFO - 化學生技醫療: 化學生技醫療類報酬指數
# 2024-11-13 21:59:12,961 - INFO - 半導體: 半導體類報酬指數
# 2024-11-13 21:59:12,963 - INFO - 塑膠: 塑膠類報酬指數
# 2024-11-13 21:59:12,964 - INFO - 塑膠化工: 塑膠化工類指數
# 2024-11-13 21:59:12,967 - INFO - 建材營造: 建材營造類報酬指數
# 2024-11-13 21:59:12,968 - INFO - 橡膠: 橡膠類報酬指數
# 2024-11-13 21:59:12,970 - INFO - 水泥: 水泥類報酬指數
# 2024-11-13 21:59:12,971 - INFO - 水泥窯製: 水泥窯製類指數
# 2024-11-13 21:59:12,972 - INFO - 汽車: 汽車類報酬指數
# 2024-11-13 21:59:12,973 - INFO - 油電燃氣: 油電燃氣類報酬指數
# 2024-11-13 21:59:12,974 - INFO - 玻璃陶瓷: 玻璃陶瓷類報酬指數
# 2024-11-13 21:59:12,975 - INFO - 生技醫療: 生技醫療類報酬指數
# 2024-11-13 21:59:12,977 - INFO - 紡織纖維: 紡織纖維類報酬指數
# 2024-11-13 21:59:12,978 - INFO - 航運: 航運類報酬指數
# 2024-11-13 21:59:12,980 - INFO - 觀光: 觀光類報酬指數
# 2024-11-13 21:59:12,982 - INFO - 貿易百貨: 貿易百貨類報酬指數
# 2024-11-13 21:59:12,983 - INFO - 資訊服務: 資訊服務類報酬指數
# 2024-11-13 21:59:12,985 - INFO - 通信網路: 通信網路類報酬指數
# 2024-11-13 21:59:12,986 - INFO - 造紙: 造紙類報酬指數
# 2024-11-13 21:59:12,988 - INFO - 鋼鐵: 鋼鐵類報酬指數
# 2024-11-13 21:59:12,989 - INFO - 電器電纜: 電器電纜類報酬指數
# 2024-11-13 21:59:12,991 - INFO - 電子工: 電子工業類指數
# 2024-11-13 21:59:12,992 - INFO - 電子通路: 電子通路類報酬指數
# 2024-11-13 21:59:12,993 - INFO - 電子零組件: 電子零組件類報酬指數
# 2024-11-13 21:59:12,995 - INFO - 電機機械: 電機機械類報酬指數
# 2024-11-13 21:59:12,996 - INFO - 電腦及週邊設備: 電腦及週邊設備類報酬指數
# 2024-11-13 21:59:13,001 - INFO - 已保存相關性矩陣到: D:\Min\Python\Project\FA_Data\industry_correlation\weekly\industry_correlation_20230609.csv
# 生成週度相關性矩陣:  23%|██████████████                                                | 22/97 [00:04<00:16,  4.59it/s]2024-11-13 21:59:13,139 - INFO - 使用的指數類型:
# 2024-11-13 21:59:13,141 - INFO - 光電: 光電類報酬指數
# 2024-11-13 21:59:13,142 - INFO - 其他: 其他類報酬指數
# 2024-11-13 21:59:13,142 - INFO - 其他電子: 其他電子類報酬指數
# 2024-11-13 21:59:13,143 - INFO - 化學: 化學類報酬指數
# 2024-11-13 21:59:13,145 - INFO - 化學生技醫療: 化學生技醫療類報酬指數
# 2024-11-13 21:59:13,146 - INFO - 半導體: 半導體類報酬指數
# 2024-11-13 21:59:13,148 - INFO - 塑膠: 塑膠類報酬指數
# 2024-11-13 21:59:13,150 - INFO - 塑膠化工: 塑膠化工類指數
# 2024-11-13 21:59:13,152 - INFO - 建材營造: 建材營造類報酬指數
# 2024-11-13 21:59:13,153 - INFO - 橡膠: 橡膠類報酬指數
# 2024-11-13 21:59:13,155 - INFO - 水泥: 水泥類報酬指數
# 2024-11-13 21:59:13,157 - INFO - 水泥窯製: 水泥窯製類指數
# 2024-11-13 21:59:13,159 - INFO - 汽車: 汽車類報酬指數
# 2024-11-13 21:59:13,160 - INFO - 油電燃氣: 油電燃氣類報酬指數
# 2024-11-13 21:59:13,162 - INFO - 玻璃陶瓷: 玻璃陶瓷類報酬指數
# 2024-11-13 21:59:13,163 - INFO - 生技醫療: 生技醫療類報酬指數
# 2024-11-13 21:59:13,165 - INFO - 紡織纖維: 紡織纖維類報酬指數
# 2024-11-13 21:59:13,167 - INFO - 航運: 航運類報酬指數
# 2024-11-13 21:59:13,168 - INFO - 觀光: 觀光類報酬指數
# 2024-11-13 21:59:13,171 - INFO - 貿易百貨: 貿易百貨類報酬指數
# 2024-11-13 21:59:13,172 - INFO - 資訊服務: 資訊服務類報酬指數
# 2024-11-13 21:59:13,174 - INFO - 通信網路: 通信網路類報酬指數
# 2024-11-13 21:59:13,176 - INFO - 造紙: 造紙類報酬指數
# 2024-11-13 21:59:13,177 - INFO - 鋼鐵: 鋼鐵類報酬指數
# 2024-11-13 21:59:13,179 - INFO - 電器電纜: 電器電纜類報酬指數
# 2024-11-13 21:59:13,181 - INFO - 電子工: 電子工業類指數
# 2024-11-13 21:59:13,182 - INFO - 電子通路: 電子通路類報酬指數
# 2024-11-13 21:59:13,184 - INFO - 電子零組件: 電子零組件類報酬指數
# 2024-11-13 21:59:13,187 - INFO - 電機機械: 電機機械類報酬指數
# 2024-11-13 21:59:13,188 - INFO - 電腦及週邊設備: 電腦及週邊設備類報酬指數
# 2024-11-13 21:59:13,192 - INFO - 已保存相關性矩陣到: D:\Min\Python\Project\FA_Data\industry_correlation\weekly\industry_correlation_20230616.csv
# 生成週度相關性矩陣:  24%|██████████████▋                                               | 23/97 [00:04<00:15,  4.76it/s]2024-11-13 21:59:13,354 - INFO - 使用的指數類型:
# 2024-11-13 21:59:13,356 - INFO - 光電: 光電類報酬指數
# 2024-11-13 21:59:13,357 - INFO - 其他: 其他類報酬指數
# 2024-11-13 21:59:13,359 - INFO - 其他電子: 其他電子類報酬指數
# 2024-11-13 21:59:13,360 - INFO - 化學: 化學類報酬指數
# 2024-11-13 21:59:13,362 - INFO - 化學生技醫療: 化學生技醫療類報酬指數
# 2024-11-13 21:59:13,363 - INFO - 半導體: 半導體類報酬指數
# 2024-11-13 21:59:13,364 - INFO - 塑膠: 塑膠類報酬指數
# 2024-11-13 21:59:13,365 - INFO - 塑膠化工: 塑膠化工類指數
# 2024-11-13 21:59:13,367 - INFO - 建材營造: 建材營造類報酬指數
# 2024-11-13 21:59:13,368 - INFO - 橡膠: 橡膠類報酬指數
# 2024-11-13 21:59:13,370 - INFO - 水泥: 水泥類報酬指數
# 2024-11-13 21:59:13,371 - INFO - 水泥窯製: 水泥窯製類指數
# 2024-11-13 21:59:13,373 - INFO - 汽車: 汽車類報酬指數
# 2024-11-13 21:59:13,374 - INFO - 油電燃氣: 油電燃氣類報酬指數
# 2024-11-13 21:59:13,376 - INFO - 玻璃陶瓷: 玻璃陶瓷類報酬指數
# 2024-11-13 21:59:13,377 - INFO - 生技醫療: 生技醫療類報酬指數
# 2024-11-13 21:59:13,379 - INFO - 紡織纖維: 紡織纖維類報酬指數
# 2024-11-13 21:59:13,380 - INFO - 航運: 航運類報酬指數
# 2024-11-13 21:59:13,381 - INFO - 觀光: 觀光類報酬指數
# 2024-11-13 21:59:13,382 - INFO - 貿易百貨: 貿易百貨類報酬指數
# 2024-11-13 21:59:13,384 - INFO - 資訊服務: 資訊服務類報酬指數
# 2024-11-13 21:59:13,386 - INFO - 通信網路: 通信網路類報酬指數
# 2024-11-13 21:59:13,388 - INFO - 造紙: 造紙類報酬指數
# 2024-11-13 21:59:13,390 - INFO - 鋼鐵: 鋼鐵類報酬指數
# 2024-11-13 21:59:13,391 - INFO - 電器電纜: 電器電纜類報酬指數
# 2024-11-13 21:59:13,393 - INFO - 電子工: 電子工業類指數
# 2024-11-13 21:59:13,395 - INFO - 電子通路: 電子通路類報酬指數
# 2024-11-13 21:59:13,396 - INFO - 電子零組件: 電子零組件類報酬指數
# 2024-11-13 21:59:13,398 - INFO - 電機機械: 電機機械類報酬指數
# 2024-11-13 21:59:13,399 - INFO - 電腦及週邊設備: 電腦及週邊設備類報酬指數
# 2024-11-13 21:59:13,406 - INFO - 已保存相關性矩陣到: D:\Min\Python\Project\FA_Data\industry_correlation\weekly\industry_correlation_20230621.csv
# 生成週度相關性矩陣:  25%|███████████████▎                                              | 24/97 [00:04<00:15,  4.73it/s]2024-11-13 21:59:13,543 - INFO - 使用的指數類型:
# 2024-11-13 21:59:13,545 - INFO - 光電: 光電類報酬指數
# 2024-11-13 21:59:13,547 - INFO - 其他: 其他類報酬指數
# 2024-11-13 21:59:13,548 - INFO - 其他電子: 其他電子類報酬指數
# 2024-11-13 21:59:13,549 - INFO - 化學: 化學類報酬指數
# 2024-11-13 21:59:13,551 - INFO - 化學生技醫療: 化學生技醫療類報酬指數
# 2024-11-13 21:59:13,552 - INFO - 半導體: 半導體類報酬指數
# 2024-11-13 21:59:13,553 - INFO - 塑膠: 塑膠類報酬指數
# 2024-11-13 21:59:13,557 - INFO - 塑膠化工: 塑膠化工類指數
# 2024-11-13 21:59:13,558 - INFO - 建材營造: 建材營造類報酬指數
# 2024-11-13 21:59:13,560 - INFO - 橡膠: 橡膠類報酬指數
# 2024-11-13 21:59:13,561 - INFO - 水泥: 水泥類報酬指數
# 2024-11-13 21:59:13,563 - INFO - 水泥窯製: 水泥窯製類指數
# 2024-11-13 21:59:13,565 - INFO - 汽車: 汽車類報酬指數
# 2024-11-13 21:59:13,566 - INFO - 油電燃氣: 油電燃氣類報酬指數
# 2024-11-13 21:59:13,569 - INFO - 玻璃陶瓷: 玻璃陶瓷類報酬指數
# 2024-11-13 21:59:13,570 - INFO - 生技醫療: 生技醫療類報酬指數
# 2024-11-13 21:59:13,572 - INFO - 紡織纖維: 紡織纖維類報酬指數
# 2024-11-13 21:59:13,573 - INFO - 航運: 航運類報酬指數
# 2024-11-13 21:59:13,574 - INFO - 觀光: 觀光類報酬指數
# 2024-11-13 21:59:13,576 - INFO - 貿易百貨: 貿易百貨類報酬指數
# 2024-11-13 21:59:13,577 - INFO - 資訊服務: 資訊服務類報酬指數
# 2024-11-13 21:59:13,579 - INFO - 通信網路: 通信網路類報酬指數
# 2024-11-13 21:59:13,580 - INFO - 造紙: 造紙類報酬指數
# 2024-11-13 21:59:13,581 - INFO - 鋼鐵: 鋼鐵類報酬指數
# 2024-11-13 21:59:13,582 - INFO - 電器電纜: 電器電纜類報酬指數
# 2024-11-13 21:59:13,583 - INFO - 電子工: 電子工業類指數
# 2024-11-13 21:59:13,585 - INFO - 電子通路: 電子通路類報酬指數
# 2024-11-13 21:59:13,587 - INFO - 電子零組件: 電子零組件類報酬指數
# 2024-11-13 21:59:13,588 - INFO - 電機機械: 電機機械類報酬指數
# 2024-11-13 21:59:13,589 - INFO - 電腦及週邊設備: 電腦及週邊設備類報酬指數
# 2024-11-13 21:59:13,595 - INFO - 已保存相關性矩陣到: D:\Min\Python\Project\FA_Data\industry_correlation\weekly\industry_correlation_20230630.csv
# 生成週度相關性矩陣:  26%|███████████████▉                                              | 25/97 [00:05<00:14,  4.89it/s]2024-11-13 21:59:13,757 - INFO - 使用的指數類型:
# 2024-11-13 21:59:13,759 - INFO - 光電: 光電類報酬指數
# 2024-11-13 21:59:13,761 - INFO - 其他: 其他類報酬指數
# 2024-11-13 21:59:13,763 - INFO - 其他電子: 其他電子類報酬指數
# 2024-11-13 21:59:13,765 - INFO - 化學: 化學類報酬指數
# 2024-11-13 21:59:13,766 - INFO - 化學生技醫療: 化學生技醫療類報酬指數
# 2024-11-13 21:59:13,767 - INFO - 半導體: 半導體類報酬指數
# 2024-11-13 21:59:13,768 - INFO - 塑膠: 塑膠類報酬指數
# 2024-11-13 21:59:13,771 - INFO - 塑膠化工: 塑膠化工類指數
# 2024-11-13 21:59:13,772 - INFO - 居家生活: 居家生活類報酬指數
# 2024-11-13 21:59:13,774 - INFO - 建材營造: 建材營造類報酬指數
# 2024-11-13 21:59:13,776 - INFO - 數位雲端: 數位雲端類報酬指數
# 2024-11-13 21:59:13,777 - INFO - 橡膠: 橡膠類報酬指數
# 2024-11-13 21:59:13,779 - INFO - 水泥: 水泥類報酬指數
# 2024-11-13 21:59:13,781 - INFO - 水泥窯製: 水泥窯製類指數
# 2024-11-13 21:59:13,782 - INFO - 汽車: 汽車類報酬指數
# 2024-11-13 21:59:13,784 - INFO - 油電燃氣: 油電燃氣類報酬指數
# 2024-11-13 21:59:13,786 - INFO - 玻璃陶瓷: 玻璃陶瓷類報酬指數
# 2024-11-13 21:59:13,787 - INFO - 生技醫療: 生技醫療類報酬指數
# 2024-11-13 21:59:13,788 - INFO - 紡織纖維: 紡織纖維類報酬指數
# 2024-11-13 21:59:13,789 - INFO - 綠能環保: 綠能環保類報酬指數
# 2024-11-13 21:59:13,791 - INFO - 航運: 航運類報酬指數
# 2024-11-13 21:59:13,792 - INFO - 觀光: 觀光類報酬指數
# 2024-11-13 21:59:13,793 - INFO - 觀光餐旅: 觀光餐旅類報酬指數
# 2024-11-13 21:59:13,794 - INFO - 貿易百貨: 貿易百貨類報酬指數
# 2024-11-13 21:59:13,796 - INFO - 資訊服務: 資訊服務類報酬指數
# 2024-11-13 21:59:13,798 - INFO - 通信網路: 通信網路類報酬指數
# 2024-11-13 21:59:13,799 - INFO - 造紙: 造紙類報酬指數
# 2024-11-13 21:59:13,801 - INFO - 運動休閒: 運動休閒類報酬指數
# 2024-11-13 21:59:13,802 - INFO - 鋼鐵: 鋼鐵類報酬指數
# 2024-11-13 21:59:13,804 - INFO - 電器電纜: 電器電纜類報酬指數
# 2024-11-13 21:59:13,806 - INFO - 電子工: 電子工業類指數
# 2024-11-13 21:59:13,807 - INFO - 電子通路: 電子通路類報酬指數
# 2024-11-13 21:59:13,809 - INFO - 電子零組件: 電子零組件類報酬指數
# 2024-11-13 21:59:13,810 - INFO - 電機機械: 電機機械類報酬指數
# 2024-11-13 21:59:13,811 - INFO - 電腦及週邊設備: 電腦及週邊設備類報酬指數
# 2024-11-13 21:59:13,816 - INFO - 已保存相關性矩陣到: D:\Min\Python\Project\FA_Data\industry_correlation\weekly\industry_correlation_20230707.csv
# 生成週度相關性矩陣:  27%|████████████████▌                                             | 26/97 [00:05<00:14,  4.78it/s]2024-11-13 21:59:13,953 - INFO - 使用的指數類型:
# 2024-11-13 21:59:13,957 - INFO - 光電: 光電類報酬指數
# 2024-11-13 21:59:13,959 - INFO - 其他: 其他類報酬指數
# 2024-11-13 21:59:13,960 - INFO - 其他電子: 其他電子類報酬指數
# 2024-11-13 21:59:13,961 - INFO - 化學: 化學類報酬指數
# 2024-11-13 21:59:13,962 - INFO - 化學生技醫療: 化學生技醫療類報酬指數
# 2024-11-13 21:59:13,964 - INFO - 半導體: 半導體類報酬指數
# 2024-11-13 21:59:13,966 - INFO - 塑膠: 塑膠類報酬指數
# 2024-11-13 21:59:13,967 - INFO - 塑膠化工: 塑膠化工類指數
# 2024-11-13 21:59:13,969 - INFO - 居家生活: 居家生活類報酬指數
# 2024-11-13 21:59:13,971 - INFO - 建材營造: 建材營造類報酬指數
# 2024-11-13 21:59:13,972 - INFO - 數位雲端: 數位雲端類報酬指數
# 2024-11-13 21:59:13,974 - INFO - 橡膠: 橡膠類報酬指數
# 2024-11-13 21:59:13,975 - INFO - 水泥: 水泥類報酬指數
# 2024-11-13 21:59:13,977 - INFO - 水泥窯製: 水泥窯製類指數
# 2024-11-13 21:59:13,978 - INFO - 汽車: 汽車類報酬指數
# 2024-11-13 21:59:13,979 - INFO - 油電燃氣: 油電燃氣類報酬指數
# 2024-11-13 21:59:13,980 - INFO - 玻璃陶瓷: 玻璃陶瓷類報酬指數
# 2024-11-13 21:59:13,982 - INFO - 生技醫療: 生技醫療類報酬指數
# 2024-11-13 21:59:13,983 - INFO - 紡織纖維: 紡織纖維類報酬指數
# 2024-11-13 21:59:13,984 - INFO - 綠能環保: 綠能環保類報酬指數
# 2024-11-13 21:59:13,985 - INFO - 航運: 航運類報酬指數
# 2024-11-13 21:59:13,987 - INFO - 觀光: 觀光類報酬指數
# 2024-11-13 21:59:13,988 - INFO - 觀光餐旅: 觀光餐旅類報酬指數
# 2024-11-13 21:59:13,990 - INFO - 貿易百貨: 貿易百貨類報酬指數
# 2024-11-13 21:59:13,991 - INFO - 資訊服務: 資訊服務類報酬指數
# 2024-11-13 21:59:13,993 - INFO - 通信網路: 通信網路類報酬指數
# 2024-11-13 21:59:13,994 - INFO - 造紙: 造紙類報酬指數
# 2024-11-13 21:59:13,995 - INFO - 運動休閒: 運動休閒類報酬指數
# 2024-11-13 21:59:13,997 - INFO - 鋼鐵: 鋼鐵類報酬指數
# 2024-11-13 21:59:13,999 - INFO - 電器電纜: 電器電纜類報酬指數
# 2024-11-13 21:59:14,000 - INFO - 電子工: 電子工業類指數
# 2024-11-13 21:59:14,001 - INFO - 電子通路: 電子通路類報酬指數
# 2024-11-13 21:59:14,003 - INFO - 電子零組件: 電子零組件類報酬指數
# 2024-11-13 21:59:14,004 - INFO - 電機機械: 電機機械類報酬指數
# 2024-11-13 21:59:14,005 - INFO - 電腦及週邊設備: 電腦及週邊設備類報酬指數
# 2024-11-13 21:59:14,011 - INFO - 已保存相關性矩陣到: D:\Min\Python\Project\FA_Data\industry_correlation\weekly\industry_correlation_20230714.csv
# 生成週度相關性矩陣:  28%|█████████████████▎                                            | 27/97 [00:05<00:14,  4.87it/s]2024-11-13 21:59:14,159 - INFO - 使用的指數類型:
# 2024-11-13 21:59:14,161 - INFO - 光電: 光電類報酬指數
# 2024-11-13 21:59:14,162 - INFO - 其他: 其他類報酬指數
# 2024-11-13 21:59:14,163 - INFO - 其他電子: 其他電子類報酬指數
# 2024-11-13 21:59:14,164 - INFO - 化學: 化學類報酬指數
# 2024-11-13 21:59:14,166 - INFO - 化學生技醫療: 化學生技醫療類報酬指數
# 2024-11-13 21:59:14,167 - INFO - 半導體: 半導體類報酬指數
# 2024-11-13 21:59:14,168 - INFO - 塑膠: 塑膠類報酬指數
# 2024-11-13 21:59:14,170 - INFO - 塑膠化工: 塑膠化工類指數
# 2024-11-13 21:59:14,171 - INFO - 居家生活: 居家生活類報酬指數
# 2024-11-13 21:59:14,173 - INFO - 建材營造: 建材營造類報酬指數
# 2024-11-13 21:59:14,174 - INFO - 數位雲端: 數位雲端類報酬指數
# 2024-11-13 21:59:14,175 - INFO - 橡膠: 橡膠類報酬指數
# 2024-11-13 21:59:14,177 - INFO - 水泥: 水泥類報酬指數
# 2024-11-13 21:59:14,178 - INFO - 水泥窯製: 水泥窯製類指數
# ...
# 2024-11-13 21:59:25,201 - INFO - 電子通路: 電子通路類報酬指數
# 2024-11-13 21:59:25,202 - INFO - 電子零組件: 電子零組件類報酬指數
# 2024-11-13 21:59:25,204 - INFO - 電機機械: 電機機械類報酬指數
# 2024-11-13 21:59:25,206 - INFO - 電腦及週邊設備: 電腦及週邊設備類報酬指數
# 2024-11-13 21:59:25,213 - INFO - 已保存相關性矩陣到: D:\Min\Python\Project\FA_Data\industry_correlation\weekly\industry_correlation_20240712.csv
# 生成週度相關性矩陣:  81%|██████████████████████████████████████████████████▍           | 79/97 [00:16<00:03,  4.98it/s]2024-11-13 21:59:25,347 - INFO - 使用的指數類型:
# 2024-11-13 21:59:25,350 - INFO - 光電: 光電類報酬指數
# 2024-11-13 21:59:25,352 - INFO - 其他: 其他類報酬指數
# 2024-11-13 21:59:25,353 - INFO - 其他電子: 其他電子類報酬指數
# 2024-11-13 21:59:25,355 - INFO - 化學: 化學類報酬指數
# 2024-11-13 21:59:25,356 - INFO - 化學生技醫療: 化學生技醫療類報酬指數
# 2024-11-13 21:59:25,358 - INFO - 半導體: 半導體類指數
# 2024-11-13 21:59:25,359 - INFO - 塑膠: 塑膠類報酬指數
# 2024-11-13 21:59:25,361 - INFO - 塑膠化工: 塑膠化工類指數
# 2024-11-13 21:59:25,363 - INFO - 居家生活: 居家生活類報酬指數
# 2024-11-13 21:59:25,364 - INFO - 建材營造: 建材營造類指數
# 2024-11-13 21:59:25,366 - INFO - 數位雲端: 數位雲端類報酬指數
# 2024-11-13 21:59:25,368 - INFO - 橡膠: 橡膠類報酬指數
# 2024-11-13 21:59:25,370 - INFO - 水泥: 水泥類報酬指數
# 2024-11-13 21:59:25,371 - INFO - 水泥窯製: 水泥窯製類指數
# 2024-11-13 21:59:25,372 - INFO - 汽車: 汽車類報酬指數
# 2024-11-13 21:59:25,374 - INFO - 油電燃氣: 油電燃氣類報酬指數
# 2024-11-13 21:59:25,376 - INFO - 玻璃陶瓷: 玻璃陶瓷類報酬指數
# 2024-11-13 21:59:25,377 - INFO - 生技醫療: 生技醫療類報酬指數
# 2024-11-13 21:59:25,379 - INFO - 紡織纖維: 紡織纖維類指數
# 2024-11-13 21:59:25,380 - INFO - 綠能環保: 綠能環保類報酬指數
# 2024-11-13 21:59:25,382 - INFO - 航運: 航運類報酬指數
# 2024-11-13 21:59:25,384 - INFO - 觀光餐旅: 觀光餐旅類報酬指數
# 2024-11-13 21:59:25,386 - INFO - 貿易百貨: 貿易百貨類報酬指數
# 2024-11-13 21:59:25,386 - INFO - 資訊服務: 資訊服務類報酬指數
# 2024-11-13 21:59:25,389 - INFO - 通信網路: 通信網路類報酬指數
# 2024-11-13 21:59:25,390 - INFO - 造紙: 造紙類報酬指數
# 2024-11-13 21:59:25,392 - INFO - 運動休閒: 運動休閒類報酬指數
# 2024-11-13 21:59:25,394 - INFO - 鋼鐵: 鋼鐵類報酬指數
# 2024-11-13 21:59:25,395 - INFO - 電器電纜: 電器電纜類報酬指數
# 2024-11-13 21:59:25,396 - INFO - 電子通路: 電子通路類報酬指數
# 2024-11-13 21:59:25,398 - INFO - 電子零組件: 電子零組件類報酬指數
# 2024-11-13 21:59:25,399 - INFO - 電機機械: 電機機械類報酬指數
# 2024-11-13 21:59:25,401 - INFO - 電腦及週邊設備: 電腦及週邊設備類報酬指數
# 2024-11-13 21:59:25,406 - INFO - 已保存相關性矩陣到: D:\Min\Python\Project\FA_Data\industry_correlation\weekly\industry_correlation_20240719.csv
# 生成週度相關性矩陣:  82%|███████████████████████████████████████████████████▏          | 80/97 [00:16<00:03,  5.04it/s]2024-11-13 21:59:25,566 - INFO - 使用的指數類型:
# 2024-11-13 21:59:25,569 - INFO - 光電: 光電類報酬指數
# 2024-11-13 21:59:25,571 - INFO - 其他: 其他類報酬指數
# 2024-11-13 21:59:25,572 - INFO - 其他電子: 其他電子類報酬指數
# 2024-11-13 21:59:25,574 - INFO - 化學: 化學類報酬指數
# 2024-11-13 21:59:25,575 - INFO - 化學生技醫療: 化學生技醫療類報酬指數
# 2024-11-13 21:59:25,577 - INFO - 半導體: 半導體類指數
# 2024-11-13 21:59:25,579 - INFO - 塑膠: 塑膠類報酬指數
# 2024-11-13 21:59:25,580 - INFO - 塑膠化工: 塑膠化工類指數
# 2024-11-13 21:59:25,582 - INFO - 居家生活: 居家生活類報酬指數
# 2024-11-13 21:59:25,584 - INFO - 建材營造: 建材營造類指數
# 2024-11-13 21:59:25,585 - INFO - 數位雲端: 數位雲端類報酬指數
# 2024-11-13 21:59:25,587 - INFO - 橡膠: 橡膠類報酬指數
# 2024-11-13 21:59:25,588 - INFO - 水泥: 水泥類報酬指數
# 2024-11-13 21:59:25,590 - INFO - 水泥窯製: 水泥窯製類指數
# 2024-11-13 21:59:25,591 - INFO - 汽車: 汽車類報酬指數
# 2024-11-13 21:59:25,593 - INFO - 油電燃氣: 油電燃氣類報酬指數
# 2024-11-13 21:59:25,595 - INFO - 玻璃陶瓷: 玻璃陶瓷類報酬指數
# 2024-11-13 21:59:25,596 - INFO - 生技醫療: 生技醫療類報酬指數
# 2024-11-13 21:59:25,598 - INFO - 紡織纖維: 紡織纖維類指數
# 2024-11-13 21:59:25,600 - INFO - 綠能環保: 綠能環保類報酬指數
# 2024-11-13 21:59:25,602 - INFO - 航運: 航運類報酬指數
# 2024-11-13 21:59:25,604 - INFO - 觀光餐旅: 觀光餐旅類報酬指數
# 2024-11-13 21:59:25,605 - INFO - 貿易百貨: 貿易百貨類報酬指數
# 2024-11-13 21:59:25,606 - INFO - 資訊服務: 資訊服務類報酬指數
# 2024-11-13 21:59:25,608 - INFO - 通信網路: 通信網路類報酬指數
# 2024-11-13 21:59:25,610 - INFO - 造紙: 造紙類報酬指數
# 2024-11-13 21:59:25,613 - INFO - 運動休閒: 運動休閒類報酬指數
# 2024-11-13 21:59:25,614 - INFO - 鋼鐵: 鋼鐵類報酬指數
# 2024-11-13 21:59:25,616 - INFO - 電器電纜: 電器電纜類報酬指數
# 2024-11-13 21:59:25,619 - INFO - 電子通路: 電子通路類報酬指數
# 2024-11-13 21:59:25,621 - INFO - 電子零組件: 電子零組件類報酬指數
# 2024-11-13 21:59:25,624 - INFO - 電機機械: 電機機械類報酬指數
# 2024-11-13 21:59:25,627 - INFO - 電腦及週邊設備: 電腦及週邊設備類報酬指數
# 2024-11-13 21:59:25,636 - INFO - 已保存相關性矩陣到: D:\Min\Python\Project\FA_Data\industry_correlation\weekly\industry_correlation_20240726.csv
# 生成週度相關性矩陣:  84%|███████████████████████████████████████████████████▊          | 81/97 [00:17<00:03,  4.81it/s]2024-11-13 21:59:25,787 - INFO - 使用的指數類型:
# 2024-11-13 21:59:25,789 - INFO - 光電: 光電類報酬指數
# 2024-11-13 21:59:25,791 - INFO - 其他: 其他類報酬指數
# 2024-11-13 21:59:25,792 - INFO - 其他電子: 其他電子類報酬指數
# 2024-11-13 21:59:25,794 - INFO - 化學: 化學類報酬指數
# 2024-11-13 21:59:25,796 - INFO - 化學生技醫療: 化學生技醫療類報酬指數
# 2024-11-13 21:59:25,797 - INFO - 半導體: 半導體類指數
# 2024-11-13 21:59:25,798 - INFO - 塑膠: 塑膠類報酬指數
# 2024-11-13 21:59:25,800 - INFO - 塑膠化工: 塑膠化工類指數
# 2024-11-13 21:59:25,801 - INFO - 居家生活: 居家生活類報酬指數
# 2024-11-13 21:59:25,802 - INFO - 建材營造: 建材營造類指數
# 2024-11-13 21:59:25,804 - INFO - 數位雲端: 數位雲端類報酬指數
# 2024-11-13 21:59:25,804 - INFO - 橡膠: 橡膠類報酬指數
# 2024-11-13 21:59:25,806 - INFO - 水泥: 水泥類報酬指數
# 2024-11-13 21:59:25,807 - INFO - 水泥窯製: 水泥窯製類指數
# 2024-11-13 21:59:25,809 - INFO - 汽車: 汽車類報酬指數
# 2024-11-13 21:59:25,810 - INFO - 油電燃氣: 油電燃氣類報酬指數
# 2024-11-13 21:59:25,811 - INFO - 玻璃陶瓷: 玻璃陶瓷類報酬指數
# 2024-11-13 21:59:25,812 - INFO - 生技醫療: 生技醫療類報酬指數
# 2024-11-13 21:59:25,813 - INFO - 紡織纖維: 紡織纖維類指數
# 2024-11-13 21:59:25,815 - INFO - 綠能環保: 綠能環保類報酬指數
# 2024-11-13 21:59:25,816 - INFO - 航運: 航運類報酬指數
# 2024-11-13 21:59:25,818 - INFO - 觀光餐旅: 觀光餐旅類報酬指數
# 2024-11-13 21:59:25,820 - INFO - 貿易百貨: 貿易百貨類報酬指數
# 2024-11-13 21:59:25,821 - INFO - 資訊服務: 資訊服務類報酬指數
# 2024-11-13 21:59:25,822 - INFO - 通信網路: 通信網路類報酬指數
# 2024-11-13 21:59:25,823 - INFO - 造紙: 造紙類報酬指數
# 2024-11-13 21:59:25,825 - INFO - 運動休閒: 運動休閒類報酬指數
# 2024-11-13 21:59:25,826 - INFO - 鋼鐵: 鋼鐵類報酬指數
# 2024-11-13 21:59:25,827 - INFO - 電器電纜: 電器電纜類報酬指數
# 2024-11-13 21:59:25,829 - INFO - 電子通路: 電子通路類報酬指數
# 2024-11-13 21:59:25,831 - INFO - 電子零組件: 電子零組件類報酬指數
# 2024-11-13 21:59:25,833 - INFO - 電機機械: 電機機械類報酬指數
# 2024-11-13 21:59:25,835 - INFO - 電腦及週邊設備: 電腦及週邊設備類報酬指數
# 2024-11-13 21:59:25,840 - INFO - 已保存相關性矩陣到: D:\Min\Python\Project\FA_Data\industry_correlation\weekly\industry_correlation_20240802.csv
# 生成週度相關性矩陣:  85%|████████████████████████████████████████████████████▍         | 82/97 [00:17<00:03,  4.84it/s]2024-11-13 21:59:25,982 - INFO - 使用的指數類型:
# 2024-11-13 21:59:25,985 - INFO - 光電: 光電類報酬指數
# 2024-11-13 21:59:25,986 - INFO - 其他: 其他類報酬指數
# 2024-11-13 21:59:25,988 - INFO - 其他電子: 其他電子類報酬指數
# 2024-11-13 21:59:25,989 - INFO - 化學: 化學類報酬指數
# 2024-11-13 21:59:25,991 - INFO - 化學生技醫療: 化學生技醫療類報酬指數
# 2024-11-13 21:59:25,993 - INFO - 半導體: 半導體類報酬指數
# 2024-11-13 21:59:25,994 - INFO - 塑膠: 塑膠類報酬指數
# 2024-11-13 21:59:25,995 - INFO - 塑膠化工: 塑膠化工類指數
# 2024-11-13 21:59:25,996 - INFO - 居家生活: 居家生活類報酬指數
# 2024-11-13 21:59:25,997 - INFO - 建材營造: 建材營造類指數
# 2024-11-13 21:59:25,998 - INFO - 數位雲端: 數位雲端類報酬指數
# 2024-11-13 21:59:25,999 - INFO - 橡膠: 橡膠類報酬指數
# 2024-11-13 21:59:26,001 - INFO - 水泥: 水泥類報酬指數
# 2024-11-13 21:59:26,002 - INFO - 水泥窯製: 水泥窯製類指數
# 2024-11-13 21:59:26,004 - INFO - 汽車: 汽車類報酬指數
# 2024-11-13 21:59:26,005 - INFO - 油電燃氣: 油電燃氣類報酬指數
# 2024-11-13 21:59:26,006 - INFO - 玻璃陶瓷: 玻璃陶瓷類報酬指數
# 2024-11-13 21:59:26,007 - INFO - 生技醫療: 生技醫療類報酬指數
# 2024-11-13 21:59:26,009 - INFO - 紡織纖維: 紡織纖維類指數
# 2024-11-13 21:59:26,010 - INFO - 綠能環保: 綠能環保類報酬指數
# 2024-11-13 21:59:26,012 - INFO - 航運: 航運類報酬指數
# 2024-11-13 21:59:26,013 - INFO - 觀光餐旅: 觀光餐旅類報酬指數
# 2024-11-13 21:59:26,015 - INFO - 貿易百貨: 貿易百貨類報酬指數
# 2024-11-13 21:59:26,016 - INFO - 資訊服務: 資訊服務類報酬指數
# 2024-11-13 21:59:26,017 - INFO - 通信網路: 通信網路類報酬指數
# 2024-11-13 21:59:26,019 - INFO - 造紙: 造紙類報酬指數
# 2024-11-13 21:59:26,020 - INFO - 運動休閒: 運動休閒類報酬指數
# 2024-11-13 21:59:26,021 - INFO - 鋼鐵: 鋼鐵類報酬指數
# 2024-11-13 21:59:26,023 - INFO - 電器電纜: 電器電纜類報酬指數
# 2024-11-13 21:59:26,025 - INFO - 電子通路: 電子通路類報酬指數
# 2024-11-13 21:59:26,026 - INFO - 電子零組件: 電子零組件類報酬指數
# 2024-11-13 21:59:26,029 - INFO - 電機機械: 電機機械類報酬指數
# 2024-11-13 21:59:26,030 - INFO - 電腦及週邊設備: 電腦及週邊設備類報酬指數
# 2024-11-13 21:59:26,035 - INFO - 已保存相關性矩陣到: D:\Min\Python\Project\FA_Data\industry_correlation\weekly\industry_correlation_20240809.csv
# 生成週度相關性矩陣:  86%|█████████████████████████████████████████████████████         | 83/97 [00:17<00:02,  4.92it/s]2024-11-13 21:59:26,182 - INFO - 使用的指數類型:
# 2024-11-13 21:59:26,184 - INFO - 光電: 光電類報酬指數
# 2024-11-13 21:59:26,185 - INFO - 其他: 其他類報酬指數
# 2024-11-13 21:59:26,186 - INFO - 其他電子: 其他電子類報酬指數
# 2024-11-13 21:59:26,188 - INFO - 化學: 化學類報酬指數
# 2024-11-13 21:59:26,189 - INFO - 化學生技醫療: 化學生技醫療類報酬指數
# 2024-11-13 21:59:26,191 - INFO - 半導體: 半導體類報酬指數
# 2024-11-13 21:59:26,193 - INFO - 塑膠: 塑膠類報酬指數
# 2024-11-13 21:59:26,194 - INFO - 塑膠化工: 塑膠化工類指數
# 2024-11-13 21:59:26,196 - INFO - 居家生活: 居家生活類報酬指數
# 2024-11-13 21:59:26,198 - INFO - 建材營造: 建材營造類指數
# 2024-11-13 21:59:26,199 - INFO - 數位雲端: 數位雲端類報酬指數
# 2024-11-13 21:59:26,200 - INFO - 橡膠: 橡膠類報酬指數
# 2024-11-13 21:59:26,202 - INFO - 水泥: 水泥類報酬指數
# 2024-11-13 21:59:26,203 - INFO - 水泥窯製: 水泥窯製類指數
# 2024-11-13 21:59:26,205 - INFO - 汽車: 汽車類報酬指數
# 2024-11-13 21:59:26,206 - INFO - 油電燃氣: 油電燃氣類報酬指數
# 2024-11-13 21:59:26,207 - INFO - 玻璃陶瓷: 玻璃陶瓷類報酬指數
# 2024-11-13 21:59:26,208 - INFO - 生技醫療: 生技醫療類報酬指數
# 2024-11-13 21:59:26,210 - INFO - 紡織纖維: 紡織纖維類指數
# 2024-11-13 21:59:26,211 - INFO - 綠能環保: 綠能環保類報酬指數
# 2024-11-13 21:59:26,212 - INFO - 航運: 航運類報酬指數
# 2024-11-13 21:59:26,214 - INFO - 觀光餐旅: 觀光餐旅類報酬指數
# 2024-11-13 21:59:26,215 - INFO - 貿易百貨: 貿易百貨類報酬指數
# 2024-11-13 21:59:26,217 - INFO - 資訊服務: 資訊服務類報酬指數
# 2024-11-13 21:59:26,218 - INFO - 通信網路: 通信網路類報酬指數
# 2024-11-13 21:59:26,220 - INFO - 造紙: 造紙類報酬指數
# 2024-11-13 21:59:26,222 - INFO - 運動休閒: 運動休閒類報酬指數
# 2024-11-13 21:59:26,224 - INFO - 鋼鐵: 鋼鐵類報酬指數
# 2024-11-13 21:59:26,226 - INFO - 電器電纜: 電器電纜類報酬指數
# 2024-11-13 21:59:26,227 - INFO - 電子通路: 電子通路類報酬指數
# 2024-11-13 21:59:26,228 - INFO - 電子零組件: 電子零組件類報酬指數
# 2024-11-13 21:59:26,230 - INFO - 電機機械: 電機機械類報酬指數
# 2024-11-13 21:59:26,231 - INFO - 電腦及週邊設備: 電腦及週邊設備類報酬指數
# 2024-11-13 21:59:26,236 - INFO - 已保存相關性矩陣到: D:\Min\Python\Project\FA_Data\industry_correlation\weekly\industry_correlation_20240816.csv
# 生成週度相關性矩陣:  87%|█████████████████████████████████████████████████████▋        | 84/97 [00:17<00:02,  4.94it/s]2024-11-13 21:59:26,375 - INFO - 使用的指數類型:
# 2024-11-13 21:59:26,377 - INFO - 光電: 光電類報酬指數
# 2024-11-13 21:59:26,379 - INFO - 其他: 其他類報酬指數
# 2024-11-13 21:59:26,380 - INFO - 其他電子: 其他電子類報酬指數
# 2024-11-13 21:59:26,382 - INFO - 化學: 化學類報酬指數
# 2024-11-13 21:59:26,383 - INFO - 化學生技醫療: 化學生技醫療類報酬指數
# 2024-11-13 21:59:26,384 - INFO - 半導體: 半導體類報酬指數
# 2024-11-13 21:59:26,386 - INFO - 塑膠: 塑膠類報酬指數
# 2024-11-13 21:59:26,387 - INFO - 塑膠化工: 塑膠化工類指數
# 2024-11-13 21:59:26,388 - INFO - 居家生活: 居家生活類報酬指數
# 2024-11-13 21:59:26,389 - INFO - 建材營造: 建材營造類指數
# 2024-11-13 21:59:26,391 - INFO - 數位雲端: 數位雲端類報酬指數
# 2024-11-13 21:59:26,393 - INFO - 橡膠: 橡膠類報酬指數
# 2024-11-13 21:59:26,395 - INFO - 水泥: 水泥類報酬指數
# 2024-11-13 21:59:26,397 - INFO - 水泥窯製: 水泥窯製類指數
# 2024-11-13 21:59:26,398 - INFO - 汽車: 汽車類報酬指數
# 2024-11-13 21:59:26,399 - INFO - 油電燃氣: 油電燃氣類報酬指數
# 2024-11-13 21:59:26,401 - INFO - 玻璃陶瓷: 玻璃陶瓷類報酬指數
# 2024-11-13 21:59:26,402 - INFO - 生技醫療: 生技醫療類報酬指數
# 2024-11-13 21:59:26,403 - INFO - 紡織纖維: 紡織纖維類指數
# 2024-11-13 21:59:26,405 - INFO - 綠能環保: 綠能環保類報酬指數
# 2024-11-13 21:59:26,406 - INFO - 航運: 航運類報酬指數
# 2024-11-13 21:59:26,408 - INFO - 觀光餐旅: 觀光餐旅類報酬指數
# 2024-11-13 21:59:26,410 - INFO - 貿易百貨: 貿易百貨類報酬指數
# 2024-11-13 21:59:26,412 - INFO - 資訊服務: 資訊服務類報酬指數
# 2024-11-13 21:59:26,413 - INFO - 通信網路: 通信網路類報酬指數
# 2024-11-13 21:59:26,415 - INFO - 造紙: 造紙類報酬指數
# 2024-11-13 21:59:26,416 - INFO - 運動休閒: 運動休閒類報酬指數
# 2024-11-13 21:59:26,417 - INFO - 鋼鐵: 鋼鐵類報酬指數
# 2024-11-13 21:59:26,419 - INFO - 電器電纜: 電器電纜類報酬指數
# 2024-11-13 21:59:26,420 - INFO - 電子通路: 電子通路類報酬指數
# 2024-11-13 21:59:26,422 - INFO - 電子零組件: 電子零組件類報酬指數
# 2024-11-13 21:59:26,423 - INFO - 電機機械: 電機機械類報酬指數
# 2024-11-13 21:59:26,424 - INFO - 電腦及週邊設備: 電腦及週邊設備類報酬指數
# 2024-11-13 21:59:26,429 - INFO - 已保存相關性矩陣到: D:\Min\Python\Project\FA_Data\industry_correlation\weekly\industry_correlation_20240823.csv
# 生成週度相關性矩陣:  88%|██████████████████████████████████████████████████████▎       | 85/97 [00:17<00:02,  5.01it/s]2024-11-13 21:59:26,566 - INFO - 使用的指數類型:
# 2024-11-13 21:59:26,568 - INFO - 光電: 光電類報酬指數
# 2024-11-13 21:59:26,570 - INFO - 其他: 其他類報酬指數
# 2024-11-13 21:59:26,572 - INFO - 其他電子: 其他電子類報酬指數
# 2024-11-13 21:59:26,573 - INFO - 化學: 化學類報酬指數
# 2024-11-13 21:59:26,574 - INFO - 化學生技醫療: 化學生技醫療類報酬指數
# 2024-11-13 21:59:26,575 - INFO - 半導體: 半導體類報酬指數
# 2024-11-13 21:59:26,577 - INFO - 塑膠: 塑膠類報酬指數
# 2024-11-13 21:59:26,579 - INFO - 塑膠化工: 塑膠化工類指數
# 2024-11-13 21:59:26,580 - INFO - 居家生活: 居家生活類報酬指數
# 2024-11-13 21:59:26,581 - INFO - 建材營造: 建材營造類指數
# 2024-11-13 21:59:26,583 - INFO - 數位雲端: 數位雲端類報酬指數
# 2024-11-13 21:59:26,584 - INFO - 橡膠: 橡膠類報酬指數
# 2024-11-13 21:59:26,586 - INFO - 水泥: 水泥類報酬指數
# 2024-11-13 21:59:26,587 - INFO - 水泥窯製: 水泥窯製類指數
# 2024-11-13 21:59:26,589 - INFO - 汽車: 汽車類報酬指數
# 2024-11-13 21:59:26,591 - INFO - 油電燃氣: 油電燃氣類報酬指數
# 2024-11-13 21:59:26,592 - INFO - 玻璃陶瓷: 玻璃陶瓷類報酬指數
# 2024-11-13 21:59:26,593 - INFO - 生技醫療: 生技醫療類報酬指數
# 2024-11-13 21:59:26,595 - INFO - 紡織纖維: 紡織纖維類指數
# 2024-11-13 21:59:26,596 - INFO - 綠能環保: 綠能環保類報酬指數
# 2024-11-13 21:59:26,597 - INFO - 航運: 航運類報酬指數
# 2024-11-13 21:59:26,598 - INFO - 觀光餐旅: 觀光餐旅類報酬指數
# 2024-11-13 21:59:26,599 - INFO - 貿易百貨: 貿易百貨類報酬指數
# 2024-11-13 21:59:26,600 - INFO - 資訊服務: 資訊服務類報酬指數
# 2024-11-13 21:59:26,601 - INFO - 通信網路: 通信網路類報酬指數
# 2024-11-13 21:59:26,602 - INFO - 造紙: 造紙類報酬指數
# 2024-11-13 21:59:26,604 - INFO - 運動休閒: 運動休閒類報酬指數
# 2024-11-13 21:59:26,606 - INFO - 鋼鐵: 鋼鐵類報酬指數
# 2024-11-13 21:59:26,606 - INFO - 電器電纜: 電器電纜類報酬指數
# 2024-11-13 21:59:26,607 - INFO - 電子通路: 電子通路類報酬指數
# 2024-11-13 21:59:26,609 - INFO - 電子零組件: 電子零組件類報酬指數
# 2024-11-13 21:59:26,610 - INFO - 電機機械: 電機機械類報酬指數
# 2024-11-13 21:59:26,611 - INFO - 電腦及週邊設備: 電腦及週邊設備類報酬指數
# 2024-11-13 21:59:26,617 - INFO - 已保存相關性矩陣到: D:\Min\Python\Project\FA_Data\industry_correlation\weekly\industry_correlation_20240830.csv
# 生成週度相關性矩陣:  89%|██████████████████████████████████████████████████████▉       | 86/97 [00:18<00:02,  5.10it/s]2024-11-13 21:59:26,745 - INFO - 使用的指數類型:
# 2024-11-13 21:59:26,746 - INFO - 光電: 光電類報酬指數
# 2024-11-13 21:59:26,751 - INFO - 其他: 其他類報酬指數
# 2024-11-13 21:59:26,753 - INFO - 其他電子: 其他電子類報酬指數
# 2024-11-13 21:59:26,755 - INFO - 化學: 化學類報酬指數
# 2024-11-13 21:59:26,756 - INFO - 化學生技醫療: 化學生技醫療類報酬指數
# 2024-11-13 21:59:26,758 - INFO - 半導體: 半導體類指數
# 2024-11-13 21:59:26,759 - INFO - 塑膠: 塑膠類報酬指數
# 2024-11-13 21:59:26,761 - INFO - 塑膠化工: 塑膠化工類指數
# 2024-11-13 21:59:26,762 - INFO - 居家生活: 居家生活類報酬指數
# 2024-11-13 21:59:26,764 - INFO - 建材營造: 建材營造類指數
# 2024-11-13 21:59:26,766 - INFO - 數位雲端: 數位雲端類報酬指數
# 2024-11-13 21:59:26,767 - INFO - 橡膠: 橡膠類報酬指數
# 2024-11-13 21:59:26,769 - INFO - 水泥: 水泥類報酬指數
# 2024-11-13 21:59:26,770 - INFO - 水泥窯製: 水泥窯製類指數
# 2024-11-13 21:59:26,771 - INFO - 汽車: 汽車類報酬指數
# 2024-11-13 21:59:26,773 - INFO - 油電燃氣: 油電燃氣類報酬指數
# 2024-11-13 21:59:26,774 - INFO - 玻璃陶瓷: 玻璃陶瓷類報酬指數
# 2024-11-13 21:59:26,776 - INFO - 生技醫療: 生技醫療類報酬指數
# 2024-11-13 21:59:26,777 - INFO - 紡織纖維: 紡織纖維類指數
# 2024-11-13 21:59:26,779 - INFO - 綠能環保: 綠能環保類報酬指數
# 2024-11-13 21:59:26,781 - INFO - 航運: 航運類報酬指數
# 2024-11-13 21:59:26,782 - INFO - 觀光餐旅: 觀光餐旅類報酬指數
# 2024-11-13 21:59:26,783 - INFO - 貿易百貨: 貿易百貨類報酬指數
# 2024-11-13 21:59:26,784 - INFO - 資訊服務: 資訊服務類報酬指數
# 2024-11-13 21:59:26,786 - INFO - 通信網路: 通信網路類報酬指數
# 2024-11-13 21:59:26,788 - INFO - 造紙: 造紙類報酬指數
# 2024-11-13 21:59:26,789 - INFO - 運動休閒: 運動休閒類報酬指數
# 2024-11-13 21:59:26,791 - INFO - 鋼鐵: 鋼鐵類報酬指數
# 2024-11-13 21:59:26,792 - INFO - 電器電纜: 電器電纜類報酬指數
# 2024-11-13 21:59:26,794 - INFO - 電子通路: 電子通路類報酬指數
# 2024-11-13 21:59:26,796 - INFO - 電子零組件: 電子零組件類報酬指數
# 2024-11-13 21:59:26,798 - INFO - 電機機械: 電機機械類報酬指數
# 2024-11-13 21:59:26,799 - INFO - 電腦及週邊設備: 電腦及週邊設備類報酬指數
# 2024-11-13 21:59:26,803 - INFO - 已保存相關性矩陣到: D:\Min\Python\Project\FA_Data\industry_correlation\weekly\industry_correlation_20240906.csv
# 生成週度相關性矩陣:  90%|███████████████████████████████████████████████████████▌      | 87/97 [00:18<00:01,  5.18it/s]2024-11-13 21:59:26,945 - INFO - 使用的指數類型:
# 2024-11-13 21:59:26,947 - INFO - 光電: 光電類報酬指數
# 2024-11-13 21:59:26,949 - INFO - 其他: 其他類報酬指數
# 2024-11-13 21:59:26,950 - INFO - 其他電子: 其他電子類報酬指數
# 2024-11-13 21:59:26,951 - INFO - 化學: 化學類報酬指數
# 2024-11-13 21:59:26,953 - INFO - 化學生技醫療: 化學生技醫療類報酬指數
# 2024-11-13 21:59:26,954 - INFO - 半導體: 半導體類指數
# 2024-11-13 21:59:26,955 - INFO - 塑膠: 塑膠類報酬指數
# 2024-11-13 21:59:26,957 - INFO - 塑膠化工: 塑膠化工類指數
# 2024-11-13 21:59:26,958 - INFO - 居家生活: 居家生活類報酬指數
# 2024-11-13 21:59:26,960 - INFO - 建材營造: 建材營造類指數
# 2024-11-13 21:59:26,961 - INFO - 數位雲端: 數位雲端類報酬指數
# 2024-11-13 21:59:26,963 - INFO - 橡膠: 橡膠類報酬指數
